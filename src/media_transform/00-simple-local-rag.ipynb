# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/mrdbourke/simple-local-rag/blob/main/00-simple-local-rag.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# # Create and run a local RAG pipeline from scratch
#
# The goal of this notebook is to build a RAG (Retrieval Augmented Generation) pipeline from scratch and have it run on a local GPU.
#
# Specifically, we'd like to be able to open a PDF file, ask questions (queries) of it and have them answered by a Large Language Model (LLM).
#
# There are frameworks that replicate this kind of workflow, including [LlamaIndex](https://www.llamaindex.ai/) and [LangChain](https://www.langchain.com/), however, the goal of building from scratch is to be able to inspect and customize all the parts.

# %% [markdown]
# ## What is RAG?
#
# RAG stands for Retrieval Augmented Generation.
#
# It was introduced in the paper [*Retrieval-Augmented Generation for Knowledge-Intensive NLP Tasks*](https://arxiv.org/abs/2005.11401).
#
# Each step can be roughly broken down to:
#
# * **Retrieval** - Seeking relevant information from a source given a query. For example, getting relevant passages of Wikipedia text from a database given a question.
# * **Augmented** - Using the relevant retrieved information to modify an input to a generative model (e.g. an LLM).
# * **Generation** - Generating an output given an input. For example, in the case of an LLM, generating a passage of text given an input prompt.

# %% [markdown]
# ## Why RAG?
#
# The main goal of RAG is to improve the generation outptus of LLMs.
#
# Two primary improvements can be seen as:
# 1. **Preventing hallucinations** - LLMs are incredible but they are prone to potential hallucination, as in, generating something that *looks* correct but isn't. RAG pipelines can help LLMs generate more factual outputs by providing them with factual (retrieved) inputs. And even if the generated answer from a RAG pipeline doesn't seem correct, because of retrieval, you also have access to the sources where it came from.
# 2. **Work with custom data** - Many base LLMs are trained with internet-scale text data. This means they have a great ability to model language, however, they often lack specific knowledge. RAG systems can provide LLMs with domain-specific data such as medical information or company documentation and thus customized their outputs to suit specific use cases.
#
# The authors of the original RAG paper mentioned above outlined these two points in their discussion.
#
# > This work offers several positive societal benefits over previous work: the fact that it is more
# strongly grounded in real factual knowledge (in this case Wikipedia) makes it “hallucinate” less
# with generations that are more factual, and offers more control and interpretability. RAG could be
# employed in a wide variety of scenarios with direct benefit to society, for example by endowing it
# with a medical index and asking it open-domain questions on that topic, or by helping people be more
# effective at their jobs.
#
# RAG can also be a much quicker solution to implement than fine-tuning an LLM on specific data.

# %% [markdown]
# ## What kind of problems can RAG be used for?
#
# RAG can help anywhere there is a specific set of information that an LLM may not have in its training data (e.g. anything not publicly accessible on the internet).
#
# For example you could use RAG for:
# * **Customer support Q&A chat** - By treating your existing customer support documentation as a resource, when a customer asks a question, you could have a system retrieve relevant documentation snippets and then have an LLM craft those snippets into an answer. Think of this as a "chatbot for your documentation". Klarna, a large financial company, [uses a system like this](https://www.klarna.com/international/press/klarna-ai-assistant-handles-two-thirds-of-customer-service-chats-in-its-first-month/) to save $40M per year on customer support costs.
# * **Email chain analysis** - Let's say you're an insurance company with long threads of emails between customers and insurance agents. Instead of searching through each individual email, you could retrieve relevant passages and have an LLM create strucutred outputs of insurance claims.
# * **Company internal documentation chat** - If you've worked at a large company, you know how hard it can be to get an answer sometimes. Why not let a RAG system index your company information and have an LLM answer questions you may have? The benefit of RAG is that you will have references to resources to learn more if the LLM answer doesn't suffice.
# * **Textbook Q&A** - Let's say you're studying for your exams and constantly flicking through a large textbook looking for answers to your quesitons. RAG can help provide answers as well as references to learn more.
#
# All of these have the common theme of retrieving relevant resources and then presenting them in an understandable way using an LLM.
#
# From this angle, you can consider an LLM a calculator for words.

# %% [markdown]
# ## Why local?
#
# Privacy, speed, cost.
#
# Running locally means you use your own hardware.
#
# From a privacy standpoint, this means you don't have send potentially sensitive data to an API.
#
# From a speed standpoint, it means you won't necessarily have to wait for an API queue or downtime, if your hardware is running, the pipeline can run.
#
# And from a cost standpoint, running on your own hardware often has a heavier starting cost but little to no costs after that.
#
# Performance wise, LLM APIs may still perform better than an open-source model running locally on general tasks but there are more and more examples appearing of smaller, focused models outperforming larger models.

# %% [markdown]
# ## Key terms
#
# | Term | Description |
# | ----- | ----- |
# | **Token** | A sub-word piece of text. For example, "hello, world!" could be split into ["hello", ",", "world", "!"]. A token can be a whole word,<br> part of a word or group of punctuation characters. 1 token ~= 4 characters in English, 100 tokens ~= 75 words.<br> Text gets broken into tokens before being passed to an LLM. |
# | **Embedding** | A learned numerical representation of a piece of data. For example, a sentence of text could be represented by a vector with<br> 768 values. Similar pieces of text (in meaning) will ideally have similar values. |
# | **Embedding model** | A model designed to accept input data and output a numerical representation. For example, a text embedding model may take in 384 <br>tokens of text and turn it into a vector of size 768. An embedding model can and often is different to an LLM model. |
# | **Similarity search/vector search** | Similarity search/vector search aims to find two vectors which are close together in high-demensional space. For example, <br>two pieces of similar text passed through an embedding model should have a high similarity score, whereas two pieces of text about<br> different topics will have a lower similarity score. Common similarity score measures are dot product and cosine similarity. |
# | **Large Language Model (LLM)** | A model which has been trained to numerically represent the patterns in text. A generative LLM will continue a sequence when given a sequence. <br>For example, given a sequence of the text "hello, world!", a genertive LLM may produce "we're going to build a RAG pipeline today!".<br> This generation will be highly dependant on the training data and prompt. |
# | **LLM context window** | The number of tokens a LLM can accept as input. For example, as of March 2024, GPT-4 has a default context window of 32k tokens<br> (about 96 pages of text) but can go up to 128k if needed. A recent open-source LLM from Google, Gemma (March 2024) has a context<br> window of 8,192 tokens (about 24 pages of text). A higher context window means an LLM can accept more relevant information<br> to assist with a query. For example, in a RAG pipeline, if a model has a larger context window, it can accept more reference items<br> from the retrieval system to aid with its generation. |
# | **Prompt** | A common term for describing the input to a generative LLM. The idea of "[prompt engineering](https://en.wikipedia.org/wiki/Prompt_engineering)" is to structure a text-based<br> (or potentially image-based as well) input to a generative LLM in a specific way so that the generated output is ideal. This technique is<br> possible because of a LLMs capacity for in-context learning, as in, it is able to use its representation of language to breakdown <br>the prompt and recognize what a suitable output may be (note: the output of LLMs is probable, so terms like "may output" are used). |

# %% [markdown]
#  ## What we're going to build
#
# We're going to build RAG pipeline which enables us to chat with a PDF document, specifically an open-source [nutrition textbook](https://pressbooks.oer.hawaii.edu/humannutrition2/), ~1200 pages long.
#
# You could call our project NutriChat!
#
# We'll write the code to:
# 1. Open a PDF document (you could use almost any PDF here).
# 2. Format the text of the PDF textbook ready for an embedding model (this process is known as text splitting/chunking).
# 3. Embed all of the chunks of text in the textbook and turn them into numerical representation which we can store for later.
# 4. Build a retrieval system that uses vector search to find relevant chunks of text based on a query.
# 5. Create a prompt that incorporates the retrieved pieces of text.
# 6. Generate an answer to a query based on passages from the textbook.
#
# The above steps can broken down into two major sections:
# 1. Document preprocessing/embedding creation (steps 1-3).
# 2. Search and answer (steps 4-6).
#
# And that's the structure we'll follow.
#
# It's similar to the workflow outlined on the NVIDIA blog which [details a local RAG pipeline](https://developer.nvidia.com/blog/rag-101-demystifying-retrieval-augmented-generation-pipelines/).
#
# <img src="https://github.com/mrdbourke/simple-local-rag/blob/main/images/simple-local-rag-workflow-flowchart.png?raw=true" alt="flowchart of a local RAG workflow" />

# %% [markdown]
# ## Requirements and setup
#
# * Local NVIDIA GPU (I used a NVIDIA RTX 4090 on a Windows 11 machine) or Google Colab with access to a GPU.
# * Environment setup (see [setup details on GitHub](https://github.com/mrdbourke/simple-local-rag/?tab=readme-ov-file#setup)).
# * Data source (for example, a PDF).
# * Internet connection (to download the models, but once you have them, it'll run offline).

# %%
# Perform Google Colab installs (if running in Google Colab)
import os

if "COLAB_GPU" in os.environ:
    print("[INFO] Running in Google Colab, installing requirements.")
    # !pip install -U torch # requires torch 2.1.1+ (for efficient sdpa implementation)
    # !pip install PyMuPDF # for reading PDFs with Python
    # !pip install tqdm # for progress bars
    # !pip install sentence-transformers # for embedding models
    # !pip install accelerate # for quantization model loading
    # !pip install bitsandbytes # for quantizing models (less storage space)
    # !pip install flash-attn --no-build-isolation # for faster attention mechanism = faster LLM inference

# %% [markdown]
# ## 1. Document/Text Processing and Embedding Creation
#
# Ingredients:
# * PDF document of choice.
# * Embedding model of choice.
#
# Steps:
# 1. Import PDF document.
# 2. Process text for embedding (e.g. split into chunks of sentences).
# 3. Embed text chunks with embedding model.
# 4. Save embeddings to file for later use (embeddings will store on file for many years or until you lose your hard drive).

# %% [markdown]
# ### Import Recording Transcription
#
# This will work with many other kinds of recording transcriptions.
#
# But just keep in mind, text files, email chains, support documentation, articles and more can also work.
#
# First we'll read the recording transcriptions.

# %% [markdown]
# Read all the CSV files from the datasource, it contains the transcription data

# %%
# Download PDF file
import pandas as pd
import os

transcriptions_folder_path = r'C:\Users\cesar_0qb0xal\Documents\GitHub\mml_sg_meetings_rag\src\data\meetings_data'

filenames = os.listdir(transcriptions_folder_path)
transcriptions_paths = [filename for filename in filenames if filename.endswith(".csv")]

all_transcriptions_df = pd.DataFrame()
for transcriptions_path in transcriptions_paths:
    print(f"Read the CSV file: {transcriptions_path}")
    transcriptions_df = pd.read_csv(os.path.join(transcriptions_folder_path, transcriptions_path))
    transcriptions_df['Source'] = transcriptions_path
    
    all_transcriptions_df = pd.concat([all_transcriptions_df, transcriptions_df])

all_transcriptions_df
# Out:
# Read the CSV file: MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv
# Read the CSV file: MML-SG Training meeting (2024-02-28 19_14 GMT-5).csv
# Read the CSV file: MML-SG Training meeting (2024-03-06 19_08 GMT-5).csv
# Read the CSV file: MML-SG Training meeting (2024-03-13 19_07 GMT-5).csv
# Read the CSV file: MML-SG Training meeting (2024-04-10 19_11 GMT-5).csv
# Read the CSV file: MML-SG Training meeting (2024-04-17 19_09 GMT-5).csv
# Read the CSV file: MML-SG Training meeting (2024-04-24 19_09 GMT-5).csv
# Read the CSV file: MML-SG Training meeting (2024-05-02 19_09 GMT-5).csv
# Read the CSV file: MML-SG Training meeting (2024-05-08 19_12 GMT-5).csv
# Read the CSV file: MML-SG Training meeting (2024-05-15 19_11 GMT-5).csv
# Read the CSV file: MML-SG Training meeting (2024-05-22 19_34 GMT-5).csv
# Read the CSV file: MML-SG Training meeting (2024-05-29 19_11 GMT-5).csv
# Read the CSV file: MML-SG Training meeting (2024-06-05 19_10 GMT-5).csv
#      Start time  End time Language code  Confidence  Channel  Speaker tag  \
# 0           0.9       8.7         es-us     0.94994      NaN          NaN
# 1          16.4      18.9         es-us     0.77046      NaN          NaN
# 2          21.8      36.7         es-us     0.67797      NaN          NaN
# 3          38.5      41.5         es-us     0.80584      NaN          NaN
# 4          42.8      75.5         es-us     0.96387      NaN          NaN
# ..          ...       ...           ...         ...      ...          ...
# 107      6413.0    6472.2         es-us     0.85210      NaN          NaN
# 108      6473.0    6532.8         es-us         NaN      NaN          NaN
# 109      6533.0    6580.2         es-us         NaN      NaN          NaN
# 110      6593.0    6650.8         es-us     0.86750      NaN          NaN
# 111      6652.9    6701.2         es-us     0.85276      NaN          NaN
#
#                                             Transcript  \
# 0    Lo que hacemos Es compartirles la grabación en...
# 1     Me pueden confirmar cuando la puedan ver, por...
# 2     Sí sí, se puede ver listo amplia, grande. Eso...
# 3          No son simplemente un grupo de estudio, eh?
# 4     Que pues surgió de de uno que existía en Berl...
# ..                                                 ...
# 107  Entonces recuerdan que esa regularización tamb...
# 108  Que Yo calculo al final cuando comparo el prec...
# 109  Que funciona, no, en algunos casos se desea qu...
# 110  Listo no muchachos Muchísimas gracias a ustede...
# 111  Sí, les tiró el pool, Okay o quieren listo, li...
#
#                                                 Source
# 0    MML-SG Training meeting (2024-02-21 19_06 GMT-...
# 1    MML-SG Training meeting (2024-02-21 19_06 GMT-...
# 2    MML-SG Training meeting (2024-02-21 19_06 GMT-...
# 3    MML-SG Training meeting (2024-02-21 19_06 GMT-...
# 4    MML-SG Training meeting (2024-02-21 19_06 GMT-...
# ..                                                 ...
# 107  MML-SG Training meeting (2024-06-05 19_10 GMT-...
# 108  MML-SG Training meeting (2024-06-05 19_10 GMT-...
# 109  MML-SG Training meeting (2024-06-05 19_10 GMT-...
# 110  MML-SG Training meeting (2024-06-05 19_10 GMT-...
# 111  MML-SG Training meeting (2024-06-05 19_10 GMT-...
#
# [1176 rows x 8 columns]

# %%
recording_transcription_data = all_transcriptions_df.to_dict('records')
recording_transcription_data
# Out:
# [{'Start time': 0.9,
#   'End time': 8.7,
#   'Language code': 'es-us',
#   'Confidence': 0.94994,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Lo que hacemos Es compartirles la grabación entonces Déjenme comparto pantalla.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 16.4,
#   'End time': 18.9,
#   'Language code': 'es-us',
#   'Confidence': 0.77046,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Me pueden confirmar cuando la puedan ver, por favor?',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 21.8,
#   'End time': 36.7,
#   'Language code': 'es-us',
#   'Confidence': 0.67797,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Sí sí, se puede ver listo amplia, grande. Eso es, eh? Nada muchachos, Bienvenidos a Machine learning Medellín Machine learning Story Group',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 38.5,
#   'End time': 41.5,
#   'Language code': 'es-us',
#   'Confidence': 0.80584,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' No son simplemente un grupo de estudio, eh?',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 42.8,
#   'End time': 75.5,
#   'Language code': 'es-us',
#   'Confidence': 0.96387,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Que pues surgió de de uno que existía en Berlín en Alemania y pues inspiró este Eh me pareció que tuve la oportunidad el año pasado viajar allá, eh? Lo conocí en primera persona me pareció una idea Genial porque el concepto es casi muy parecido al que van a ver acá es completamente abierto y simplemente para aprender, eh? Esta es la agenda que vamos a tener el día de hoy, va a ser un poco más introductoria respecto a lo que',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 76.4,
#   'End time': 85.4,
#   'Language code': 'es-us',
#   'Confidence': 0.97313,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'A lo que trata el grupo y vamos a dar una introducción un poco a alto nivel de lo que vamos a ver.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 86.7,
#   'End time': 147.2,
#   'Language code': 'es-us',
#   'Confidence': 0.85825,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Y finalmente una una demo o un un primer plano de cómo funcionario un modelo Entonces como pueden ver tenemos es, eh? Acerca del grupo una breve introducción, eh? Porque es buena idea usar Machine learning, Qué tipos de Machine learning learning Vamos a aprender, eh? Configurar el ambiente y desarrollo y una explicación en tuent de de lo que implica un modelo emochiner, eh? Acerca del grupo el propósito como Les acabo de mencionar es aprender diseñar construir proyectos, eh? Hacerlo no solo sino con una comunidad poder aprender de otros, eh? Soy fiel creyente cuando trabajas en equipo y y aprendes de otras personas aprendes mucho más rápido aprendes cosas a una velocidad más rápida y siempre tienes una comunidad que te soporta en momentos de dudas en',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 147.0,
#   'End time': 179.0,
#   'Language code': 'es-us',
#   'Confidence': 0.92522,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Momentos de incluso oportunidades laborales incluso construir cosas proyectos juntos es la idea básicamente, eh? Quién puede participar es completamente gratuito y abierto cualquier persona puede ingresar simplemente se necesita que tenga un conocimiento en programación, eh? Pero la idea es comenzar de sero to Hero desde cero hasta poder manejar un buen nivel de lo que significa Machine learning e',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 181.1,
#   'End time': 236.9,
#   'Language code': 'es-us',
#   'Confidence': 0.83267,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Y eh, para aclarar, eh? El grupo es más cercano a un gimnasio a ir a un gimnasio que a un curso no es tanto como una guía en la que una persona está dictando las pautas, sino es completamente abierto si alguien tiene una idea, si alguien tiene un comentario Si alguien, tiene un Data set, si alguien tiene algo, es completamente abierto que lo comparta a que entre su código que preguntas que incluso esa persona dirija, una sesión es completamente abierto, eh, Y cuando digo que es gimnasio, eh? Es más un entrenamiento diario de de mejorar esta habilidad, en este caso va a ser semanal, pero es un entrenamiento para poder mejorar esta habilidad, eh, Y básicamente se fundamenta en dos en dos frases que me gustan mucho del inglés, que es shoring sc.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 237.6,
#   'End time': 245.4,
#   'Language code': 'es-us',
#   'Confidence': 0.82295,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Básicamente compartir es es cuidar a los demás y tework make the Dreams work.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 245.4,
#   'End time': 305.4,
#   'Language code': 'es-us',
#   'Confidence': 0.82497,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Eh, el trabajo en equipo hace que los sueños funcionen no, no suele pasar que una persona lo pueda hacer todo solo, entonces siempre en comunidad y apoyándose uno llega más lejos Ese es el objetivo de del grupo de machinder e breve introducción al grupo, eh? Como ya se dieron cuenta todo se dieron a través del canal de discord, allí pueden participar comentar compartir entregar cualquier material invitar compañeros, es completamente abierto e sobre el administrador soy yo, eh? De pronto un background de lo que yo he hecho, eh? Llevo yo diría que ya casi 10 años programando comencé con aplicaciones móviles y servidores también, eh? Trabajé en automatización y estoy trabajando actualmente en Machine learning, eh, Me apasiona de todos los temas de programación que he trabajado Este es el que más me ha movido las fibras, me encanta, me encanta, eh?',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 306.0,
#   'End time': 366.0,
#   'Language code': 'es-us',
#   'Confidence': 0.84563,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Tanto así que se dio la oportunidad de abrir este grupo y de participar, eh, De pronto también un poco de introducción de Por qué se diseñó un poco más como un gimnasio que como un curso es Eh Yo también, eh? Fui entrenador de patinaje de velocidad y actualmente soy, eh? Un activo patinador de velocidad el concepto que se tiene allí es parecido al que yo intento transmitir acá en ese grupo que es es en un gimnasio en el que vas a entrenar con tus compañeros Y en vez de crearse como una rivalidad, eh? Cuando esa persona Mejora tu mejoras y así ambos van creciendo Y tienes la guía, que es el entrenador que te va aconsejando, pero también tus compañeros que te van dando feedback de lo que puedes mejorar de Qué cosas. Estás haciendo bien? Estás haciendo mal es una idea muy parecida y obviamente trabajo duro, eh?',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 366.0,
#   'End time': 397.6,
#   'Language code': 'es-us',
#   'Confidence': 0.91708,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Apoyo trabajo duro buena lectura en este caso y ejercicios, eh? Un poco el Bag también porque es un poco más gimnasio que que curso, eh? Las reglas son muy sencillas con respecto a las comunicaciones, eh? Si hay alguna diferencia, simplemente con respeto y pasa usar los canales, eh, Para lo que fueron diseñados que es Eh Pues si es algo de chisme o algo, así podemos crear un canal, pero eh? Digamos, eh, si el canal de pronto solo para comunicaciones, eh?',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 399.5,
#   'End time': 411.4,
#   'Language code': 'es-us',
#   'Confidence': 0.84631,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' No lo sé dataset o algo así puedes usarlo para eso y ya eso es en los únicos reglas y eh finalmente la guía, que vamos a usar es la de la página que se llama Fast a e.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 413.0,
#   'End time': 438.1,
#   'Language code': 'es-us',
#   'Confidence': 0.95896,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Que le haríamos algunos cambios Aunque tampoco La idea, es ligarse como a rajatabla, la guía Sí nosotros decimos que hay otra forma de de aprender o de de entender un tema Simplemente se toma ese camino y ya no hay resistencia en ningún tipo, simplemente se propone se coloca a consideración si se ve que es la mejor opción, pues va para adelante, eh?',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 439.6,
#   'End time': 447.5,
#   'Language code': 'es-us',
#   'Confidence': 0.92174,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Y pues hasta ese momento Tienen alguna duda pregunta comentario o todo va bien él.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 450.5,
#   'End time': 461.3,
#   'Language code': 'es-us',
#   'Confidence': 0.6907,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Sí, por ahora listo, continuamos ahí e Por qué usar Machine learning.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 462.1,
#   'End time': 496.9,
#   'Language code': 'es-us',
#   'Confidence': 0.92573,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Eh, esta pregunta es tan e es tan fácil como difícil de responder, eh? Machine learning. Es el corazón a uno de los corazones que tiene a y creo que todos ahorita vemos el impacto que tiene la tecnología llegó a un nivel de madurez en el que podemos sacar provecho a estos algoritmos que se han estado desarrollando desde hace mucho tiempo, pero por capacidad de Hardware principalmente no se ha podido, eh? Concretar Eh hay hay mucho por hacer y es difícil incluso.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 498.2,
#   'End time': 513.5,
#   'Language code': 'es-us',
#   'Confidence': 0.95878,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Pensar los campos en los que no va a impactar, es más fácil pensar es más difícil decir qué Campos no va a impactar, puedes pensar en medicina en construcción, puedes pensar en negocios, puedes pensar en en deportes?',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 514.5,
#   'End time': 557.0,
#   'Language code': 'es-us',
#   'Confidence': 0.89146,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Va a haber algo? Básicamente si tienes datos e incluso si no ya lo vamos a ver Hay posibilidades de construir un modelo que te sirva para hacer alguna clasificación alguna regresión alguna detección de anomalías algo que de pronto ahorita suena muy aburrido esos términos, pero van a ver que aplicados a veces te dan, eh? Resultados increíbles y incluso ahorita el el Boom que hay ahorita en Machine learning, es referente a las eh, tecnología, tecnologías generativas como puede ser un tío, como puede ser un un stable difusion para generar imágenes que ahorita también le vamos a echar un ojo, Eh entonces.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 558.4,
#   'End time': 561.2,
#   'Language code': 'es-us',
#   'Confidence': 0.95402,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Empezar por el por qué es buena idea usarlo, eh?',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 562.9,
#   'End time': 612.2,
#   'Language code': 'es-us',
#   'Confidence': 0.87155,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Es un buen inicio, entender Por qué es una buena idea y creo que también sirve para que uno se motive a a trabajar en esto e no siempre es el buen inicio, no siempre es como la matemática y todo esto que a veces es muy denso aburrido, sino entender el proyecto que te apasiona como lo puedes potenciar y sin dudas Yo pienso que Machine learning e Inteligencia artificial Está abriendo o está poniendo más lejos, la Barrera de lo que podemos hacer ahorita Hay un montón de cosas para hacer y si hay algún tema que les apasiona estoy, seguro que en algún campo se le puede aplicar Machine learning a nivel de negocio a nivel de incluso recreativo, ya vamos a ver ahorita unos ejemplos bastante buenos del tema, eh?',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 614.0,
#   'End time': 618.7,
#   'Language code': 'es-us',
#   'Confidence': 0.75823,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Qué tipos de Machine learning models, vamos a utilizar, eh?',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 622.2,
#   'End time': 640.7,
#   'Language code': 'es-us',
#   'Confidence': 0.93375,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Vamos a ver principalmente cuatro es el objetivo de del grupo Studio eh? Igual si cualquier persona quiere aportar uno nuevo que no sea muy muy utilizado algo así también es super bienvenido, eh? Pero aquí sí voy a hacer una interacción entre la presentación y',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 642.6,
#   'End time': 646.6,
#   'Language code': 'es-us',
#   'Confidence': 0.89432,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Y lo que lo que lo que me gustaría Mostrar eh.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 647.6,
#   'End time': 670.4,
#   'Language code': 'es-us',
#   'Confidence': 0.91368,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' El primero es supervise learning, los términos los voy a poner en inglés porque así aparecemos que todo en la literatura por lo que es bueno familiarizarse de esa manera, eh? Los modelos de aprendizaje supervisado o supervise learning es una forma en la que tú le puedes enseñar a la máquina, qué tiene que hacer ya dándole la respuestas la imagen lo representa bastante bien, eh? Que sería',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 671.8,
#   'End time': 718.2,
#   'Language code': 'es-us',
#   'Confidence': 0.87814,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Le muestras la imagen de que de que en este momento son manzanas, la máquina se equivoca y tú le haces el feedback de que se está equivocando. Y luego la máquina corrige es la forma en la que tienes las características de la manzana, en este caso es la imagen de la manzana y tienes la respuesta ya hecha que es son manzanas, no son banadas Entonces de esa manera. Él aprende Ajustando la la la el valor, que es correcto con el valor, que él está prediciendo y va Ajustando hasta que ya entrega el valor esperado, yo lo cuando lo intenté entender por primera vez era el comportamiento es muy parecido cuando estás afinando una guitarra que tú tocas la guitarra y suena horrible.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 719.4,
#   'End time': 749.1,
#   'Language code': 'es-us',
#   'Confidence': 0.91601,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Y lo que haces es ajustar un poco, no sé cómo se llaman estas tuerquitas, eh? Pero ajustas para que se tensione vuelves a tonar y otra vez suena horrible Entonces lo vuelves a ajustar, lo ajustas lo ajustas hasta que ya te entregue el resultado esperado en ese caso se llama supervisado porque le estás entregando ya las respuestas y simplemente haces un feedback para que al final se vaya se vaya acomodando a la respuesta correcta, eh? O también otro ejercicio con el que se puede ver es, eh?',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 750.6,
#   'End time': 797.8,
#   'Language code': 'es-us',
#   'Confidence': 0.88295,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Como manejar un carro ponle tú un tesla o simplemente nosotros mismos manejando un carro, eh? Vamos Aprendiendo a a frenar acelerar. Se nos va apagando el carro, pero con el tiempo vamos entendiendo con nuestro guía, que es el que nos va dando las respuestas, qué es lo que tenemos que ir haciendo? Vale, eh, coloco este ejercicio de primeras porque de aquí nació mi mi inspiración para para trabajar en Machine learning y hace unos años. Yo estaba con la ilusión de querer comprar un apartamento. Creo que la mayoría de nosotros lo tenemos y y en mi cabeza, Yo decía Qué chévere, sería poder saber cuál es el apartamento más barato y pues que se acomodan mis necesidades, etcétera, etcétera.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 798.6,
#   'End time': 817.4,
#   'Language code': 'es-us',
#   'Confidence': 0.93938,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Con el que pueda tener Pues que se valorice, Imagínate tú e y de ahí nació la primera idea de del proyecto que es el Data set que les he compartido en el grupo y también he compartido el link en la red laboral, que es el Data set de inmuebles que han estado en venta.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 818.5,
#   'End time': 876.3,
#   'Language code': 'es-us',
#   'Confidence': 0.86604,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Y incluye el precio Este es un ejercicio de aprendizaje supervisado porque conocemos las características del inmueble, pero también conocemos su precio final o el precio en el que está a la venta de esta manera, podemos crear un modelo que prediga los precios de los inmuebles cosa que la próxima vez que tú ya compres o quieras vender un apartamento. Tú puedes ya saber si más o menos en cuánto estaría el precio de ese apartamento, si si se compensa, eh, comprarlo, eh? Se pueden hacer muchas más cosas que ya veremos más adelante, eh? Con ese mismo Data set como una de las cosas más interesantes es este, eh? Detección de anomalías, se llama para poder identificar perfectamente eso dadas las características de todos los apartamentos que hay cuáles son estos raritos que están por debajo del precio normal y esos eso es una de las aplicaciones de anomaly detection que son geniales en este caso porque pues.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 877.4,
#   'End time': 927.4,
#   'Language code': 'es-us',
#   'Confidence': 0.85977,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Esa es la respuesta para poderte encontrar el inmueble que querías que está barato y que tiene las mejores condiciones que tú estás buscando este dato set, eh? Se le puede agregar un montón de cosas más, eh? Supón tú que ahora puedes agregar ubicaciones de valor, puedes pegarse dos comerciales estaciones de policías cárceles, etcétera, etcétera incluso, eh? Las vías de tráfico y tú puedes decir, eh Por ejemplo, eh? Yo soy estudiante y mi universidad queda al norte de la ciudad Entonces cuál es Cuál es el mejor apartamento que me queda a para mis condiciones y dado mi presupuesto, entonces uno podría pensar que siempre uno tiene que durar a zonas lejanas, pero más baratas, pero a veces si compensas lo que gastas en en en transporte y lo sumas de pronto a',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 928.7,
#   'End time': 953.8,
#   'Language code': 'es-us',
#   'Confidence': 0.93647,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' a tu alquiler, tú podrías saber cuál es el mejor lugar para tus condiciones de estudiante o de pronto las condiciones mías son diferentes como ser padre y tengo hijos y necesito que quedes cerca de la escuela de mis hijos para mi trabajo todos esos, eh? Todo ese tipo de problemas que con programación convencional no Se podrían solucionar fácilmente son estándar al alcance de lo que puede hacer ahorita entonces.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 955.4,
#   'End time': 991.3,
#   'Language code': 'es-us',
#   'Confidence': 0.93428,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Eh, si se dan cuenta con el mismo dataset, se pueden hacer un montón de cosas y es es lo que vamos a hacer en este en este grupo E eso sobre el supervisado, eh? Sobre el no supervisado o un supervise learning como pueden ver en la imagen e En qué cambia con el supervisor. Tú conoces las características del evento, pero no sabes la respuesta en este caso Solamente le estamos mostrando al robot o a la máquina, eh? La forma de las Manzanas o de las frutas.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 992.3,
#   'End time': 1044.2,
#   'Language code': 'es-us',
#   'Confidence': 0.8649,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Y él tiene que intuir de alguna manera Cuáles son bananas Cuáles son manzanas, cuáles son peras y lo hace a través de algoritmos que por lo general buscan similitudes, eh? Algo que algunos de de clerización o cosas parecidas y intentándolos agrupar como se pueden dar cuenta aquí en la imagen, eh? Las bananas las las, eh, marco con este marcador como azul en las otras con El Rosado es una forma en la que puede encontrar características, eh? Semejantes sin tener la respuesta clave y para qué podría funcionar esto por ejemplo, eh? Imagínate tú que estás trabajando en una prensa de ciberseguridad y te ponen la tarea Pues de encontrar estos comportamientos raros que pueden existir en la red. Entonces tú podrías e',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1046.1,
#   'End time': 1076.7,
#   'Language code': 'es-us',
#   'Confidence': 0.96713,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Identificar dados las entradas que tienen los usuarios, las navegaciones que tienen cuál se está comportando un rarito. Tú no sabes que está está cometiendo como algún delito o está haciendo algo malo en la pereza, pero está rarito y eso ya te ayuda como a filtrar Entonces es no supervisado porque tú no tienes la respuesta, no sabes, eh? Espero, eh? Sí no sabes no sabes al final, eh?',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1078.7,
#   'End time': 1103.0,
#   'Language code': 'es-us',
#   'Confidence': 0.84991,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Cuál cuál es Cuál es el target, pero dadas las características puedes intuir, eh? Que se comporta de forma rara. Eso es una de las aplicaciones que podría tener anual detection, eh? Eh, el aprendizaje No supervisado e el siguiente que también la idea es verlo, este es uno de los más impresionantes y de los que está pegando más duro ahorita el set supervise learning.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1103.8,
#   'End time': 1107.8,
#   'Language code': 'es-us',
#   'Confidence': 0.98148,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Es una forma en la que la misma máquina o algoritmo fue.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1109.8,
#   'End time': 1144.4,
#   'Language code': 'es-us',
#   'Confidence': 0.92817,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Aprender más allá de lo que sabe a través de modelos generativos, vamos a hacer un ejercicio y creo que de esta manera lo van a entender y ahí se van a responder un poco porque chaji Pit una versión es gratis y otra, no, eh? Lo que están viendo en pantalla, es difusion. Este es un un modelo fundacional que se utiliza para generación de imágenes y básicamente te genera una imagen a través de un prot es como un chpt, pero para imágenes, eh? Con una diferencia que ya vamos a ver cómo funciona el cell supervide. Voy a colocar aquí, eh?',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1147.3,
#   'End time': 1148.6,
#   'Language code': 'es-us',
#   'Confidence': 0.77518,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' motos en Medellín',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1152.8,
#   'End time': 1162.3,
#   'Language code': 'es-us',
#   'Confidence': 0.94901,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Leamos dibujar le podemos escoger que queramos, pero en este caso le vamos a pedir que escoja que nos genere dos imágenes ya les comentaré por qué.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1163.3,
#   'End time': 1167.2,
#   'Language code': 'es-us',
#   'Confidence': 0.94156,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' eh, simplemente con esta con este Pro él va a ser capaz de',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1168.8,
#   'End time': 1176.9,
#   'Language code': 'es-us',
#   'Confidence': 0.93884,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' de de generar dos imágenes le podemos escoger a mano izquierda, Pues los diferentes estilos que queremos que tenga.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1178.3,
#   'End time': 1181.2,
#   'Language code': 'es-us',
#   'Confidence': 0.84515,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Y pues mira aquí generó la primera, esperemos la segunda.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1182.9,
#   'End time': 1187.2,
#   'Language code': 'es-us',
#   'Confidence': 0.85004,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Me haría falta una det para que sea Medellín pero no está mal.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1188.8,
#   'End time': 1191.2,
#   'Language code': 'es-us',
#   'Confidence': 0.50348,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Espera Aquí está, eh?',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1192.5,
#   'End time': 1201.2,
#   'Language code': 'es-us',
#   'Confidence': 0.96246,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' El modelo generativo es capaz de eh, el modelo generativo es capaz de de a partir de',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1202.7,
#   'End time': 1211.6,
#   'Language code': 'es-us',
#   'Confidence': 0.97437,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' cosas que ya sabe generar nuevas salidas en este caso lo que ya sabes que este este modelo fue entrenado con muchas imágenes de motos',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1213.3,
#   'End time': 1217.8,
#   'Language code': 'es-us',
#   'Confidence': 0.75212,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' y el momento en el que funciona el el el cell supervise learning el',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1218.5,
#   'End time': 1277.2,
#   'Language code': 'es-us',
#   'Confidence': 0.76755,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'El entrenamiento autosupervisado es cuando yo escojo una de estas imágenes porque yo al mismo modelo le estoy indicando Cuál es la imagen que acierta más con con la solicitud que yo tenía entonces ahí se genera un feedback en el cual, el modelo genera yo solo utilizándolo valida y va mejorando su su va mejorando su precisión va mejorando su rendimiento porque es un círculo virtuoso el cual me entrega resultados yo valido indirectamente porque yo no estoy siendo alguien que etiqueta, sino simplemente alguien que lo utiliza pero indirectamente etiqueta y él va generando este círculo virtuoso en el cual se va mejorando con el tiempo ahí de ahí viene que saypiti se ha se ha sea gratuito una parte porque cuando alguien lo utiliza y le dice Esto no es lo que yo pedí de alguna manera le estás diciendo al modelo, esa respuesta está mal.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1277.5,
#   'End time': 1305.1,
#   'Language code': 'es-us',
#   'Confidence': 0.92222,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Y cuando muchas personas utilizan gpt y muchas personas le dicen a la misma solicitud que está mal chachipiti, va a corregir en la próxima versión en el próximo entrenamiento, ahí se va generando un un una un un círculo virtuoso se llama, eh? Trabaja mucho con modelos generativos Por lo general se usan redes neuronales para eso también la idea es verlo, eh? Justo en el en el Data set de de finca raíz.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1306.7,
#   'End time': 1310.0,
#   'Language code': 'es-us',
#   'Confidence': 0.9299,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Que tiene todas las propiedades, eh?',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1311.3,
#   'End time': 1338.4,
#   'Language code': 'es-us',
#   'Confidence': 0.97076,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Una de las aplicaciones que se le dio con el modelo generativo es poder saber cuáles son las mejores dimensiones que tiene el inmueble que quiero para que se venda rápido Sí entonces lo que haces es entrenar Este modelo generativo con los que con los que se entrenan, eh, Eh disculpe con información de los Data sets que se entrenan, eh? Que que se han vendido más.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1339.8,
#   'End time': 1379.9,
#   'Language code': 'es-us',
#   'Confidence': 0.92329,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Y a partir de eso te genera otros inmuebles que se parecen o que están en locaciones parecidas para que se vendan rápidamente, eh, listo, eso es sobre el modelo, eh? Autosupervisor Ahora el modelo, eh? Reinfort learning. Básicamente lo que sucede acá es que acá no tienes ni siquiera las características de del Data set y no tienes las respuestas, es decir Estás tú solo contra el mundo y aquí se utilizan otro tipo de algoritmos que en el cual estás trabajando en un ambiente en el cual haces una acción y el ambiente te entrega una reacción uno de los ejemplos en los que podemos ver eso es aquí.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1383.0,
#   'End time': 1388.5,
#   'Language code': 'es-us',
#   'Confidence': 0.9473,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Eh, este es uno de mis favoritos que es están enseñando, básicamente a caminar.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1389.2,
#   'End time': 1390.4,
#   'Language code': 'es-us',
#   'Confidence': 0.97338,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' A este muñequito.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1391.5,
#   'End time': 1434.8,
#   'Language code': 'es-us',
#   'Confidence': 0.90594,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Eh, simplemente es el agente manejando los piecitos y la recompensa se maneja a través de un sistema de recompensa y de castigo, Se podría decir si te caes es un castigo, si tú duras vivo que es básicamente caminar en pie es recompensa y le puedes enseñar un montón de comportamientos diferentes el reto, por ejemplo, aquí más grande es que a través de todos estos obstáculos de lado a lado y si se dan cuenta son superficies completamente irregulares, pero en realidad, nosotros no le estamos diciendo Cuáles son los datos para que aprenda él los va a aprender con las acciones y las recompensas Y eso lo hace a través de muchas iteraciones aquí Déjenme lo coloco de pronto en una velocidad más alta.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1439.6,
#   'End time': 1478.7,
#   'Language code': 'es-us',
#   'Confidence': 0.85159,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Para que vayamos viendo cómo cómo Va progresando con el tiempo se va a caer, va a levantarse, se va a caer, va a levantarse y hasta que finalmente vamos a ver qué hacer capaz de superar los obstáculos. Eso es lo que se podría hacer cor incluso, eh? El algoritmo que utilizaron para poder ganarle a En ajedrez a alguien Utiliza este utiliza un modelo de supervisado que aprendió a jugar ajedrez y entre más perdía, pues más aprendida hasta que al final ninguna persona creo que le ha podido ganar últimamente a ese modelo y si le gana pues al final estás enseñando Cómo cómo ganarte, eh?',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1480.8,
#   'End time': 1482.8,
#   'Language code': 'es-us',
#   'Confidence': 0.96731,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Eso es lo que se puede llegar a hacer, vale?',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1484.2,
#   'End time': 1489.6,
#   'Language code': 'es-us',
#   'Confidence': 0.94486,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Ya más adelante, vamos a ver otra posible, eh? Aplicación que podría tener esta.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1491.3,
#   'End time': 1510.1,
#   'Language code': 'es-us',
#   'Confidence': 0.96863,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Me vuelvo aquí atrás a la presentación, eh? Listo hasta este punto, eh? La idea básicamente es empezar con lo que tú puedes llegar a ser más que empezar como con la matemática dura y pesada, sino qué es lo que yo puedo llegar a construir, qué es lo que puedo, eh, lograr con estos modelos.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1511.3,
#   'End time': 1571.0,
#   'Language code': 'es-us',
#   'Confidence': 0.8261,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Eh, lo digo desde una experiencia personal porque así ha funcionado a través de mi carrera. Siempre me ha dado curiosidad algo y la curiosidad me gana para poder terminarla haciéndolo, eh? La forma en la que empecé con aplicaciones móviles fue así una vez, yo vi cuando salieron estos celulares, eh, geniales con aplicaciones y touch, no sé qué y yo decía Wow Yo quiero aprender a hacer una de esas una de esas aplicaciones e curiosamente mi primera aplicación fue una de citas que se llama wigman, eh? Pero creo que es importante empezar con eso con esa con ese proyecto que tienes en la cabeza que te llamaría la atención que dices, ey, esto se ve muy interesante y a partir de ahí empezar a jalar la pita para poder construir modelos muy bacanos, eh, Y ya la parte verán que la parte de estadística y la parte de matemática que sí que la vamos a ver no va a ser tan dolorosa porque ya le encuentras un por qué ya le encuentras un Stone sí me sirve para algo. Lo digo porque en la universidad odiaba estadística.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1571.0,
#   'End time': 1585.4,
#   'Language code': 'es-us',
#   'Confidence': 0.94888,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Y ahorita me encanta por lo que puede llegar a a significar en en en la aplicación, eh? Listo lo siguiente que me gustaría mostrarles es, eh, el ID que vamos a utilizar.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1587.4,
#   'End time': 1601.6,
#   'Language code': 'es-us',
#   'Confidence': 0.86449,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Eh, yo lo recomiendo que hay más, eh? Visual Studio code con la extensión que es de jpiter, eh? Es básicamente te permite utilizar notebooks Déjenme Aquí les muestro un poco de que se trata.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1613.9,
#   'End time': 1622.3,
#   'Language code': 'es-us',
#   'Confidence': 0.86984,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' que yo tengo aquí solo estoy a la mano y de esta manera, pues pueden ver cómo funcionan Notebook y por ejemplo, qué se diferencia con respecto a',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1624.4,
#   'End time': 1627.1,
#   'Language code': 'es-us',
#   'Confidence': 0.83734,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' a un Script normal que podríamos testear.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1635.9,
#   'End time': 1662.5,
#   'Language code': 'es-us',
#   'Confidence': 0.92544,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Aquí se debería bueno Esto es un Notebook en el cual una explicación No tan técnica es tienes celdas las cuales vas escribiendo código, pero es capaz de visualizar, eh? O hacer pausas en ese código y es más amable Al momento de visualizar datos es importante porque lo que nosotros vamos a utilizar mucho Machine learning, no está todas esos programas son convencionales de hecho, te demoras más pensando la idea que programando.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1663.9,
#   'End time': 1705.6,
#   'Language code': 'es-us',
#   'Confidence': 0.89256,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' En la experiencia, pero lo que puedes hacer acá es testear, secciones e ir verificando datos, por ejemplo, lo que pueden ver en pantalla, tengo esta parte que es simplemente borré una columna y aquí muestra otra vez el Data set, o sea, sin esa columna hago una transformación y luego lo que me muestra es la la el resultado de la transformación, eh? Incluso puedo también ver, eh? Los algoritmos de Machine learning que podría estar utilizando Esto es para poder, eh? Quitar las anomalías, que vamos a ver después, por ejemplo, si puede hacer otra visualización esta fueron partes de las pruebas que se hicieron para el dataset que tienen raíz, eh?',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1711.9,
#   'End time': 1771.1,
#   'Language code': 'es-us',
#   'Confidence': 0.76266,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Prefieren otro, eh, No hay ningún problema e ahora un poco de manos a la obra con con el primer modelo, eh, Solo mostrarles un poco a lo que sería un ent Ah pero antes una una falla media también además de el ID que sería visual Studio code, eh? Recomendaría usar, eh? Esta librería skiller e tiene varios algoritmos de de Machine learning, es cuando ya sabes qué significa cada uno de los algoritmos es bastante fácil de utilizar, hay que aprenderlos eso es lo que desearíamos hacer acá en este en este grupo de estudio También tenemos tensor Flow este está más enfocado a redes neuronales, que es el Deep lo que se conoce como Deep Y actualmente es lo que ha presentado mejores resultados para problemas complejos tanto, así que no se entiende cómo funciona para resolver problemas tan complejos, eh?',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1772.0,
#   'End time': 1799.1,
#   'Language code': 'es-us',
#   'Confidence': 0.93297,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Que también aprenderíamos a Cómo desarrollar estas redes neuronales para hacer regresiones clasificaciones, eh? Modelos generativos, eh, autores, que ya veremos qué significa más adelante y finalmente para visualización recomiendo esto simplemente, simplemente es para mostrar gráficas de distribuciones o cosas así Que también será necesario para poder, eh?',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1801.0,
#   'End time': 1806.4,
#   'Language code': 'es-us',
#   'Confidence': 0.94846,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Tomar decisiones técnicas Al momento de resolver un problema, eh listo?',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1808.9,
#   'End time': 1812.1,
#   'Language code': 'es-us',
#   'Confidence': 0.85594,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Eh, Ahora manos a la obra con lo que sería.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1813.4,
#   'End time': 1857.7,
#   'Language code': 'es-us',
#   'Confidence': 0.92667,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Con lo que sería un proyecto Machine learning, eh? Podemos dividirlo en cuatro etapas, eh? La primera es la conexión de la información literalmente aquí la información es el nuevo oro digital. Yo estoy absolutamente convencido de eso la persona que se que pueda capturar datos, eh? Tiene ya alguien que se los compre incluso, eh, En este diagrama que pueden ver en la parte superior se ven los actores que vienen siendo personas que están recolectando datos, etcétera, etcétera En la mitad van a ver, eh? Las diferentes herramientas que se pueden utilizar para hacer recolección de datos Y en la parte de abajo se puede ver en',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1859.1,
#   'End time': 1876.7,
#   'Language code': 'es-us',
#   'Confidence': 0.93738,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Eh, los servicios que se podrían entregar, eh? Un desde el primer paso en la colección de datos, ya se podría vender si tú estás interesado en un negocio o algo así se podría vender el mismo, eh? Scrapy o el mismo modelo automático que va a capturar esa información desde la Fuente',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1878.5,
#   'End time': 1936.8,
#   'Language code': 'es-us',
#   'Confidence': 0.78919,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'O se podría ya vender, eh? La información recolectada en el siguiente paso está en las analíticas Este es el paso previo a a realizar un modelo de Machine learning de hecho es Es uno que tiene que estar bien fundamentado, que es, ya tienes la la información capturada. Ya conoces la calidad de los datos y eres capaz de identificar ciertos insites que te pueden entregar como las ventas que he tenido en la empresa o por con el Dr de las de finca raíz, eh, Cuáles son las áreas que mejor presentan comportamiento de crecimiento, si los procesos son aumentaban decrecidos y las tendencias de las áreas han bajado han crecido etcétera, etcétera tener esa información es Clara para poder construir el modelo porque a partir de eso puedes tomar la decisión de Qué se puede hacer siguiente paso construye el modelo en este caso, eh? Hacer el modelo de anomalía de detecciones para identificar, cuál es el inmueble que más te sirve para comprar e',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1937.1,
#   'End time': 1980.4,
#   'Language code': 'es-us',
#   'Confidence': 0.86206,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Puedes vender el modelo también, eh, Y al final se el diploiment que es también puedes vender el consumo del móvil que es lo que hace, básicamente ellos no nos van a vender el modelo. Además que es muy pesado y grande y se necesitaría un buen computador para atenderlo Pero lo que sí van a hacer es venderte acceso venderte el acceso al modelo Esa es la el pib que se necesitaría a muy grandes rasgos, eso también se los puedo compartir, eh, Si desea e ya pasando para las últimas partes del de la presentación para ya dejar de de hacerla tan larga la idea no es que en todas, eh? Nos quedemos hablando sino también ya hagamos manos a la obra y algo más Dinámico eh.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1981.9,
#   'End time': 1984.0,
#   'Language code': 'es-us',
#   'Confidence': 0.81921,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Machine learning y ética, eh',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1985.7,
#   'End time': 1994.8,
#   'Language code': 'es-us',
#   'Confidence': 0.86418,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Si hay chicos acá que son de neostella que sí que habían varios, eh? Yo una vez tuve una conversación con mi mentor que uno de mis mentores que es Felipe',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 1996.0,
#   'End time': 2002.2,
#   'Language code': 'es-us',
#   'Confidence': 0.9008,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Johnny intenta explicar a él una vez que entiendes Cómo funcionan los modelos y lo de lo que son capaces.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 2003.6,
#   'End time': 2004.2,
#   'Language code': 'es-us',
#   'Confidence': 0.78181,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' lo',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 2006.2,
#   'End time': 2029.4,
#   'Language code': 'es-us',
#   'Confidence': 0.94095,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'El alcance que tiene es increíble, es increíble, eh? Las capacidades que en las que cuales iguales supera el Humano son muchas más de lo que la gente cree y yo lo he intentado explicar a él, yo siento que vino una ola que la gente no no ve venir no ve venir y',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 2031.0,
#   'End time': 2039.5,
#   'Language code': 'es-us',
#   'Confidence': 0.89263,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' puede llegar a ahí, ya le explicaba él, yo me siento como estas personas del gorrito que van con conspiraciones, pero yo le expliqué.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 2040.6,
#   'End time': 2066.1,
#   'Language code': 'es-us',
#   'Confidence': 0.97553,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Puede que llegue una un momento en el que un joven que tiene todas las capacidades para trabajar intenta buscar trabajo, pero no lo va a encontrar, o sea, tiene que tener otras habilidades completamente especiales o diferentes o incluso áreas en las que preferimos los humanos, el el contacto humano como ir al doctor o algo así o un restaurante Pero hay muchas tareas en las cuales la Inteligencia artificial va a ser mejor.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 2067.5,
#   'End time': 2098.9,
#   'Language code': 'es-us',
#   'Confidence': 0.94048,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Eh, esta parte cuestiona un poco la parte ética y las personas que ven en pantalla son dos personas que admiro mucho izquierda, eh? Robero penheimer. Creo que todos sabemos Quién es por la película de openheimer la escena en la que él me recuerda mucho el uso de la ética es recuerdan cuando por fin se enteran que si es posible hacer la bomba atómica porque descubren que con agua pesada algo así sí se podía hacer la división de de los átomos.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 2101.1,
#   'End time': 2133.6,
#   'Language code': 'es-us',
#   'Confidence': 0.93742,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' Y en ese momento él da dos ideas la primera es podemos crear energía o podemos crear una bomba y es como Wow eh? El problema no es la herramienta el problema es como la usas y a mano derecha Alan torin, que es también otro personaje que admiro mucho él básicamente el padre de la computación y en una escena en en la película que se llama código Enigma eh, él descubre con sus compañeros el código Enigma Cómo resolver el código Enigma que era el código de encriptación que usan los nazis.',
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv'},
#  {'Start time': 2134.9,
#   'End time': 2147.5,
#   'Language code': 'es-us',
#   'Confidence': 0.9423,
#   'Channel': nan,
#   'Speaker tag': nan,
# ...
#   'Source': 'MML-SG Training meeting (2024-05-29 19_11 GMT-5).csv'},
#  {'Start time': 1961.9,
#   'End time': 2021.7,
#   'Language code': 'es-us',
#   'Confidence': 0.76345,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Sí en el training y que en el de validación está funcionando significativamente peor Entonces se comparan esos dos datos de hecho se compara acá, eh? Que no superé el 10% del valor a que se se hace esa evaluación, si llega a superar al 10% pues ahí ya sugiere que hay un lobo perfil entonces, eh? Se hace la versión acá y finalmente se saca otra métrica, que es el el mean absolute, error, que si la resumimos esas dos son mse en tamaño en sesiones, anteriores que eran si recuerdan era el maes el Absolut el el MS es el que viene con la exponencial es más sensible a los errores, listo Entonces como resultado acá es donde empiezan a brillar los ojos.',
#   'Source': 'MML-SG Training meeting (2024-05-29 19_11 GMT-5).csv'},
#  {'Start time': 2022.0,
#   'End time': 2081.9,
#   'Language code': 'es-us',
#   'Confidence': 0.82654,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Porque por acá se arman en un json y Se imprime y el resultado utilizando el Random Forest que es el más básico era de 0.90 a veces salta 91 a veces se quedan 90 porque Recuerden que aquí el factor Random a veces afecta el factor aleatorio de los datos que estoy cogiendo, pero este r. Cuadrado fue bastante chévere verlo solamente para el más básico que es este es el Random Ford es el más sencillo, eh? Tenemos el MC que es este valor el mma, que es este valor ahora con el MC podemos hacer algo adicional que es sacar la raíz cuadrada y eso me va a sumar más o menos me va a decir qué tanta varianza hay en los datos que predice el modelo. Entonces saquemos calculadora también lo podemos hacer de forma programática nos lo dice, creo que por tiempo y les acabó la raíz.',
#   'Source': 'MML-SG Training meeting (2024-05-29 19_11 GMT-5).csv'},
#  {'Start time': 2081.9,
#   'End time': 2141.2,
#   'Language code': 'es-us',
#   'Confidence': 0.8322,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'A esto entonces aquí me está diciendo Mira más o menos en varianza, tenemos $7000 es decir si el modelo a mí me predice que el carro vale 20,000 estaría en un Rango entre 13000 y 27000 sí, porque eso sería la varianza que podría tener en promedio con los valores predichos que en algunos casos va a ser menos en algunos casos va a ser más la diferencia Sí pero es un buen acercamiento, digamos y adicionalmente esto está generando al final los archivos ya predichos tanto de validación como para entrenamiento como para echarle un ojo, a cómo se vería ya ese precio ese precio predicho que yo creo que vendría siendo la última columna A ver, vamos Sí mira acá están las dos una es como verdecita. La otra un verdecito más más encendido veamos cómo se ve acá los precios Entonces por ejemplo acá.',
#   'Source': 'MML-SG Training meeting (2024-05-29 19_11 GMT-5).csv'},
#  {'Start time': 2141.9,
#   'End time': 2201.6,
#   'Language code': 'es-us',
#   'Confidence': 0.73522,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': '23.000 Este es el, eh, Ah al parecer Este es el real Sí este que es el real 23,000, Sí señor, sí señor mira 23.151 y aquí 25000 no es que no es un mal güey sí y así pueden ver varios que en algunos casos Habrá más diferencias que nosotros sí Pero entre más cercanos estemos a el r. Cuadrado = -1 vamos a tener mejor performance y entre más pequeño sea el rmc, vamos a tener mejor performance entonces acá por ejemplo, si se dan cuenta, estamos viendo diferencias de $1000 que no está mal o sea es es un es yo la verdad no sabía que iba a funcionar también se los juro yo dije pues va a funcionar Pero mira Funciona muy bien, entonces acá tenemos, por ejemplo 11.000 y acá tenemos elementos acá ya son $4000 más o menos.',
#   'Source': 'MML-SG Training meeting (2024-05-29 19_11 GMT-5).csv'},
#  {'Start time': 2201.9,
#   'End time': 2261.6,
#   'Language code': 'es-us',
#   'Confidence': 0.78408,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Entonces en algunos funcionará mejor a otros peor Pero tengan en cuenta que este es el más básico, eso es como lo que lo que me gustaría que tuvieran en cuenta, este es el el Random Forest pelado Este es el que casi no, pues no tiene mucha mucha sorpresa lo que podría entregar. Entonces aquí es donde uno también se va al PayPal otra vez, Uh entonces acá intentamos correr el de Cat Bruce ahora miramos cómo nos va Y acá es donde uno empieza a ver las diferencias el campus va a ser mejor porque da la naturaleza de cómo funciona que, eh? Si sé si se acuerdan, yo les explicaba que es como un Random Ford es evolucionado, que lo que hace es como un estilo Naruto que va arreglando los los errores que va teniendo sobre la marcha y entrega un un modelo más fino se demora más en entrenarse, se necesita más tiempo y más recursos, pero me va a entregar un mejor performance, va a entregar un mejor.',
#   'Source': 'MML-SG Training meeting (2024-05-29 19_11 GMT-5).csv'},
#  {'Start time': 2261.9,
#   'End time': 2320.9,
#   'Language code': 'es-us',
#   'Confidence': 0.78853,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Comportamiento Entonces es eso lo que haría el cactus el cactus funciona Exactamente igual diferencias los hiperparametros cambian porque es otro algoritmo tiene otra naturaleza. Estamos usando de que el el mismo optimizador yo quería utilizar otro optimizador pero no como les comentaba el de Rodrigo que es el de él de iPad no tenía una versión vieja de de una librería y pues no me da tiempo a arreglarlo ni nada es y acá el resultado es igual También se hace la validación de validation por asegurarse de que no está teniendo ningún problema de work fire y estar seguros y trabajar con con los parámetros pero nada más O sea el resultado inicial nada más, eh? Lo voy a bajar corriendo. Esperemos a ver qué resulta sí resulta que ya vi que esto va a tirarlo en roble Pero al menos va a tirar error aquí al momento de imprimir.',
#   'Source': 'MML-SG Training meeting (2024-05-29 19_11 GMT-5).csv'},
#  {'Start time': 2321.9,
#   'End time': 2381.6,
#   'Language code': 'es-us',
#   'Confidence': 0.75178,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Pues ahora ya que vi el error y como no lleva tanto tiempo haremos y tiré bola otra vez Entonces bacano, a ver que funcione, o sea, lo que pasa es bacano Es que esto es un ejercicio real. O sea, estos esos datos reales no es un dato de libro, no? Y todas las transformaciones que hicimos parece que tienen sentido. Parece que sí es algo que el modelo puede identificar y y sacar o sea, magnífico en mi opinión magnífico Entonces ya para para cerrar y empezar a echar un ojo al testing y saltar a la parte de la red neuronal, hay algo más que se puede utilizar para poder evaluar, el performance de estos modelos que es algo llamado residuales que básicamente los residuales es un plot que se hace A partir de la diferencia que se tiene del valor real y el valor predicho Entonces por ejemplo para otra.',
#   'Source': 'MML-SG Training meeting (2024-05-29 19_11 GMT-5).csv'},
#  {'Start time': 2382.0,
#   'End time': 2441.8,
#   'Language code': 'es-us',
#   'Confidence': 0.82433,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'El el ejemplo con los datos que estamos viendo hace un momento Es como si yo cogiera aquí en este en esta tabla y por cada una de las filas yo digo, voy a restar este - este eso me va a dar un residuo va a restar este menos este voy a restar este - este para restar este y así es cierto. Ta ta ta hago la resta de cada uno de ellos, como resultado aquí se alcanza, a ver, yo creo que este nos va a ayudar bastante a entender cómo funciona se carga Sí por ejemplo hay otro plot que también es útil, pero no están de 7, cómo lo recibo, que es yo ploteo el valor que predice versus el valor real Sí eso cómo debería deberían ser idealmente el mismo valor es decir acá Tiene que ser si son $5000 acá son $5000 y así con todos los datos en el caso ideal.',
#   'Source': 'MML-SG Training meeting (2024-05-29 19_11 GMT-5).csv'},
#  {'Start time': 2442.0,
#   'End time': 2501.5,
#   'Language code': 'es-us',
#   'Confidence': 0.78591,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Y hacer una línea de 45 grados llena de pepitas como más o menos se ve así que todas estén muy cerquita, esa línea de 45 grados, Porque si el valor real es 35,000 el modelo debería predecir 35,000 Entonces el punto siempre tiene que estar sobresalir esa es muy deficiente para el bien de negocio alguien de negocio le sirve mucho ver como Ah mira aquí es porque hay casos en los que por ejemplo Funciona muy bien para los casos pequeños, supongamos que todos los carros por debajo de $40,000 funcionan bien y funciona Perfecto esa esa línea pero a partir de los 45 y para arriba se empieza a ver que la diferencia es más grande es decir que hay hay más descaches hay más descaches al momento de de de predecir El el valor O sea que acá son $50,000 Pero él él lo predijo 35,000. Eso podría ser un descache muy grande y se puede encontrar con ese con ese gráfico, pero otro gráfico que es más diciente es',
#   'Source': 'MML-SG Training meeting (2024-05-29 19_11 GMT-5).csv'},
#  {'Start time': 2502.0,
#   'End time': 2561.9,
#   'Language code': 'es-us',
#   'Confidence': 0.7734,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Que es el que se ve aquí en pantalla de hecho ambos están relacionados como pueden ver que es cálculo los residuales y luego esa columna nueva que tengo de residuales la ploteo con otra que son de los valores que de los valores que predije entonces se dan cuenta Acá tengo valores, que siempre dijo en la parte, eh? En el eje x y residuales sí, en en y si se dan cuenta, hay una línea punteada que está sobre cero a ver si podemos ampliar Esto sí hay una línea punteada que está sobre 0 que esa sería en dónde deberían estar todos los residuales, Porque si todos los residuales están en la línea 0 significa que la diferencia entre el valor predicho y el valor real es cero Entonces sería casi perfecta Esa esa relación, pero te dicen algunos casos. Voy a ver que está por encima está por debajo, Eh sí, pero idealmente que estén cerca y acá se pueden hacer incluso análisis más más.',
#   'Source': 'MML-SG Training meeting (2024-05-29 19_11 GMT-5).csv'},
#  {'Start time': 2561.9,
#   'End time': 2621.8,
#   'Language code': 'es-us',
#   'Confidence': 0.79432,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Profundos en esta documentación ellos indican por ejemplo que un resultado bastante bueno es algo como esto donde se tienen que todos están alrededor de cero Y de pronto no están tan descacha para arriba y para abajo no alcanzan a ver tantas anomalías en precios no se escacha tanto Al momento de hacer esos precios, eh? Eh, de calcular esos precios pero en algunos casos se presentan comportamientos como este que ya se empiezan a ver por ejemplo, este está es como una curva que aparece acá y por aquí está el eje 0 por aquí indica que hay unos layer, por ejemplo, aquí se tiene este que es cero y todos están aquí pegaditos, pero por aquí tengo un desgraciado que me salió mal defecto acá por eso entonces aquí no empieza a decir quizás tengo que limpiar mejor Mis datos, Porque estoy teniendo un error con unos Life unos líder. Me está arruinando, Pues el el entrenamiento y y no me está gustando suficientemente bien. Entonces este podría ser algo que se borre.',
#   'Source': 'MML-SG Training meeting (2024-05-29 19_11 GMT-5).csv'},
#  {'Start time': 2621.9,
#   'End time': 2681.5,
#   'Language code': 'es-us',
#   'Confidence': 0.84137,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Hay uno que es muy curioso es y de hecho sugieren en la documentación que es algo muy común, que es, eh? Está, se llama estereotipo, este de acá que dice básicamente que para valores pequeños el modelo puede que lo haga bien, pero para valores grandes puede que empiece a ver más variación y más descaches em, en algunos predicciones, eso podría, eh? Encontrarse Y eso podría sugerir que para valores grandes en la predicción hay información perdida, entonces también el cono podría ir en esta dirección o el cono podría ir en otro en en la dirección puesta en la que para valores altos Funciona muy bien para para valores pequeños se descansa, ahí también podría sugerir de pronto. Hay algo más que se está perdiendo en lo en las predicciones de datos pequeños. Entonces uno ya empieza a echarle ojo como a qué podría estar fallando.',
#   'Source': 'MML-SG Training meeting (2024-05-29 19_11 GMT-5).csv'},
#  {'Start time': 2681.9,
#   'End time': 2741.8,
#   'Language code': 'es-us',
#   'Confidence': nan,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'E intenta ajustar acá Incluso en esta argumentación, Pues sugieren que se puede hacer final por acá, te dicen como que Cómo se arreglan entonces acá pueden que sea una transformación o que sea limpiar los datos, por ejemplo, también te lo dicen en los layers acá seguramente te dice que es borrar los sublimes o evitar que el modelo sea sensible a los usuarios, esa puede ser otra opción. Entonces esa es la idea como el último análisis que se puede hacer de para verificar que el modelo está funcionando bien, sí que tiene que no tiene un sesgo al presente y nada aquí como ven en pantalla, se toma mucho más mucho más tiempo lastimosamente, por ejemplo, el de auto Mel que es el que yo creo que va a entregar más resultados ese todavía no lo puede entrenar. Lo dejé como unas 3 horas, esta mañana, pero después tenía que usar mi computador y me tocó desbloquear porque básicamente el otro, eh? El coge mi cpu y',
#   'Source': 'MML-SG Training meeting (2024-05-29 19_11 GMT-5).csv'},
#  {'Start time': 2742.0,
#   'End time': 2801.5,
#   'Language code': 'es-us',
#   'Confidence': 0.80277,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Estalla 100% de hecho miren que esté aquí está dándole dándole guerra de hecho, no sé cómo estoy reventado todavía porque mira que el catbus está usando la cpu A toda máquina Entonces ahí es donde uno. Mira Qué recursos, tengo cuánto me demoro en entrenarlo, por ejemplo, hay un modelo, eh? En la empresa que estamos haciendo el hijo de madre se demora yo le estoy calculando como unas 3 semanas mínimo en entrenarse como yo lo enseñé y pues no, qué me tocó hacer? Era inviable porque el entrenamiento no se puede durar tanto, qué me tocó hacer bajar la complejidad del vuelo y era una red neuronal, entonces me tocó quitarle capas y quitarle neuronas y perdía precisión, pero ganaba velocidad en el entrenamiento mientras ellos me disponían un recurso más potente porque estoy usando también la máquina del de de la empresa y pues ahí es donde las gpus tienen.',
#   'Source': 'MML-SG Training meeting (2024-05-29 19_11 GMT-5).csv'},
#  {'Start time': 2802.0,
#   'End time': 2860.4,
#   'Language code': 'es-us',
#   'Confidence': 0.65974,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Porque ella sí te van a permitir Pues segmentar de forma paralela, estas operaciones y hacer un entrenamiento mucho más rápido y ahí vamos, Qué les parece, hay personas que Perdón cómo lo vieron. Ahí dudas preguntas no Recuerden que silencio es esta No pero en realidad, eh? Y también eso tiene sentido que el otro se mueve tanto Pues porque está consumiendo mucho y mucho más recursos ese auto ML lo que haces te busca la prueba con varios algoritmos y al final elige Cuál es el mejor el de mejor rendimiento y ese es el que propone pues sugiere cierto.',
#   'Source': 'MML-SG Training meeting (2024-05-29 19_11 GMT-5).csv'},
#  ...]

# %% [markdown]
# Recording Transcription acquired!
#
# We'll write a small helper function to preprocess the text as it gets read. Note that not all text will be read in the same so keep this in mind for when you prepare your text.
#
# We'll save each transcription sequence to a dictionary and then append that dictionary to a list for ease of use later.

# %%
# Requires !pip install PyMuPDF, see: https://github.com/pymupdf/pymupdf
from tqdm.auto import tqdm  # for progress bars, requires !pip install tqdm 


def text_formatter(recording_text: str) -> str:
    # Remove crutches when speaking
    recording_text = recording_text.replace('eh?', '.').replace('eh', '.')
    return recording_text


for record in tqdm(recording_transcription_data):
    record['Transcript'] = text_formatter(record['Transcript'])

recording_transcription_data[0]['Transcript']
# Out:
#   0%|          | 0/1176 [00:00<?, ?it/s]
# 'Lo que hacemos Es compartirles la grabación entonces Déjenme comparto pantalla.'

# %% [markdown]
# Now let's get a random sample of the pages.

# %%
import random

random.sample(recording_transcription_data, k=3)
# Out:
# [{'Start time': 2516.9,
#   'End time': 2576.2,
#   'Language code': 'es-us',
#   'Confidence': 0.80746,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'El mate que también es como una escala de de colores que te dice que tanto soy perdidos y acá te entrega. Un ejemplo Esta es la tabla que que estaremos viendo, por ejemplo. Mira esta está toda vacía local son es la que tiene 100% vacíos tiene sentido y así entonces uno empieza a hacer Estos tipos de ejercicios para entender entender qué es lo que Qué es la información que tiene y si los datos Tienen buena calidad que era el documento que está en en resources en el en el grupo hay un documento que se llama Déjenme Les comparto solo para otra vez tenerla ahí presente, no resortes es este de acá de m3 Ah no esté sixte dimensions, es muy sencillo de entender, es muy sencillo de leer, Eh mi opinión y te explica más o menos, Qué significa que hayan datos de buena calidad.',
#   'Source': 'MML-SG Training meeting (2024-04-17 19_09 GMT-5).csv'},
#  {'Start time': 418.9,
#   'End time': 478.8,
#   'Language code': 'es-us',
#   'Confidence': nan,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Ya estamos usando la librería que se llama pycaret Y esto es lo que hace es tiene algunas secuencias de preparación de datos, . Te van a realizar este manejo o Esta preparación de datos en algún en algunos en algunos casos, Perdón todos, porque como les comentaba en sesiones pasadas también no tiene el contexto del problema, que es por ejemplo Supongo que uno de los textos originales de una de las columnas de del dataset que estamos usando en vez de tener un número que hace referencia a leid, tiene un texto que te dice como un año o de 1 a 8 años o de 8 años a 16 años y son textos Entonces si lo leemos como textos son categorías y esas categorías en teoría no se podrían ordenar pero si lo',
#   'Source': 'MML-SG Training meeting (2024-04-10 19_11 GMT-5).csv'},
#  {'Start time': 3453.9,
#   'End time': 3513.9,
#   'Language code': 'es-us',
#   'Confidence': nan,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'Línea como lo lo fue el polinómico y cómo lo es en este momento el regresivo pueden operar en muchas dimensiones no solamente en dos, como lo hemos visto, sino, por ejemplo acá se puede ver, . Este es el logaritmo pero en un plano 3D sí es decir algo que todavía podemos interpretar pero si se dan cuenta en la en la parte superior están los puntos las líneas punteadas que ven que contacta con el plano viene siendo los errores, entonces La idea es coger el error mínimo posible, por eso es que hace ese ajuste porque dice este es el punto en el que encuentran menor error entre todos los puntos que hay en el Data set que también para aclarar el término de sustancias instancias, . Y que me entregan la la salida desea La idea, es encontrar ese punto más bajo, pero para que entiendan Puede que haya una regresión lineal que funciona en 10 dimensiones y es Igualmente válida como Puede que haya una polinómica.',
#   'Source': 'MML-SG Training meeting (2024-03-06 19_08 GMT-5).csv'}]

# %% [markdown]
# ### Get some stats on the text
#
# Let's perform a rough exploratory data analysis (EDA) to get an idea of the size of the texts (e.g. character counts, word counts etc) we're working with.
#
# The different sizes of texts will be a good indicator into how we should split our texts.
#
# Many embedding models have limits on the size of texts they can ingest, for example, the [`sentence-transformers`](https://www.sbert.net/docs/pretrained_models.html) model [`all-mpnet-base-v2`](https://huggingface.co/sentence-transformers/all-mpnet-base-v2) has an input size of 384 tokens.
#
# This means that the model has been trained in ingest and turn into embeddings texts with 384 tokens (1 token ~= 4 characters ~= 0.75 words).
#
# Texts over 384 tokens which are encoded by this model will be auotmatically reduced to 384 tokens in length, potentially losing some information.
#
# We'll discuss this more in the embedding section.
#
# For now, let's turn our list of dictionaries into a DataFrame and explore it.

# %%
import pandas as pd

df = pd.DataFrame(recording_transcription_data)
df.head()
# Out:
#    Start time  End time Language code  Confidence  Channel  Speaker tag  \
# 0         0.9       8.7         es-us     0.94994      NaN          NaN
# 1        16.4      18.9         es-us     0.77046      NaN          NaN
# 2        21.8      36.7         es-us     0.67797      NaN          NaN
# 3        38.5      41.5         es-us     0.80584      NaN          NaN
# 4        42.8      75.5         es-us     0.96387      NaN          NaN
#
#                                           Transcript  \
# 0  Lo que hacemos Es compartirles la grabación en...
# 1   Me pueden confirmar cuando la puedan ver, por...
# 2   Sí sí, se puede ver listo amplia, grande. Eso...
# 3          No son simplemente un grupo de estudio, .
# 4   Que pues surgió de de uno que existía en Berl...
#
#                                               Source
# 0  MML-SG Training meeting (2024-02-21 19_06 GMT-...
# 1  MML-SG Training meeting (2024-02-21 19_06 GMT-...
# 2  MML-SG Training meeting (2024-02-21 19_06 GMT-...
# 3  MML-SG Training meeting (2024-02-21 19_06 GMT-...
# 4  MML-SG Training meeting (2024-02-21 19_06 GMT-...

# %%
# Get stats
df.describe().round(2)
# Out:
#        Start time  End time  Confidence  Channel  Speaker tag
# count     1176.00   1176.00      911.00      0.0          0.0
# mean      2525.43   2579.29        0.81      NaN          NaN
# std       1595.14   1596.64        0.07      NaN          NaN
# min          0.00      8.70        0.33      NaN          NaN
# 25%       1198.00   1257.57        0.77      NaN          NaN
# 50%       2396.90   2456.55        0.81      NaN          NaN
# 75%       3659.42   3719.32        0.85      NaN          NaN
# max       6652.90   6701.20        0.98      NaN          NaN

# %% [markdown]
# Okay, looks like our average token count per page is 287.
#
# For this particular use case, it means we could embed an average whole page with the `all-mpnet-base-v2` model (this model has an input capacity of 384).

# %% [markdown]
# ### Further text processing (splitting pages into sentences)
#
# The ideal way of processing text before embedding it is still an active area of research.
#
# A simple method I've found helpful is to break the text into chunks of sentences.
#
# As in, chunk a page of text into groups of 5, 7, 10 or more sentences (these values are not set in stone and can be explored).
#
# But we want to follow the workflow of:
#
# `Ingest text -> split it into groups/chunks -> embed the groups/chunks -> use the embeddings`
#
# Some options for splitting text into sentences:
#
# 1. Split into sentences with simple rules (e.g. split on ". " with `text = text.split(". ")`, like we did above).
# 2. Split into sentences with a natural language processing (NLP) library such as [spaCy](https://spacy.io/) or [nltk](https://www.nltk.org/).
#
# Why split into sentences?
#
# * Easier to handle than larger pages of text (especially if pages are densely filled with text).
# * Can get specific and find out which group of sentences were used to help within a RAG pipeline.
#
# > **Resource:** See [spaCy install instructions](https://spacy.io/usage).
#
# Let's use spaCy to break our text into sentences since it's likely a bit more robust than just using `text.split(". ")`.

# %%
from spacy.lang.es import Spanish  # see https://spacy.io/usage for install instructions

nlp = Spanish()

# Add a sentencizer pipeline, see https://spacy.io/api/sentencizer/ 
nlp.add_pipe("sentencizer")

# Create a document instance as an example
doc = nlp("Oracion uno. Oracion dos.")
assert len(list(doc.sents)) == 2

# Access the sentences of the document
list(doc.sents)
# Out:
# [Oracion uno., Oracion dos.]

# %% [markdown]
# We don't necessarily need to use spaCy, however, it's an open-source library designed to do NLP tasks like this at scale.
#
# So let's run our small sentencizing pipeline on our pages of text.

# %%
for item in tqdm(recording_transcription_data):
    item["sentences"] = list(nlp(item["Transcript"]).sents)

    # Make sure all sentences are strings
    item["sentences"] = [str(sentence) for sentence in item["sentences"]]

    # Count the sentences 
    item["page_sentence_count_spacy"] = len(item["sentences"])
# Out:
#   0%|          | 0/1176 [00:00<?, ?it/s]

# %%
# Inspect an example
random.sample(recording_transcription_data, k=1)
# Out:
# [{'Start time': 1797.9,
#   'End time': 1855.8,
#   'Language code': 'es-us',
#   'Confidence': nan,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': 'La marca esto el the de la ubicación de este no me interesa Y el nombre tampoco por ahí está. Sí es importante es esta por hora, no? Esto creo que era así era como una versión por ahora dejemos programar como para simplificarlo, pero en el futuro sospecho que lo vamos a necesitar porque me imagino que la versión del mismo carro puede que haga incremente su valor ligeramente Pero puede que tenga que incremente está también lo calzón, esa local son tan al lado. La va a borrar Hasta que estemos seguros que tiene ya ahorita lo miramos bien. El modelo está tampoco me interesa.',
#   'Source': 'MML-SG Training meeting (2024-04-24 19_09 GMT-5).csv',
#   'sentences': ['La marca esto el the de la ubicación de este no me interesa Y el nombre tampoco por ahí está.',
#    'Sí es importante es esta por hora, no?',
#    'Esto creo que era así era como una versión por ahora dejemos programar como para simplificarlo, pero en el futuro sospecho que lo vamos a necesitar porque me imagino que la versión del mismo carro puede que haga incremente su valor ligeramente Pero puede que tenga que incremente está también lo calzón, esa local son tan al lado.',
#    'La va a borrar Hasta que estemos seguros que tiene ya ahorita lo miramos bien.',
#    'El modelo está tampoco me interesa.'],
#   'page_sentence_count_spacy': 5}]

# %% [markdown]
# Wonderful!
#
# Now let's turn out list of dictionaries into a DataFrame and get some stats.

# %%
df = pd.DataFrame(recording_transcription_data)
df.describe().round(2)
# Out:
#        Start time  End time  Confidence  Channel  Speaker tag  \
# count     1176.00   1176.00      911.00      0.0          0.0
# mean      2525.43   2579.29        0.81      NaN          NaN
# std       1595.14   1596.64        0.07      NaN          NaN
# min          0.00      8.70        0.33      NaN          NaN
# 25%       1198.00   1257.57        0.77      NaN          NaN
# 50%       2396.90   2456.55        0.81      NaN          NaN
# 75%       3659.42   3719.32        0.85      NaN          NaN
# max       6652.90   6701.20        0.98      NaN          NaN
#
#        page_sentence_count_spacy
# count                    1176.00
# mean                        3.56
# std                         1.97
# min                         1.00
# 25%                         2.00
# 50%                         3.00
# 75%                         5.00
# max                        17.00

# %% [markdown]
# For our set of text, it looks like our raw sentence count (e.g. splitting on `". "`) is quite close to what spaCy came up with.
#
# Now we've got our text split into sentences, how about we gorup those sentences?

# %% [markdown]
# ### Chunking our sentences together
#
# Let's take a step to break down our list of sentences/text into smaller chunks.
#
# As you might've guessed, this process is referred to as **chunking**.
#
# Why do we do this?
#
# 1. Easier to manage similar sized chunks of text.
# 2. Don't overload the embedding models capacity for tokens (e.g. if an embedding model has a capacity of 384 tokens, there could be information loss if you try to embed a sequence of 400+ tokens).
# 3. Our LLM context window (the amount of tokens an LLM can take in) may be limited and requires compute power so we want to make sure we're using it as well as possible.
#
# Something to note is that there are many different ways emerging for creating chunks of information/text.
#
# For now, we're going to keep it simple and break our pages of sentences into groups of 10 (this number is arbitrary and can be changed, I just picked it because it seemed to line up well with our embedding model capacity of 384).
#
# On average each of our pages has 10 sentences.
#
# And an average total of 287 tokens per page.
#
# So our groups of 10 sentences will also be ~287 tokens long.
#
# This gives us plenty of room for the text to embedded by our `all-mpnet-base-v2` model (it has a capacity of 384 tokens).
#
# To split our groups of sentences into chunks of 10 or less, let's create a function which accepts a list as input and recursively breaks into down into sublists of a specified size.

# %%
# Define split size to turn groups of sentences into chunks
num_sentence_chunk_size = 10


# Create a function that recursively splits a list into desired sizes
def split_list(input_list: list,
               slice_size: int) -> list[list[str]]:
    """
    Splits the input_list into sublists of size slice_size (or as close as possible).

    For example, a list of 17 sentences would be split into two lists of [[10], [7]]
    """
    return [input_list[i:i + slice_size] for i in range(0, len(input_list), slice_size)]


# Loop through pages and texts and split sentences into chunks
for item in tqdm(recording_transcription_data):
    item["sentence_chunks"] = split_list(input_list=item["sentences"],
                                         slice_size=num_sentence_chunk_size)
    item["num_chunks"] = len(item["sentence_chunks"])
# Out:
#   0%|          | 0/1176 [00:00<?, ?it/s]

# %%
# Sample an example from the group (note: many samples have only 1 chunk as they have <=10 sentences total)
random.sample(recording_transcription_data, k=1)
# Out:
# [{'Start time': 1749.0,
#   'End time': 1763.3,
#   'Language code': 'es-us',
#   'Confidence': 0.95508,
#   'Channel': nan,
#   'Speaker tag': nan,
#   'Transcript': ' En este libro de hecho sugieren que sea así si no estoy mal en alguna parte de tantas notas, que tengo se los juro que está por ahí, pero sugiere que sea así la regla entonces, ., Ahora nos vamos con esta de por acá.',
#   'Source': 'MML-SG Training meeting (2024-05-02 19_09 GMT-5).csv',
#   'sentences': [' En este libro de hecho sugieren que sea así si no estoy mal en alguna parte de tantas notas, que tengo se los juro que está por ahí, pero sugiere que sea así la regla entonces, .,',
#    'Ahora nos vamos con esta de por acá.'],
#   'page_sentence_count_spacy': 2,
#   'sentence_chunks': [[' En este libro de hecho sugieren que sea así si no estoy mal en alguna parte de tantas notas, que tengo se los juro que está por ahí, pero sugiere que sea así la regla entonces, .,',
#     'Ahora nos vamos con esta de por acá.']],
#   'num_chunks': 1}]

# %%
# Create a DataFrame to get stats
df = pd.DataFrame(recording_transcription_data)
df.describe().round(2)
# Out:
#        Start time  End time  Confidence  Channel  Speaker tag  \
# count     1176.00   1176.00      911.00      0.0          0.0
# mean      2525.43   2579.29        0.81      NaN          NaN
# std       1595.14   1596.64        0.07      NaN          NaN
# min          0.00      8.70        0.33      NaN          NaN
# 25%       1198.00   1257.57        0.77      NaN          NaN
# 50%       2396.90   2456.55        0.81      NaN          NaN
# 75%       3659.42   3719.32        0.85      NaN          NaN
# max       6652.90   6701.20        0.98      NaN          NaN
#
#        page_sentence_count_spacy  num_chunks
# count                    1176.00     1176.00
# mean                        3.56        1.01
# std                         1.97        0.08
# min                         1.00        1.00
# 25%                         2.00        1.00
# 50%                         3.00        1.00
# 75%                         5.00        1.00
# max                        17.00        2.00

# %% [markdown]
# Note how the average number of chunks is around 1.5, this is expected since many of our pages only contain an average of 10 sentences.

# %% [markdown]
# ### Splitting each chunk into its own item
#
# We'd like to embed each chunk of sentences into its own numerical representation.
#
# So to keep things clean, let's create a new list of dictionaries each containing a single chunk of sentences with relative information such as page number as well statistics about each chunk.

# %%
import re

# Split each chunk into its own item
recording_transcription_and_chunks = []
for item in tqdm(recording_transcription_data):
    for sentence_chunk in item["sentence_chunks"]:
        chunk_dict = {}
        chunk_dict["Start time"] = item["Start time"]
        chunk_dict["End time"] = item["End time"]
        chunk_dict["Source"] = item["Source"]

        # Join the sentences together into a paragraph-like structure, aka a chunk (so they are a single string)
        joined_sentence_chunk = "".join(sentence_chunk).replace("  ", " ").strip()
        joined_sentence_chunk = re.sub(r'\.([A-Z])', r'. \1',
                                       joined_sentence_chunk)  # ".A" -> ". A" for any full-stop/capital letter combo 
        chunk_dict["sentence_chunk"] = joined_sentence_chunk

        # Get stats about the chunk
        chunk_dict["chunk_char_count"] = len(joined_sentence_chunk)
        chunk_dict["chunk_word_count"] = len([word for word in joined_sentence_chunk.split(" ")])
        chunk_dict["chunk_token_count"] = len(joined_sentence_chunk) / 4  # 1 token = ~4 characters

        recording_transcription_and_chunks.append(chunk_dict)

# How many chunks do we have?
len(recording_transcription_and_chunks)
# Out:
#   0%|          | 0/1176 [00:00<?, ?it/s]
# 1183

# %%
# View a random sample
random.sample(recording_transcription_and_chunks, k=1)
# Out:
# [{'Start time': 0.0,
#   'End time': 58.6,
#   'Source': 'MML-SG Training meeting (2024-03-13 19_07 GMT-5).csv',
#   'sentence_chunk': 'Listo chicos, entonces, . Bienvenidos a la cuarta sesión del grupo estudio Eh bueno Ricardo sé que eres nuevo y no estoy muy seguro de nivel de de manejo del tema por lo que si llegas a tener alguna pregunta, tranquilo, interrumpa, eso en el micrófono levantas la mano cualquier cosa Vale en sesiones, anteriores, Disculpa Ah no Okay okay, está bien. Gracias, sesiones, anteriores. Habíamos logrado ver cómo funcionaba un modelo supervisado Cómo se podía interpretar el entrenamiento el ajuste que va haciendo con los datos en este caso Ya teniendo la respuesta, por eso es que se llama el modelo supervisor porque ya conocemos la respuesta al problema en el contexto, que estamos ahora Estamos trabajando con',
#   'chunk_char_count': 709,
#   'chunk_word_count': 119,
#   'chunk_token_count': 177.25}]

# %% [markdown]
# Excellent!
#
# Now we've broken our whole textbook into chunks of 10 sentences or less as well as the page number they came from.
#
# This means we could reference a chunk of text and know its source.
#
# Let's get some stats about our chunks.

# %%
# Get stats about our chunks
df = pd.DataFrame(recording_transcription_and_chunks)
df.describe().round(2)
# Out:
#        Start time  End time  chunk_char_count  chunk_word_count  \
# count     1183.00   1183.00           1183.00           1183.00
# mean      2530.02   2583.92            732.16            136.05
# std       1595.76   1597.27            239.97             44.86
# min          0.00      8.70              1.00              1.00
# 25%       1198.00   1257.75            677.00            125.00
# 50%       2396.90   2456.60            806.00            149.00
# 75%       3673.50   3733.15            890.00            164.00
# max       6652.90   6701.20           1107.00            230.00
#
#        chunk_token_count
# count            1183.00
# mean              183.04
# std                59.99
# min                 0.25
# 25%               169.25
# 50%               201.50
# 75%               222.50
# max               276.75

# %% [markdown]
# Hmm looks like some of our chunks have quite a low token count.
#
# How about we check for samples with less than 30 tokens (about the length of a sentence) and see if they are worth keeping?

# %%
# Show random chunks with under 30 tokens in length
min_token_length = 30
for row in df[df["chunk_token_count"] <= min_token_length].iterrows():
    print(f'Chunk token count: {row[1]["chunk_token_count"]} | Text: {row[1]["sentence_chunk"]}')
# Out:
# Chunk token count: 19.75 | Text: Lo que hacemos Es compartirles la grabación entonces Déjenme comparto pantalla.
# Chunk token count: 13.0 | Text: Me pueden confirmar cuando la puedan ver, por favor?
# Chunk token count: 10.25 | Text: No son simplemente un grupo de estudio, .
# Chunk token count: 24.5 | Text: A lo que trata el grupo y vamos a dar una introducción un poco a alto nivel de lo que vamos a ver.
# Chunk token count: 19.25 | Text: Básicamente compartir es es cuidar a los demás y tework make the Dreams work.
# Chunk token count: 20.5 | Text: Y pues hasta ese momento Tienen alguna duda pregunta comentario o todo va bien él.
# Chunk token count: 17.25 | Text: Sí, por ahora listo, continuamos ahí e Por qué usar Machine learning.
# Chunk token count: 11.5 | Text: Empezar por el por qué es buena idea usarlo, .
# Chunk token count: 14.25 | Text: Qué tipos de Machine learning models, vamos a utilizar, .
# Chunk token count: 11.25 | Text: Y lo que lo que lo que me gustaría Mostrar ..
# Chunk token count: 14.0 | Text: Es una forma en la que la misma máquina o algoritmo fue.
# Chunk token count: 4.25 | Text: motos en Medellín
# Chunk token count: 14.0 | Text: .,simplemente con esta con este Pro él va a ser capaz de
# Chunk token count: 28.75 | Text: de de generar dos imágenes le podemos escoger a mano izquierda, Pues los diferentes estilos que queremos que tenga.
# Chunk token count: 14.25 | Text: Y pues mira aquí generó la primera, esperemos la segunda.
# Chunk token count: 15.5 | Text: Me haría falta una det para que sea Medellín pero no está mal.
# Chunk token count: 4.75 | Text: Espera Aquí está, .
# Chunk token count: 20.5 | Text: El modelo generativo es capaz de .,el modelo generativo es capaz de de a partir de
# Chunk token count: 16.75 | Text: y el momento en el que funciona el el el cell supervise learning el
# Chunk token count: 8.5 | Text: Que tiene todas las propiedades, .
# Chunk token count: 19.75 | Text: Eh, este es uno de mis favoritos que es están enseñando, básicamente a caminar.
# Chunk token count: 4.25 | Text: A este muñequito.
# Chunk token count: 11.0 | Text: Eso es lo que se puede llegar a hacer, vale?
# Chunk token count: 19.5 | Text: Ya más adelante, vamos a ver otra posible, . Aplicación que podría tener esta.
# Chunk token count: 10.25 | Text: a un Script normal que podríamos testear.
# Chunk token count: 17.25 | Text: Tomar decisiones técnicas Al momento de resolver un problema, .listo?
# Chunk token count: 10.75 | Text: Eh, Ahora manos a la obra con lo que sería.
# Chunk token count: 6.75 | Text: Machine learning y ética, .
# Chunk token count: 26.25 | Text: Johnny intenta explicar a él una vez que entiendes Cómo funcionan los modelos y lo de lo que son capaces.
# Chunk token count: 0.5 | Text: lo
# Chunk token count: 16.75 | Text: Y Alan sugiere que no de hecho él dice no podemos hacerlo porque si
# Chunk token count: 0.5 | Text: no
# Chunk token count: 0.25 | Text: o
# Chunk token count: 3.25 | Text: O lo que sea.
# Chunk token count: 13.0 | Text: Y vos Entonces nos recomendás Mira la página de fase
# Chunk token count: 18.25 | Text: y de ahí duditas, que tengamos el próximo miércoles y y así O cómo sería.
# Chunk token count: 5.25 | Text: listo Gracias Esteban
# Chunk token count: 4.25 | Text: Buena pregunta, .
# Chunk token count: 4.25 | Text: de la complejidad
# Chunk token count: 4.25 | Text: Sí señor, Esteban
# Chunk token count: 19.0 | Text: Chicos, no sé si hay algo más por ahí en el aire o hasta el momento todavía.
# Chunk token count: 28.25 | Text: Listo, el silencio ya dijimos que era Era como buena señal, lo último que les les Quiero compartir es este video.
# Chunk token count: 3.0 | Text: por el grupo
# Chunk token count: 26.0 | Text: A mano izquierda, ven e Cómo la mayoría de modelos, se comporta que es a partir de datos que ya conozco.
# Chunk token count: 20.5 | Text: Puedo hacer regresiones, . Así tenga el target o no?Así tenga la respuesta o no, .
# Chunk token count: 8.25 | Text: que ese sería el límite más Wow y
# Chunk token count: 24.5 | Text: y si no sé, me me deja enamorado ese tipo de ideas que que ya seamos capaces de construir algo que
# Chunk token count: 0.75 | Text: Eh!
# Chunk token count: 22.25 | Text: Y y bueno es una de las cosas que más me asombra, o sea, literalmente Esa esa ese modelo.
# Chunk token count: 5.5 | Text: Muchas gracias chicos.
# Chunk token count: 26.75 | Text: El compañero Mateo se cayó o soy yo Uy yo pensé que era yo no escucho, se cayó, se le fue más que la señal.
# Chunk token count: 21.25 | Text: Ya se cayó del todo, voy a escribir por discord, a ver si si de pronto por ahí lo ve.
# Chunk token count: 30.0 | Text: Es correcto ahí, vuelve otra vez cierto. Te decía lo que de pronto puede que yo tenga esto le explicaré no colabora hoy.
# Chunk token count: 22.25 | Text: Y aquí se nos entregan Jason tengo la sospecha de que aquí podemos sacar más información.
# Chunk token count: 8.5 | Text: Parece que tiene algo de los ojos.
# Chunk token count: 14.75 | Text: Conectamos Aquí hacemos un extractor para coger el archivo.
# Chunk token count: 21.0 | Text: Digámoslo acá listo, tenemos información aquí le hacemos un pandas._libs.tslibs.nat.
# Chunk token count: 3.0 | Text: I don't your
# Chunk token count: 23.75 | Text: Me imagino y ya la podemos utilizar aquí abajito que sería por aquí, sí agregamos una celdilla.
# Chunk token count: 7.75 | Text: montón más ya superinteligencia
# Chunk token count: 3.0 | Text: Esa palabra.
# Chunk token count: 19.25 | Text: De momento sin, o sea, con total desconocimiento de si vaya a funcionar o no.
# Chunk token count: 13.75 | Text: A ver si nos aparece una imagen que lo que lo explique.
# Chunk token count: 23.25 | Text: Así Esperemos que la comunidad crezca y nos vemos dentro de ocho listo, Gracias Gracias chao.
# Chunk token count: 8.75 | Text: Tra. Tra. Tra. Tra. Tra. Tra. Es lo

# %% [markdown]
# Looks like many of these are headers and footers of different pages.
#
# They don't seem to offer too much information.
#
# Let's filter our DataFrame/list of dictionaries to only include chunks with over 30 tokens in length.

# %%
pages_and_chunks_over_min_token_len = df[df["chunk_token_count"] > min_token_length].to_dict(orient="records")
pages_and_chunks_over_min_token_len[:2]
# Out:
# [{'Start time': 21.8,
#   'End time': 36.7,
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv',
#   'sentence_chunk': 'Sí sí, se puede ver listo amplia, grande. Eso es, . Nada muchachos, Bienvenidos a Machine learning Medellín Machine learning Story Group',
#   'chunk_char_count': 136,
#   'chunk_word_count': 22,
#   'chunk_token_count': 34.0},
#  {'Start time': 42.8,
#   'End time': 75.5,
#   'Source': 'MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv',
#   'sentence_chunk': 'Que pues surgió de de uno que existía en Berlín en Alemania y pues inspiró este Eh me pareció que tuve la oportunidad el año pasado viajar allá, . Lo conocí en primera persona me pareció una idea Genial porque el concepto es casi muy parecido al que van a ver acá es completamente abierto y simplemente para aprender, . Esta es la agenda que vamos a tener el día de hoy, va a ser un poco más introductoria respecto a lo que',
#   'chunk_char_count': 423,
#   'chunk_word_count': 83,
#   'chunk_token_count': 105.75}]

# %% [markdown]
# Smaller chunks filtered!
#
# Time to embed our chunks of text!

# %% [markdown]
# ### Embedding our text chunks
#
# While humans understand text, machines understand numbers best.
#
# An [embedding](https://vickiboykis.com/what_are_embeddings/index.html) is a broad concept.
#
# But one of my favourite and simple definitions is "a useful numerical representation".
#
# The most powerful thing about modern embeddings is that they are *learned* representations.
#
# Meaning rather than directly mapping words/tokens/characters to numbers directly (e.g. `{"a": 0, "b": 1, "c": 3...}`), the numerical representation of tokens is learned by going through large corpuses of text and figuring out how different tokens relate to each other.
#
# Ideally, embeddings of text will mean that similar meaning texts have similar numerical representation.
#
# > **Note:** Most modern NLP models deal with "tokens" which can be considered as multiple different sizes and combinations of words and characters rather than always whole words or single characters. For example, the string `"hello world!"` gets mapped to the token values `{15339: b'hello', 1917: b' world', 0: b'!'}` using [Byte pair encoding](https://en.wikipedia.org/wiki/Byte_pair_encoding) (or BPE via OpenAI's [`tiktoken`](https://github.com/openai/tiktoken) library). Google has a tokenization library called [SentencePiece](https://github.com/google/sentencepiece).
#
# Our goal is to turn each of our chunks into a numerical representation (an embedding vector, where a vector is a sequence of numbers arranged in order).
#
# Once our text samples are in embedding vectors, us humans will no longer be able to understand them.
#
# However, we don't need to.
#
# The embedding vectors are for our computers to understand.
#
# We'll use our computers to find patterns in the embeddings and then we can use their text mappings to further our understanding.
#
# Enough talking, how about we import a text embedding model and see what an embedding looks like.
#
# To do so, we'll use the [`sentence-transformers`](https://www.sbert.net/docs/installation.html) library which contains many pre-trained embedding models.
#
# Specifically, we'll get the `all-mpnet-base-v2` model (you can see the model's intended use on the [Hugging Face model card](https://huggingface.co/sentence-transformers/all-mpnet-base-v2#intended-uses)).

# %%
# Requires !pip install sentence-transformers
from sentence_transformers import SentenceTransformer

embedding_model = SentenceTransformer(model_name_or_path="all-mpnet-base-v2",  # NOTE: is it the model for SPANISH?
                                      device="cpu")  # choose the device to load the model to (note: GPU will often be *much* faster than CPU)

# Create a list of sentences to turn into numbers
sentences = [
    
#  -1.19771324e-02  8.67972523e-03  1.38819329e-02  2.82412004e-02
#   6.03429638e-02  2.11701356e-02 -4.01302464e-02 -9.08106752e-03
#   1.15351953e-01  7.45985145e-03  6.80279508e-02  2.36127153e-02
#   1.79609120e-34  3.53710447e-03 -3.27938050e-02  3.08509637e-02
#  -2.54058186e-02  2.42135711e-02 -7.76112359e-03 -3.06517761e-02
#  -1.32208574e-04  3.12191658e-02 -4.54968587e-02  1.89552289e-02]
# Embedding size: (768,)

# %% [markdown]
# Nice! We've now got a way to numerically represent each of our chunks.
#
# Our embedding has a shape of `(768,)` meaning it's a vector of 768 numbers which represent our text in high-dimensional space, too many for a human to comprehend but machines love high-dimensional space.
#
# > **Note:** No matter the size of the text input to our `all-mpnet-base-v2` model, it will be turned into an embedding size of `(768,)`. This value is fixed. So whether a sentence is 1 token long or 1000 tokens long, it will be truncated/padded with zeros to size 384 and then turned into an embedding vector of size `(768,)`. Of course, other embedding models may have different input/output shapes.
#
# How about we add an embedding field to each of our chunk items?
#
# Let's start by trying to create embeddings on the CPU, we'll time it with the `%%time` magic to see how long it takes.

# %%
# %%time

# Uncomment to see how long it takes to create embeddings on CPU
# # Make sure the model is on the CPU
embedding_model.to("cpu")

# # Embed each chunk one by one
for item in tqdm(pages_and_chunks_over_min_token_len):
    item["embedding"] = embedding_model.encode(item["sentence_chunk"])
# Out:
#   0%|          | 0/1118 [00:00<?, ?it/s]
# CPU times: total: 1h 3min 15s
# Wall time: 5min 17s

# %% [markdown]
# Ok not too bad... but this would take a *really* long time if we had a larger dataset.
#
# Now let's see how long it takes to create the embeddings with a GPU.

# %%
# %%time

# Send the model to the GPU
#embedding_model.to("cuda") # requires a GPU installed, for reference on my local machine, I'm using a NVIDIA RTX 4090

# Create embeddings one by one on the GPU
#for item in tqdm(pages_and_chunks_over_min_token_len):
#    item["embedding"] = embedding_model.encode(item["sentence_chunk"])
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %% [markdown]
# Woah! Looks like the embeddings get created much faster (~10x faster on my machine) on the GPU!
#
# You'll likely notice this trend with many of your deep learning workflows. If you have access to a GPU, especially a NVIDIA GPU, you should use one if you can.
#
# But what if I told you we could go faster again?
#
# You see many modern models can handle batched predictions.
#
# This means computing on multiple samples at once.
#
# Those are the types of operations where a GPU flourishes!
#
# We can perform batched operations by turning our target text samples into a single list and then passing that list to our embedding model.

# %%
# Turn text chunks into a single list
text_chunks = [item["sentence_chunk"] for item in pages_and_chunks_over_min_token_len]

# %%
text_chunks
# Out:
# ['Sí sí, se puede ver listo amplia, grande. Eso es, . Nada muchachos, Bienvenidos a Machine learning Medellín Machine learning Story Group',
#  'Que pues surgió de de uno que existía en Berlín en Alemania y pues inspiró este Eh me pareció que tuve la oportunidad el año pasado viajar allá, . Lo conocí en primera persona me pareció una idea Genial porque el concepto es casi muy parecido al que van a ver acá es completamente abierto y simplemente para aprender, . Esta es la agenda que vamos a tener el día de hoy, va a ser un poco más introductoria respecto a lo que',
#  'Y finalmente una una demo o un un primer plano de cómo funcionario un modelo Entonces como pueden ver tenemos es, . Acerca del grupo una breve introducción, . Porque es buena idea usar Machine learning, Qué tipos de Machine learning learning Vamos a aprender, . Configurar el ambiente y desarrollo y una explicación en tuent de de lo que implica un modelo emochiner, . Acerca del grupo el propósito como Les acabo de mencionar es aprender diseñar construir proyectos, . Hacerlo no solo sino con una comunidad poder aprender de otros, . Soy fiel creyente cuando trabajas en equipo y y aprendes de otras personas aprendes mucho más rápido aprendes cosas a una velocidad más rápida y siempre tienes una comunidad que te soporta en momentos de dudas en',
#  'Momentos de incluso oportunidades laborales incluso construir cosas proyectos juntos es la idea básicamente, . Quién puede participar es completamente gratuito y abierto cualquier persona puede ingresar simplemente se necesita que tenga un conocimiento en programación, . Pero la idea es comenzar de sero to Hero desde cero hasta poder manejar un buen nivel de lo que significa Machine learning e',
#  'Y .,para aclarar, . El grupo es más cercano a un gimnasio a ir a un gimnasio que a un curso no es tanto como una guía en la que una persona está dictando las pautas, sino es completamente abierto si alguien tiene una idea, si alguien tiene un comentario Si alguien, tiene un Data set, si alguien tiene algo, es completamente abierto que lo comparta a que entre su código que preguntas que incluso esa persona dirija, una sesión es completamente abierto, .,Y cuando digo que es gimnasio, . Es más un entrenamiento diario de de mejorar esta habilidad, en este caso va a ser semanal, pero es un entrenamiento para poder mejorar esta habilidad, .,Y básicamente se fundamenta en dos en dos frases que me gustan mucho del inglés, que es shoring sc.',
#  'Eh, el trabajo en equipo hace que los sueños funcionen no, no suele pasar que una persona lo pueda hacer todo solo, entonces siempre en comunidad y apoyándose uno llega más lejos Ese es el objetivo de del grupo de machinder e breve introducción al grupo, . Como ya se dieron cuenta todo se dieron a través del canal de discord, allí pueden participar comentar compartir entregar cualquier material invitar compañeros, es completamente abierto e sobre el administrador soy yo, . De pronto un background de lo que yo he hecho, . Llevo yo diría que ya casi 10 años programando comencé con aplicaciones móviles y servidores también, . Trabajé en automatización y estoy trabajando actualmente en Machine learning, .,Me apasiona de todos los temas de programación que he trabajado Este es el que más me ha movido las fibras, me encanta, me encanta, .',
#  'Tanto así que se dio la oportunidad de abrir este grupo y de participar, .,De pronto también un poco de introducción de Por qué se diseñó un poco más como un gimnasio que como un curso es Eh Yo también, . Fui entrenador de patinaje de velocidad y actualmente soy, . Un activo patinador de velocidad el concepto que se tiene allí es parecido al que yo intento transmitir acá en ese grupo que es es en un gimnasio en el que vas a entrenar con tus compañeros Y en vez de crearse como una rivalidad, . Cuando esa persona Mejora tu mejoras y así ambos van creciendo Y tienes la guía, que es el entrenador que te va aconsejando, pero también tus compañeros que te van dando feedback de lo que puedes mejorar de Qué cosas. Estás haciendo bien?Estás haciendo mal es una idea muy parecida y obviamente trabajo duro, .',
#  'Apoyo trabajo duro buena lectura en este caso y ejercicios, . Un poco el Bag también porque es un poco más gimnasio que que curso, . Las reglas son muy sencillas con respecto a las comunicaciones, . Si hay alguna diferencia, simplemente con respeto y pasa usar los canales, .,Para lo que fueron diseñados que es Eh Pues si es algo de chisme o algo, así podemos crear un canal, pero . Digamos, .,si el canal de pronto solo para comunicaciones, .',
#  'No lo sé dataset o algo así puedes usarlo para eso y ya eso es en los únicos reglas y .finalmente la guía, que vamos a usar es la de la página que se llama Fast a e.',
#  'Que le haríamos algunos cambios Aunque tampoco La idea, es ligarse como a rajatabla, la guía Sí nosotros decimos que hay otra forma de de aprender o de de entender un tema Simplemente se toma ese camino y ya no hay resistencia en ningún tipo, simplemente se propone se coloca a consideración si se ve que es la mejor opción, pues va para adelante, .',
#  'Eh, esta pregunta es tan e es tan fácil como difícil de responder, . Machine learning. Es el corazón a uno de los corazones que tiene a y creo que todos ahorita vemos el impacto que tiene la tecnología llegó a un nivel de madurez en el que podemos sacar provecho a estos algoritmos que se han estado desarrollando desde hace mucho tiempo, pero por capacidad de Hardware principalmente no se ha podido, . Concretar Eh hay hay mucho por hacer y es difícil incluso.',
#  'Pensar los campos en los que no va a impactar, es más fácil pensar es más difícil decir qué Campos no va a impactar, puedes pensar en medicina en construcción, puedes pensar en negocios, puedes pensar en en deportes?',
#  'Va a haber algo?Básicamente si tienes datos e incluso si no ya lo vamos a ver Hay posibilidades de construir un modelo que te sirva para hacer alguna clasificación alguna regresión alguna detección de anomalías algo que de pronto ahorita suena muy aburrido esos términos, pero van a ver que aplicados a veces te dan, . Resultados increíbles y incluso ahorita el el Boom que hay ahorita en Machine learning, es referente a las .,tecnología, tecnologías generativas como puede ser un tío, como puede ser un un stable difusion para generar imágenes que ahorita también le vamos a echar un ojo, Eh entonces.',
#  'Es un buen inicio, entender Por qué es una buena idea y creo que también sirve para que uno se motive a a trabajar en esto e no siempre es el buen inicio, no siempre es como la matemática y todo esto que a veces es muy denso aburrido, sino entender el proyecto que te apasiona como lo puedes potenciar y sin dudas Yo pienso que Machine learning e Inteligencia artificial Está abriendo o está poniendo más lejos, la Barrera de lo que podemos hacer ahorita Hay un montón de cosas para hacer y si hay algún tema que les apasiona estoy, seguro que en algún campo se le puede aplicar Machine learning a nivel de negocio a nivel de incluso recreativo, ya vamos a ver ahorita unos ejemplos bastante buenos del tema, .',
#  'Vamos a ver principalmente cuatro es el objetivo de del grupo Studio . Igual si cualquier persona quiere aportar uno nuevo que no sea muy muy utilizado algo así también es super bienvenido, . Pero aquí sí voy a hacer una interacción entre la presentación y',
#  'El primero es supervise learning, los términos los voy a poner en inglés porque así aparecemos que todo en la literatura por lo que es bueno familiarizarse de esa manera, . Los modelos de aprendizaje supervisado o supervise learning es una forma en la que tú le puedes enseñar a la máquina, qué tiene que hacer ya dándole la respuestas la imagen lo representa bastante bien, . Que sería',
#  'Le muestras la imagen de que de que en este momento son manzanas, la máquina se equivoca y tú le haces el feedback de que se está equivocando. Y luego la máquina corrige es la forma en la que tienes las características de la manzana, en este caso es la imagen de la manzana y tienes la respuesta ya hecha que es son manzanas, no son banadas Entonces de esa manera.Él aprende Ajustando la la la el valor, que es correcto con el valor, que él está prediciendo y va Ajustando hasta que ya entrega el valor esperado, yo lo cuando lo intenté entender por primera vez era el comportamiento es muy parecido cuando estás afinando una guitarra que tú tocas la guitarra y suena horrible.',
#  'Y lo que haces es ajustar un poco, no sé cómo se llaman estas tuerquitas, . Pero ajustas para que se tensione vuelves a tonar y otra vez suena horrible Entonces lo vuelves a ajustar, lo ajustas lo ajustas hasta que ya te entregue el resultado esperado en ese caso se llama supervisado porque le estás entregando ya las respuestas y simplemente haces un feedback para que al final se vaya se vaya acomodando a la respuesta correcta, . O también otro ejercicio con el que se puede ver es, .',
#  'Como manejar un carro ponle tú un tesla o simplemente nosotros mismos manejando un carro, . Vamos Aprendiendo a a frenar acelerar. Se nos va apagando el carro, pero con el tiempo vamos entendiendo con nuestro guía, que es el que nos va dando las respuestas, qué es lo que tenemos que ir haciendo?Vale, .,coloco este ejercicio de primeras porque de aquí nació mi mi inspiración para para trabajar en Machine learning y hace unos años. Yo estaba con la ilusión de querer comprar un apartamento. Creo que la mayoría de nosotros lo tenemos y y en mi cabeza, Yo decía Qué chévere, sería poder saber cuál es el apartamento más barato y pues que se acomodan mis necesidades, etcétera, etcétera.',
#  'Con el que pueda tener Pues que se valorice, Imagínate tú e y de ahí nació la primera idea de del proyecto que es el Data set que les he compartido en el grupo y también he compartido el link en la red laboral, que es el Data set de inmuebles que han estado en venta.',
#  'Y incluye el precio Este es un ejercicio de aprendizaje supervisado porque conocemos las características del inmueble, pero también conocemos su precio final o el precio en el que está a la venta de esta manera, podemos crear un modelo que prediga los precios de los inmuebles cosa que la próxima vez que tú ya compres o quieras vender un apartamento. Tú puedes ya saber si más o menos en cuánto estaría el precio de ese apartamento, si si se compensa, .,comprarlo, . Se pueden hacer muchas más cosas que ya veremos más adelante, . Con ese mismo Data set como una de las cosas más interesantes es este, . Detección de anomalías, se llama para poder identificar perfectamente eso dadas las características de todos los apartamentos que hay cuáles son estos raritos que están por debajo del precio normal y esos eso es una de las aplicaciones de anomaly detection que son geniales en este caso porque pues.',
#  'Esa es la respuesta para poderte encontrar el inmueble que querías que está barato y que tiene las mejores condiciones que tú estás buscando este dato set, . Se le puede agregar un montón de cosas más, . Supón tú que ahora puedes agregar ubicaciones de valor, puedes pegarse dos comerciales estaciones de policías cárceles, etcétera, etcétera incluso, . Las vías de tráfico y tú puedes decir, . Por ejemplo, . Yo soy estudiante y mi universidad queda al norte de la ciudad Entonces cuál es Cuál es el mejor apartamento que me queda a para mis condiciones y dado mi presupuesto, entonces uno podría pensar que siempre uno tiene que durar a zonas lejanas, pero más baratas, pero a veces si compensas lo que gastas en en en transporte y lo sumas de pronto a',
#  'a tu alquiler, tú podrías saber cuál es el mejor lugar para tus condiciones de estudiante o de pronto las condiciones mías son diferentes como ser padre y tengo hijos y necesito que quedes cerca de la escuela de mis hijos para mi trabajo todos esos, . Todo ese tipo de problemas que con programación convencional no Se podrían solucionar fácilmente son estándar al alcance de lo que puede hacer ahorita entonces.',
#  'Eh, si se dan cuenta con el mismo dataset, se pueden hacer un montón de cosas y es es lo que vamos a hacer en este en este grupo E eso sobre el supervisado, . Sobre el no supervisado o un supervise learning como pueden ver en la imagen e En qué cambia con el supervisor. Tú conoces las características del evento, pero no sabes la respuesta en este caso Solamente le estamos mostrando al robot o a la máquina, . La forma de las Manzanas o de las frutas.',
#  'Y él tiene que intuir de alguna manera Cuáles son bananas Cuáles son manzanas, cuáles son peras y lo hace a través de algoritmos que por lo general buscan similitudes, . Algo que algunos de de clerización o cosas parecidas y intentándolos agrupar como se pueden dar cuenta aquí en la imagen, . Las bananas las las, .,marco con este marcador como azul en las otras con El Rosado es una forma en la que puede encontrar características, . Semejantes sin tener la respuesta clave y para qué podría funcionar esto por ejemplo, . Imagínate tú que estás trabajando en una prensa de ciberseguridad y te ponen la tarea Pues de encontrar estos comportamientos raros que pueden existir en la red. Entonces tú podrías e',
#  'Identificar dados las entradas que tienen los usuarios, las navegaciones que tienen cuál se está comportando un rarito. Tú no sabes que está está cometiendo como algún delito o está haciendo algo malo en la pereza, pero está rarito y eso ya te ayuda como a filtrar Entonces es no supervisado porque tú no tienes la respuesta, no sabes, . Espero, . Sí no sabes no sabes al final, .',
#  'Cuál cuál es Cuál es el target, pero dadas las características puedes intuir, . Que se comporta de forma rara. Eso es una de las aplicaciones que podría tener anual detection, . Eh, el aprendizaje No supervisado e el siguiente que también la idea es verlo, este es uno de los más impresionantes y de los que está pegando más duro ahorita el set supervise learning.',
#  'Aprender más allá de lo que sabe a través de modelos generativos, vamos a hacer un ejercicio y creo que de esta manera lo van a entender y ahí se van a responder un poco porque chaji Pit una versión es gratis y otra, no, . Lo que están viendo en pantalla, es difusion. Este es un un modelo fundacional que se utiliza para generación de imágenes y básicamente te genera una imagen a través de un prot es como un chpt, pero para imágenes, . Con una diferencia que ya vamos a ver cómo funciona el cell supervide. Voy a colocar aquí, .',
#  'Leamos dibujar le podemos escoger que queramos, pero en este caso le vamos a pedir que escoja que nos genere dos imágenes ya les comentaré por qué.',
#  'cosas que ya sabe generar nuevas salidas en este caso lo que ya sabes que este este modelo fue entrenado con muchas imágenes de motos',
#  'El entrenamiento autosupervisado es cuando yo escojo una de estas imágenes porque yo al mismo modelo le estoy indicando Cuál es la imagen que acierta más con con la solicitud que yo tenía entonces ahí se genera un feedback en el cual, el modelo genera yo solo utilizándolo valida y va mejorando su su va mejorando su precisión va mejorando su rendimiento porque es un círculo virtuoso el cual me entrega resultados yo valido indirectamente porque yo no estoy siendo alguien que etiqueta, sino simplemente alguien que lo utiliza pero indirectamente etiqueta y él va generando este círculo virtuoso en el cual se va mejorando con el tiempo ahí de ahí viene que saypiti se ha se ha sea gratuito una parte porque cuando alguien lo utiliza y le dice Esto no es lo que yo pedí de alguna manera le estás diciendo al modelo, esa respuesta está mal.',
#  'Y cuando muchas personas utilizan gpt y muchas personas le dicen a la misma solicitud que está mal chachipiti, va a corregir en la próxima versión en el próximo entrenamiento, ahí se va generando un un una un un círculo virtuoso se llama, . Trabaja mucho con modelos generativos Por lo general se usan redes neuronales para eso también la idea es verlo, . Justo en el en el Data set de de finca raíz.',
#  'Una de las aplicaciones que se le dio con el modelo generativo es poder saber cuáles son las mejores dimensiones que tiene el inmueble que quiero para que se venda rápido Sí entonces lo que haces es entrenar Este modelo generativo con los que con los que se entrenan, .,Eh disculpe con información de los Data sets que se entrenan, . Que que se han vendido más.',
#  'Y a partir de eso te genera otros inmuebles que se parecen o que están en locaciones parecidas para que se vendan rápidamente, .,listo, eso es sobre el modelo, . Autosupervisor Ahora el modelo, . Reinfort learning. Básicamente lo que sucede acá es que acá no tienes ni siquiera las características de del Data set y no tienes las respuestas, es decir Estás tú solo contra el mundo y aquí se utilizan otro tipo de algoritmos que en el cual estás trabajando en un ambiente en el cual haces una acción y el ambiente te entrega una reacción uno de los ejemplos en los que podemos ver eso es aquí.',
#  'Eh, simplemente es el agente manejando los piecitos y la recompensa se maneja a través de un sistema de recompensa y de castigo, Se podría decir si te caes es un castigo, si tú duras vivo que es básicamente caminar en pie es recompensa y le puedes enseñar un montón de comportamientos diferentes el reto, por ejemplo, aquí más grande es que a través de todos estos obstáculos de lado a lado y si se dan cuenta son superficies completamente irregulares, pero en realidad, nosotros no le estamos diciendo Cuáles son los datos para que aprenda él los va a aprender con las acciones y las recompensas Y eso lo hace a través de muchas iteraciones aquí Déjenme lo coloco de pronto en una velocidad más alta.',
#  'Para que vayamos viendo cómo cómo Va progresando con el tiempo se va a caer, va a levantarse, se va a caer, va a levantarse y hasta que finalmente vamos a ver qué hacer capaz de superar los obstáculos. Eso es lo que se podría hacer cor incluso, . El algoritmo que utilizaron para poder ganarle a En ajedrez a alguien Utiliza este utiliza un modelo de supervisado que aprendió a jugar ajedrez y entre más perdía, pues más aprendida hasta que al final ninguna persona creo que le ha podido ganar últimamente a ese modelo y si le gana pues al final estás enseñando Cómo cómo ganarte, .',
#  'Me vuelvo aquí atrás a la presentación, . Listo hasta este punto, . La idea básicamente es empezar con lo que tú puedes llegar a ser más que empezar como con la matemática dura y pesada, sino qué es lo que yo puedo llegar a construir, qué es lo que puedo, .,lograr con estos modelos.',
#  'Eh, lo digo desde una experiencia personal porque así ha funcionado a través de mi carrera. Siempre me ha dado curiosidad algo y la curiosidad me gana para poder terminarla haciéndolo, . La forma en la que empecé con aplicaciones móviles fue así una vez, yo vi cuando salieron estos celulares, .,geniales con aplicaciones y touch, no sé qué y yo decía Wow Yo quiero aprender a hacer una de esas una de esas aplicaciones e curiosamente mi primera aplicación fue una de citas que se llama wigman, . Pero creo que es importante empezar con eso con esa con ese proyecto que tienes en la cabeza que te llamaría la atención que dices, ey, esto se ve muy interesante y a partir de ahí empezar a jalar la pita para poder construir modelos muy bacanos, .,Y ya la parte verán que la parte de estadística y la parte de matemática que sí que la vamos a ver no va a ser tan dolorosa porque ya le encuentras un por qué ya le encuentras un Stone sí me sirve para algo. Lo digo porque en la universidad odiaba estadística.',
#  'Y ahorita me encanta por lo que puede llegar a a significar en en en la aplicación, . Listo lo siguiente que me gustaría mostrarles es, .,el ID que vamos a utilizar.',
#  'Eh, yo lo recomiendo que hay más, . Visual Studio code con la extensión que es de jpiter, . Es básicamente te permite utilizar notebooks Déjenme Aquí les muestro un poco de que se trata.',
#  'que yo tengo aquí solo estoy a la mano y de esta manera, pues pueden ver cómo funcionan Notebook y por ejemplo, qué se diferencia con respecto a',
#  'Aquí se debería bueno Esto es un Notebook en el cual una explicación No tan técnica es tienes celdas las cuales vas escribiendo código, pero es capaz de visualizar, . O hacer pausas en ese código y es más amable Al momento de visualizar datos es importante porque lo que nosotros vamos a utilizar mucho Machine learning, no está todas esos programas son convencionales de hecho, te demoras más pensando la idea que programando.',
#  'En la experiencia, pero lo que puedes hacer acá es testear, secciones e ir verificando datos, por ejemplo, lo que pueden ver en pantalla, tengo esta parte que es simplemente borré una columna y aquí muestra otra vez el Data set, o sea, sin esa columna hago una transformación y luego lo que me muestra es la la el resultado de la transformación, . Incluso puedo también ver, . Los algoritmos de Machine learning que podría estar utilizando Esto es para poder, . Quitar las anomalías, que vamos a ver después, por ejemplo, si puede hacer otra visualización esta fueron partes de las pruebas que se hicieron para el dataset que tienen raíz, .',
#  'Prefieren otro, .,No hay ningún problema e ahora un poco de manos a la obra con con el primer modelo, .,Solo mostrarles un poco a lo que sería un ent Ah pero antes una una falla media también además de el ID que sería visual Studio code, . Recomendaría usar, . Esta librería skiller e tiene varios algoritmos de de Machine learning, es cuando ya sabes qué significa cada uno de los algoritmos es bastante fácil de utilizar, hay que aprenderlos eso es lo que desearíamos hacer acá en este en este grupo de estudio También tenemos tensor Flow este está más enfocado a redes neuronales, que es el Deep lo que se conoce como Deep Y actualmente es lo que ha presentado mejores resultados para problemas complejos tanto, así que no se entiende cómo funciona para resolver problemas tan complejos, .',
#  'Que también aprenderíamos a Cómo desarrollar estas redes neuronales para hacer regresiones clasificaciones, . Modelos generativos, .,autores, que ya veremos qué significa más adelante y finalmente para visualización recomiendo esto simplemente, simplemente es para mostrar gráficas de distribuciones o cosas así Que también será necesario para poder, .',
#  'Con lo que sería un proyecto Machine learning, . Podemos dividirlo en cuatro etapas, . La primera es la conexión de la información literalmente aquí la información es el nuevo oro digital. Yo estoy absolutamente convencido de eso la persona que se que pueda capturar datos, . Tiene ya alguien que se los compre incluso, .,En este diagrama que pueden ver en la parte superior se ven los actores que vienen siendo personas que están recolectando datos, etcétera, etcétera En la mitad van a ver, . Las diferentes herramientas que se pueden utilizar para hacer recolección de datos Y en la parte de abajo se puede ver en',
#  'Eh, los servicios que se podrían entregar, . Un desde el primer paso en la colección de datos, ya se podría vender si tú estás interesado en un negocio o algo así se podría vender el mismo, . Scrapy o el mismo modelo automático que va a capturar esa información desde la Fuente',
#  'O se podría ya vender, . La información recolectada en el siguiente paso está en las analíticas Este es el paso previo a a realizar un modelo de Machine learning de hecho es Es uno que tiene que estar bien fundamentado, que es, ya tienes la la información capturada. Ya conoces la calidad de los datos y eres capaz de identificar ciertos insites que te pueden entregar como las ventas que he tenido en la empresa o por con el Dr de las de finca raíz, .,Cuáles son las áreas que mejor presentan comportamiento de crecimiento, si los procesos son aumentaban decrecidos y las tendencias de las áreas han bajado han crecido etcétera, etcétera tener esa información es Clara para poder construir el modelo porque a partir de eso puedes tomar la decisión de Qué se puede hacer siguiente paso construye el modelo en este caso, . Hacer el modelo de anomalía de detecciones para identificar, cuál es el inmueble que más te sirve para comprar e',
#  'Puedes vender el modelo también, .,Y al final se el diploiment que es también puedes vender el consumo del móvil que es lo que hace, básicamente ellos no nos van a vender el modelo. Además que es muy pesado y grande y se necesitaría un buen computador para atenderlo Pero lo que sí van a hacer es venderte acceso venderte el acceso al modelo Esa es la el pib que se necesitaría a muy grandes rasgos, eso también se los puedo compartir, .,Si desea e ya pasando para las últimas partes del de la presentación para ya dejar de de hacerla tan larga la idea no es que en todas, . Nos quedemos hablando sino también ya hagamos manos a la obra y algo más Dinámico ..',
#  'Si hay chicos acá que son de neostella que sí que habían varios, . Yo una vez tuve una conversación con mi mentor que uno de mis mentores que es Felipe',
#  'El alcance que tiene es increíble, es increíble, . Las capacidades que en las que cuales iguales supera el Humano son muchas más de lo que la gente cree y yo lo he intentado explicar a él, yo siento que vino una ola que la gente no no ve venir no ve venir y',
#  'puede llegar a ahí, ya le explicaba él, yo me siento como estas personas del gorrito que van con conspiraciones, pero yo le expliqué.',
#  'Puede que llegue una un momento en el que un joven que tiene todas las capacidades para trabajar intenta buscar trabajo, pero no lo va a encontrar, o sea, tiene que tener otras habilidades completamente especiales o diferentes o incluso áreas en las que preferimos los humanos, el el contacto humano como ir al doctor o algo así o un restaurante Pero hay muchas tareas en las cuales la Inteligencia artificial va a ser mejor.',
#  'Eh, esta parte cuestiona un poco la parte ética y las personas que ven en pantalla son dos personas que admiro mucho izquierda, . Robero penheimer. Creo que todos sabemos Quién es por la película de openheimer la escena en la que él me recuerda mucho el uso de la ética es recuerdan cuando por fin se enteran que si es posible hacer la bomba atómica porque descubren que con agua pesada algo así sí se podía hacer la división de de los átomos.',
#  'Y en ese momento él da dos ideas la primera es podemos crear energía o podemos crear una bomba y es como Wow . El problema no es la herramienta el problema es como la usas y a mano derecha Alan torin, que es también otro personaje que admiro mucho él básicamente el padre de la computación y en una escena en en la película que se llama código Enigma .,él descubre con sus compañeros el código Enigma Cómo resolver el código Enigma que era el código de encriptación que usan los nazis.',
#  'Y en un momento de euforia, el resto del equipo se da cuenta que van a atacar un convoy que va navegando y ellos dicen Tenemos la información para detenerlo, vamos, si y lo lo detenemos, .',
#  'si se dan cuenta que ya descubrimos el código Enigma van a usar otro código y tendríamos que empezar nuestro trabajo de cero otro problema ético allí que que yo le agregaría Machine learning algo más, si es los modelos que se están empezando a construir.',
#  'A muchos no se sabe bien que tienen dentro es una caja negra, simplemente funciona Porque los algoritmos que se usaron no son como estas reglas estáticas de la programación habitual en la que tú dices si oprimas este botón Haz esta acción o si te digo que gira la derecha Gira la derecha, No acá es se le está se está se están utilizando algoritmos para que aprenda sobre los datos pero en realidad no se sabe cómo los está aprendiendo. Un ejemplo por a a a la diferencia que se usaba antes los modelos expertos, se llamaba cuando se le intentaban enseñar un modelo Cómo hacer e Cómo Cómo identificar una vaca se le mostraba una vaca, . Pero se le Define de una vez una vaca tiene cachos y una vaca es blanca con negro, Ah pero es que también hay vacas grises o Hay vacas cafés Entonces se le agrega esa regla, si es café y esos modelos no funcionaban muy bien porque había mucha variación y y',
#  'No era era el límite que tenía la programación convencional con estos modelos de Machine learning a partir de los datos, él identifica de una forma que no sabemos que es una vaca puede que los cachos sí sean relevantes, pero de pronto identificar la forma de los ojos, la forma de la cara y demás y demás y esto es un ejercicio simple en el que funciona el modelo pero en realidad no sabemos cómo funciona, . Eso es lo que yo le agregaría adicional con respecto a la bomba atómica y a la descripción del Código de nigma que es.',
#  'Hay incertidumbre en lo que se puede llegar a hacer o o más bien en como podría llegar a funcionar entonces hay un riesgo ahí y un último ejemplo es en chagipt. Había un error en el cual ellos tienen unas reglas en las que no te permite esas respuestas Como por ejemplo, cómo mato al presidente de Estados Unidos él te va a decir, no estoy habilitado para verte esa respuesta, pero personas que se dedican a ciberseguridad se dieron cuenta que si tú le dices Sabes Jugar juego de roles, el modelo te va a decir sí Entonces tú le decías imagina que yo yo estoy en un juego de rol. Yo estoy planeando matar al presidente de mi país, cómo lo mataría Y ahí sí te respondía cómo matarlo.',
#  'Eh, Por qué pasa eso?Porque no entendemos al final, cómo termina funcionando por dentro solo sabemos que funciona ese es el la parte ética que tendremos que tener en cuenta, . Y y pues por ahora sería el Gracias .,para terminar la idea. Es que a lo mucho se demore esta reunión hora y media ahora mucho porque de nuevo Es como ir al gimnasio Es simplemente aprendes de este nuevo tema Lo aplicas, . Entrenas, .,Ya cada uno de forma independiente podrá entrenar, . Por su cuenta el resto de la semana, pero pero tampoco La idea es extenderse que se vuelva una cosa super aburrida e',
#  'y es todo por ahora para la próxima semana la idea sería empezar, . Con el fundamento de cómo funciona los modelos supervisados que son los más ampliamente usados e',
#  'Veremos sus limitaciones sus fortalezas los algoritmos que usualmente se usan ya para entrar en materia y algo que olvidé decir es la idea no es usar directamente los ejercicios que aparecen en los libros, porque los libros van a servir, siempre es decir, vas a el ejercicio que te tiran el libro lo hicieron para que funcionara la idea es hacerlo con datos reales datos, . Enfrentados a un problema real el que vamos a usar por ahora es el de finca raíz, . Los links, . Los van a encontrar en el Kingdom también, . Ahorita los comparto por si acaso y ya empezará a trabajar y hacerlo, no sé si a este punto tengan alguna duda comentario.',
#  'Eh sí, yo tengo una dudita César en Tú decías como que, que eso es libre y así yo tengo Pues un amigo, pues no trabaja en una Estela yo le podría compartir como la información. Sí, sí, sí, sí, sí es completamente abierto completamente abierto en cualquier persona Gracias . Iván señor.',
#  'Si quería preguntarte vamos a manejar personas siguientes clases, quizás python o r o como buena pregunta y solo para recordar no es una clase, es un grupo de estudio O sea quiero que seamos abierto, me entiendes ese concepto no es de tutor y tal no cualquier persona puede tirar un tema y lo discutimos, . Vamos a usar python python, porque es la más ampliamente distribuida r. Se utiliza para . Digamos en las empresas convencionalmente no se usa comparativo con python, es más como para hype performance como alto rendimiento que se usa r. Entonces va a ser python el lenguaje de programación sí señor.',
#  'Eh sí e yo los voy, . Guiando un poco a través de la semana de de cómo podríamos abordarlo de paz La idea es porque hay Eh me pareció una buena idea porque ellos van con ese principio de no meterse a matemática directamente, sino primero enamorarte de lo que se puede llegar a hacer y luego verlo como una caja negra en la cual tú entras salías, básicamente manejar los niveles de abstracción mucho más amables en los que vas desde el modelo grande, que lo entiendes cómo funciona que era lo que les decía ahorita como de la guitarra, que la vas afinando y vas bajando hasta que llegas si si deseamos al nivel de la matemática para entender Por qué funciona de esta manera e entonces ahí, por eso me pareció una buena guía y si quieres yo también voy compartiendo para el capítulo, podríamos usar introductorio. Sí señor.',
#  'Hola César .,creo que ya respondiste una de las preguntas que vamos a usar python, . Yo tengo alguna idea, pues ya y es por eso es que estoy acá cierto un propósito mío una pregunta. Es que librería estaríamos usando para comenzar a adentrarnos con con Machine learning o soltar a este tema apenas vayamos avanzando en el curso buena pregunta también, . Podemos definirlo a como sea la comodidad de hecho podemos usar ambos enfoques Cuáles son los enfoques tiene una librería en la cual maneja estos modelos de forma más e alto nivel mientras los modelos que las librerías que te comentaba que son la de',
#  'Y tensor Flow Una profundidad mayor es decir, tienes que entender el modelo y el algoritmo para poder aplicar correctamente el código el de fase ya alcanza, a ser como una cajita negra en la cual decimos vamos a usar Este algoritmo. Funciona así entras y salidas, entonces podemos usar ambas a mí me parece que de entrada en la que podemos ver cómo funciona y cuáles son los resultados y luego si nos metemos a a las librerías más más fuertes listo entendido Gracias Dale dale alguna otra pregunta chicos.',
#  'Señor Felipe sí, . Bueno me me causa curiosidad como todo este tema de los modelos quería preguntarte de pronto en tu experiencia Ya pues como a nivel profesional Hasta qué punto uno digamos que no no sé si uno alcanza como a desarrollar modelos como tal o uno usa todos estos que ya vienen como ya diseñados de librerías.',
#  'Ya te adelantó algo incluso para los los modelos que son supervisados existe ya algo que se llama autoeml que es básicamente él va a usar tu Data set de entrada. Tú le colocas el target que es la respuesta en el ejemplo de los de los inmuebles todas las características del inmueble, .,área, .,número de habitaciones garajes. Ta ta ta y tienes el precio y él va a cotejar con todos los modelos todos los modelos que que son más, .',
#  'Confiables Se podrían cierto porque posiblemente resuelvan ese problema y te va a entregar la solución es decir, ya hay algo preconstruido que te puede solucionar de cabo rap para lo los problemas supervisados para el resto no?E pero es importante tener en cuenta, cómo funcionan porque es el punto de partida para entender el resto de los modelos, entonces La respuesta es Hay de todas las capas hay algunos que ya están preconstruidos ponle tu, . Stable defusion que simplemente lo uso hay otros que son, . Se llama State of Art que',
#  'Se basan en un en un algoritmo, pero lo superpotencial para que fuese un super algoritmo entonces entrega mejor la solución y ya están los algoritmos bases bases, por ejemplo, hay uno que se llama, .',
#  'Random Forest que ya crearon una versión Ese es el base ya crean una versión super mejorada que se llama, . Xg Boost aumenta estoy confundiendo con otro, . Pero ya crear una versión mejorada de ese.',
#  'Entonces la idea básicamente es aprender a utilizarlos todos, pero entender Cómo funciona el base Por qué es importante entender Cómo funciona el base porque a partir de ahí tomas las decisiones de cuál algoritmo Exacto más, las decisiones técnicas, No simplemente puedes tirarlo a veces Sino tienes que entender Por qué un algoritmo va a funcionar mejor que otro Pero entonces La idea es todos los niveles inténtalos manejar.',
#  'Se me prendió el bombillo otra vez, . Sino que ahorita hablaban de que se puede invitar a cualquier persona a este espacio cierto La idea, es contribuir una persona que no sepa programar en python podría ingresar al grupo que solamente tenga curiosidad de aprender acerca del tema O tendría que tener desarrollada estabilidad O al menos tener un un lenguaje programación en el que esté desarrollando para que le sea útil también comenzar o adentrarse en python, Mira la la buena noticia, en este caso diría yo es que en Machine learning.',
#  'No es tanto el código que utilizas es más. Qué código utilizas O sea no es tanto volumen incluso buenas prácticas se aplican obviamente, pero son más más sencillas porque no tienes que hacer tantas conexiones y demás e',
#  'Yo diría que puede que entre aunque también dependa de esa persona ponerse un poco al día respecto a temas que desconozco Sí este este este grupo es técnico, es decir, no, no, no vamos a hablar tanto como de',
#  'como el modelo de negocio o cosas así o simplemente aprender a usarlo, si no aprender a construirlo y a diseñarlo la idea es llegar a ese nivel de',
#  'de a veces es nuestro piso, sí me entiendes Entonces si la persona busca algo más de negocio, No es aquí si quiere diseñarlo y aprenderlo le le tiramos la mejor documentación que encontremos Y si pregunta pues resolvemos Y es la idea básicamente es la idea que que empieces desde cero pero que si sepas que es técnico Okay perfecto entendido Gracias Dale',
#  'Este video es de un canal de YouTube llamado csb, . Es un Man español que es un divulgador bastante este es uno de mis favoritos favoritos que he visto en respecto al tema, . Ahí les voy a enviar el video por',
#  'e lo que ven en pantalla es una de las cosas que más rompió mi cabeza cuando lo vi es él está hablando del presente el pasado del presente al futuro de la Inteligencia artificial de Machine learning, Obviamente que ya sabemos que va en el corazón, . Una de las cosas que me asombró es, .',
#  'A partir de Incluso el cell supervisor el el entrenamiento supervisado entra en un en un dominio de conocimiento que ya tiene la humanidad Se podría decir que ya tenemos todos, pero cuando lo llegas a intentar combinar en el futuro con ringforcement learning, que es lo que veíamos hace un momento de Tírate al agua y amigo empieza a a funcionar de alguna manera y entiende Cómo funciona el mundo a través de recompensas y acciones que tú haces y demás.',
#  'Y que al final se van a dar cuenta que mira, hasta sube las escaleras en reversa Esto me asombró porque esto es lo que usan esto estos robots que que son de de Boston dynamics, creo que se llama que son los robots literalmente que te hacen acrobacias ellos trabajan con esto, pero me rompió la cabeza porque él decía que era capaz de extender el conocimiento a cosas, que ya no conocíamos.',
#  'que hace cosas que no sabíamos que eran posibles, . Como ejemplo que se me viene a la cabeza ya para cerrar y una de las cosas que asustan, pero que a la vez alegran y incluso desafían es',
#  'Lo la mayoría de modelos utilizan matrices para poder funcionar es decir, son multiplicaciones de matrices matrices, ya saben que es en álgebra, básicamente un conjunto de números que tiene filas y columnas, .',
#  'Y hace multiplicación de matrices, entonces la humanidad siempre ha sabido que la una de las multiplicaciones más normales es como que pila por columna fila porque y vas sumando ese será nuestro algoritmo Pues en Open y eso ya fue hace año hace como 2 años, . Pusieron nuevamente la incertidual a que aprendiera a multiplicar matrices y lo hizo si no, si me demora No falla como 50 veces más rápido de lo que hacía el Humano la multiplicación.',
#  'Eso porque es significativo porque el mismo la misma Inteligencia artificial está logrando mejorarse a sí misma es decir, encontró un problema. Encontró la solución a un problema para algo que ya mismo utiliza Entonces ya van a ser más rápida por esa razón.',
#  'Pasó aquí, superó la Barrera de conocimiento que teníamos nosotros indudablemente y ya muchachos. Eso era todo lo que tenía para esta sesión la idea sería vernos dentro de 8 días, un mismo horario empezar con supervise learning y nada a darme listo.',
#  'Listo Entonces porque Disculpen casos de uso en los que se puede utilizar Messenger con modelos supervisados es, . Supongo que tienes un modelo que es capaz de identificar materiales que puede ser metálico plástico etcétera etcétera una aplicación que puedes hacer, . Como lo muestra en este video, . La chica lo que logró fue crear un modelo que sea capaz de identificar en una cinta transportadora los materiales que son basura pero al final puede realizar una clasificación sobre ellos Entonces .eso a nivel sí se puede automatizar en una industria y demás lo que tú podrías hacer es recolectar toda la basura y haces como reciclaje automático Simplemente te los va apartando a partir de materiales obviamente se necesitarían los sensores que capturan la información para saber los datos.',
#  'Que representan un elemento metálico un elemento de plástico y demás, . Pero lo que se puede lograr hacer es como lo pueden ver en pantalla identificar el papel y identificar el plástico identificar lo que sí completamente es basura, . En utilizando un modelo de Machine learning y cuándo es la clasificación Pues automatizas, esa parte y si te permite cosas como éstas, otro caso de uso es este cuando cuando yo lo vi me enamoró de hecho hace mucho tiempo cuando Yo comencé en la Estela .,alguna vez le pregunté a alguien si tenía acceso a estos datos en una universidad o algo así porque me da mucha ilusión es poder detectar el cáncer o algún tumor O algo parecido que sucede en nuestro cuerpo cuando se hacen radiografías se puede encontrar ya saben algunas anomalías el doctor Zara mejor en diferentes partes del cuerpo.',
#  'Que a veces al ojo humano es difícil de reconocer y a veces tienes que hacer más pruebas para poder identificar que qué es lo que sucede si es benigno o maligno, . Con bachelet, se logró crear modelos que a través de la radiografía de una foto puede hacer una clasificación de decir si posiblemente podría ser algo maligno o benigno y a pesar de que no es un veredicto final reduce tiempo y te da un poco más de información, por supuesto aquí hay que tener con los pasos positivos los pasos negativos y demás que a que me recuerdan ustedes, qué te dice que tiene que que si es maligno pero en realidad no lo es o te dice que es benigno, pero en realidad maligno cosas, así son las que tenemos que lidiar como al menos esto con un modelo lo suficientemente. Bueno, puedes alcanzar a lograr a sugerirle al doctor si tiene que hacer un análisis más profundo o no, entonces cosas como esta que ayudan a la humanidad siempre son bienvenidas, si se dan cuenta en',
#  'Así en esta radiografía es un modelo de Machine learning a través de muchos casos que ha utilizado para entrenarse que ya sabe que son malignos o son malignos, es capaz de detectar, cuál podría ser maligno Y por último hay uno que es de mis favoritos también, . El que viene en pantalla, se llama María José Alonso le dicen Che Alonso él es un desarrollador español. Gracias a el programa soy fan número uno del seika a la ciberseguridad Pero últimamente también lo ha apoyado mucho de ella y porque ya sabemos que es lo que más se está pegando fuerte, .Él en este en este preguntas si yo le doy Play ustedes escuchan Sí yo le doy, sí se escucha Sí sí se escucha Ah listo. Entonces déjame que le hablé el audio yo lo',
#  'Eh, Solo una introducción el contexto es sabemos que ahorita hay Deep pakes que es Pues clonar tu voz puedes clonar tu rostro en un video, . Puedes hacerlo ya en tiempo real incluso, pues las personas de ciberseguridad han tenido que lidiar con esto y Buscar soluciones para poder, . Darle peso o una herramienta que contrarreste este tipo de vulnerabilidades, porque yo puedo clonar la cara y la voz de el dueño de mi empresa y robar una cosa, así no sé, pero yo no estoy escuchando, no sé si todos se escuchó, pero ya no, Ah rayos o de pronto se escucha cuando yo estoy hablando, me da la impresión. Sí quizás.',
#  'ahí sí, se escucha cierto, Sí no, Ah bueno igual Les explico Y si algo Les envío los videos ahorita también en el chat básicamente es lo que dice es cuando ya se genera una native fake, tenemos que buscar medidas de contrarrestar y es a través de huellas digitales, que es cosas que nos representen a nosotros como humanos y específicamente al individuo Entonces como de los .,supervisados se ha podido entrenar para que por ejemplo detecte el parpadeo de tus ojos la frecuencia con la que lo haces Y puede decir si eres tú o no eres tú también puedes detectarse incluso con cámaras muy buenas, se puede detectar el papita el palpitar del corazón a través de de los pómulos Cómo se van sonrojando, es algo que es indetectable para lo malo, pero que una máquina, si lo puede detectar con los algoritmos correctos, pero encontrar esa frecuencia de poder definir si es válida o no se hace con los modelos progresado que',
#  'Valía que ya fue previamente entrenado con casos reales y Que de momento la Inteligencia artificial generativa no genera modelos con tanta precisión como para que también simule en el palpitar del corazón o que por ejemplo, simulen, . Cuando tú giras la cara en la cámara, . Tú morfología no Cuántas son las dimensiones que a veces la generativa cuando lo giras se se hay defectos, Eh entonces modelos supervisados están utilizando para poder contrarrestar este tipo de medidas.Él explica más detalle todo esto, . Indica que otros patrones están usando, por ejemplo, indica que ya la validación por voz Es inválida porque cualquiera puede prolongar tubos con una precisión increíble Ah De hecho, Mira acá, ahí se puede ver cómo está reconociendo los ojos y está identificando Cuántas veces parpadea, si no parpadeas y demás y demás de momento se puede reconocer, . Tengo casi la impresión.',
#  'Futuro una máquina va a ser incluso difícil que reconozca este tipo de cosas Si nosotros ya estamos perdidos Supongo que la máquina también este es el que detecta, . Los el papi tarda el corazón a través del rostro ahí ahí lo alcanza. A lo que ven acá es la frecuencia el golpista del corazón a través de del rostro y cosas, así son las que se han tenido que utilizar Entonces esta es la fe, ahí se puede ver un poco Como no sucede ese patrón y y bueno, esos son el tipo de cosas que podemos construir con los modelos supervisado y a pesar de que lo que vamos a ver ahorita es muy básico, son las fases con las que funcionan muchos modelos y el supervisor se extiende o los principios del supervisados se extiende también a las demás ramas, em no es exclusivo Ah chicos, Si llegan a tener alguna pregunta comentario, por favor sin',
#  'Déjenme pasar entonces al siguiente paso de la presentación y por supuesto nuestro último ejemplo es el deprecia y los inmuebles el precio de los inmuebles que es el que vamos a ver el día de hoy em de cómo si una forma más técnica, . El Data sed lo pueden encontrar, Denme también lo comparto en este link es el Data set es una muestra que nos puede servir para el ejercicio de hoy igual Ahorita les comparto un reto que también tiene el dato hacer con La goma de modificaciones de las cuales también ya vamos a volver entonces acá solo tomé un screenshot de la muestra para poder explicar qué es lo que sé qué es lo que se estaría bien, . Tenemos los teachers que son las características.',
# ...
#  'Sí pero no, espera Creo que me estoy saltando la parte del Back propagation, porque esto ya son problemas más avanzados donde están la propagation tiene que estar por aquí de modo, pero Les explico más o menos la idea de pronto con una imagen nos vamos haciendo más a la idea de pronto cuando está de softwares por funcionar entonces La idea es muy parecida a lo que ya hemos visto en sesiones anteriores que es yo meto las entradas eso me entrégame una salida cualquiera yo comparo la salida veo que la estoy embarrando hay un error horrible y lo que hago es que',
#  'Gustar otra vez el ejercicio de la guitarra toco la guitarra suena un asco ajusto la vuelvo a tocar ya no se da Tabasco pero suena todavía un asco vuelvo a ajustar. Vuelvo a ajustar. Vuelvo a ajustar la diferencia. Es que aquí ajustas una red neuronal y ahí es donde hay una una pequeña diferencia que es el ajuste empieza desde la parte superior o desde la salida empieza desde la serie en este caso en esta red neuronal desde la parte superior que vendría siendo yo te meto estas entradas, Yo sé que la respuesta correcta es que la persona es de recursos humanos, pero tú me estás tirando, pues probabilidades hacia el aire, me dices cualquier tipo de dato a cada 0.5 acá 0.5 y acá ser una vaina así obviamente estamos Entonces yo qué hago calculo la diferencia como lo hemos hecho y empiezo a ajustar Entonces es modifico los pesos de esta capa que se encuentra justo en la salida todos estos pesos que son las líneas que',
#  'Pero a su vez cuando yo modifico estos empiezo a modificar también los de la capa anterior Los de la capa anterior Los de la capa anterior y el ajuste se empieza a propagar, por eso se llamaba propagation empiezo desde desde la salida ajusto Desde allí y empiezo a ajustar todos los pesos que venden de ahí para atrás sigue, . Caía está capa. Está capa también empieza a calcular el error y empieza a propagar ese error o ese ajuste a partir del r. Y así hago con cada una de las entradas que tengo que corregir sí, cálculo empezó a jugar cálculo empiezo sí Entonces ahí es donde se se empieza a ajustar y Cómo afinar la red neuronal Pero entonces hay algo también adicional que sucede que es una cosa que se llama optimizadores y learning rate el lr rate, ya lo vemos como medio tocado.',
#  'Eh ya está acá, entonces hay una cosa llamada learning rates que está relacionado con el cómo se llamaba eso el landscape, si no estoy mal que el landscape era ML Last creo que así y aquí nos vamos por las imágenes, No creo que más controlado todo así se volvió el nombre, pero algo así de hecho hay una imagen en el libro que se ve mejor, pero no me interesa, era algo más o menos así este sí era así se llama las que no lo estoy escribiendo mal es decir.',
#  'Estamos nos podría servir para entender sí, y que si se acuerdan sesiones anteriores, veamos que a veces este mapa de error, que aparecía el mapa es básicamente, . Dados los hiper parámetros que estoy escogiendo, cuánto error me está generando Sí y la idea es encontrar el error mínimo bajar la montaña. Lo más posible. Sí Entonces está relacionado este landscape está relacionado con el learning rate porque él El rey básicamente me dice cuántos pasitos de hecho esta imagen está perfecta para entenderlo mejor. Sí, el el rey es Qué tan grande, va a ser los pasitos que voy a tomar para poder bajar esa montaña Sí entonces a ver dónde está la imagen Acá está perfecto, Sí que sería los picos más altos significan error.',
#  'Los más bajos significan valores óptimos porque es donde tengo el menor error, Sí y ahí es donde están mis súper parámetros y ahí es donde hace hice el ajuste bastante bien. Entonces si yo doy pasos muy largos estoy saltando de montaña entre montaña. Estoy Si me entiendes, No no estoy llegando a a a la parte inferior si doy paso es muy pequeños, me tomará mucho tiempo bajar la montaña y llegar al punto inferior sí, pero si tomo El Paso indicado voy a llegar a él él se llama global mínimo que Recuerden que puede haber un local mínima, por ejemplo acá El de acá mano izquierda, podría ser un local mínima esté a la derecha podría ser un global mínima, o sea, el el global más mínimo de todo el valle por así decir este podría ser un buen resultado, pero no el más óptimo Sí y la tarea está en encontrar ese ese valor zip entonces para hacer eso hay.',
#  'Que se llaman optimizadores y solamente para para cerrar como lo del Lenin rate, entonces acá, por ejemplo, te dice bajo Lenin rate epoch es básicamente iteraciones, Cuántas interacciones, estás haciendo para para llegar a ese valor mínimo Entonces si se dan cuenta cierra el link raid es muy es muy corto, es pequeño, me va a tomar muchas iteraciones en bajar, muchas Y eso puede ser computacionalmente muy muy pesado. Sí, . Si el learning rate es muy alto, puede que yo salté entre montaña y montaña y me quede con un error insuperable porque nunca voy a llegar a ese a ese Valle pequeño a ese Globo A ese global, mínima acá el amarillo, si es que son muy altos ahí sí, es que estoy saltando demasiado, pero el feed Perfecto es el rojo, voy bajando y descendiendo a un ritmo constante y pudiendo encontrar el valor mínimo del error y los hiperparametros Vale entonces.',
#  'Eh Así es como funciona hay muchas técnicas que se utilizan para poder ayudarle a la red neuronal a encontrar ese global mínimo, por ejemplo se utilizan varios puntos en el valle Sí en vez de solamente usar un punto, . Cómo aparece cómo aparece aquí pone tú que yo colocó 10 Caminantes imaginémonos como si fueran Caminantes colocó 10 Caminantes Sin Caminantes computacionalmente más caro, pero seguramente más rápido voy a encontrar este Valle pequeño, . Otra es hay un algoritmo ese sí nunca lo terminé de entender afirman que que es diseño de un algoritmo para poder inicializar los pesos que tiene la la red neuronal Recuerden que los pesos son como cada flechita que conecta a la red neuronal, . De una manera que sea más fácil empezar a encontrar los varones, esa ese sí no lo tengo tan fresco en mi memoria Pero hay uno, que a mí me parece muy chévere.',
#  'Que se llaman optimizadores de hecho esta chica como siempre habla de eso ese bloque es muy bueno, es de indios, pero a ver si son buenos que nos este Esto fue una pasada cuando yo lo leí cuando leí fue brutal, me acuerdo mucho de mi cara de zombie, a ver si por acá Es que así no se ve tan chévere, a ver si una obviamente una imagen dice más que mil palabras los que no es el bit, a ver si el gif nos ayuda porque hay diferentes tipos de optimizadores de hecho este es el que está buscando este es una china, a ver si podemos ver aquí Ah Ahí está vamos a ver entonces usualmente como como.',
#  'Estamos acostumbrados a que funcione esperar si usó los dedos de que sí, este ese que estaba como raro decir ahí está, . Este qué entonces si se dan cuenta a términos sencillos de ver hay como diferentes Caminantes uno se están demorando más que otros, por ejemplo, el el rojo que es como amarillo, ya llegó ese azul acaba de llegar y los otros se quedaron por allá arriba. Sí, esos son algoritmos diferentes que se usan para hacer el la bajada de se llama algo así el descendiente del gradiente, o sea, Bajar bajar la la colina y qué pasa?Hay algunos algoritmos, por ejemplo, quiero que le paren bolas al que aparece como',
#  'Amarillito se vuelve a ejecutar y si se dan cuenta su comportamiento parece el de una pelota, sí Y es porque en vez de utilizar solamente el learning rate Cómo sé yo fuera un caminante y dar un paso y un paso y un paso empiezo a meterle Ah es que si vienes con mucha velocidad corriendo, digamos, así tienes una inercia, se podría interpretar así, entonces tiendes a seguir en esa dirección y eso acelera el aprendizaje, Porque si se dan cuenta puede descender más rápido porque encuentra, o sea, se apoya en en en en en estas trayectorias, que ya tenía, por ejemplo, previamente Y es más fácil que de 100 mientras si yo doy paso a paso y voy calculando y simplemente doy pasó. Si no considero como esa trayectoria me demoraré más Sí cada uno de estos algoritmos, tiene un comportamiento diferente que sirve para',
#  'No hace caso, no sé como otras otra vez esto Qué es un un hiper parámetro, el que suele funcionar bastante bien Por lo general, el rms en esta ocasión le está ganando Pero entonces, . Suele suceder de esa manera, eso también lo van a encontrar ahí en el libro Entonces qué pasaría para combinar las dos ideas que tendríamos entonces meto las entradas las entradas me van a meter, me van a calcular algo aleatorio, porque la red neuronal no funciona bien de de entrada cálculo. Las salidas hago eso con muchas ta ta ta ta ta ta cálculo las salidas, . Globales cálculo el error con el error, puedo definir Cuál es el gradiente y moverme la dirección correcta, es decir, calcule el error en todas las dimensiones Ahora sí, cálculo el gradiente y empiezo a hacer la propagación del error del gradiente en todas las capas, Sí y lo hago.',
#  'Esa ese cálculo del gradiente y el cálculo del error lo hago con un optimizador que me facilita ese movimiento más rápido hacia el punto mínimo del error, eso a términos globales ya después Cómo hacer una una profundización, . De cómo funciona cada uno de los componentes, pero así es como funciona, . Da igual Alejandro Cuídense Dale entonces así es como funcionaría más o menos una red neuronal Cómo se podría entrenar em ya más adelante, vamos a ver también Qué son los deportes Cómo se miden ciertas métricas, Cómo se maneja, esto del vanishing del Explorer pero a términos generales, pues es es cómo funciona y los componentes que que le sigue, . Déjame ver si no me he perdido De nada más aquí hay dos términos que es como',
#  'Learning, pero eso ya es un poco más adelante más avanzado aquí, por ejemplo términos que les comentaba learning rate el optimizador el batch size que es básicamente Con cuántos quiero calcular sí cálculo con todo el dataset, pues me voy a demorar más, si cálculo como una muestra me voy a demorar menos pierdo precisión, pero me me acelero ese ese ese aprendizaje función de activación me sirve para tener curvas, . Número de iteraciones esto también lo vamos a ver que es básicamente si ya entreno muchas veces una red neuronal puede que tenga el mismo comportamiento que nos pasó con el Random Forest que es hago overfield, va a funcionar perfectamente bien para para el training Pero va a fallar para todo lo que nos atreve Sí entonces ahí también se tiene ese ese en cuenta el número de iteraciones, por eso se dan cuenta esos son como los componentes que se empezaron a tener en cuenta al momento de entrenar una una',
#  'Cómo van hasta ahí este tema es denso pero cuando yo le retiró, estáis viendo Bueno sí, pues está, está bien, pero está muy chévere muy interesante acá No acá, No acá, lo que les guste Eso a mí también, o sea, este es de los temas más densos pero fácil más brutales, o sea más brutales de nuevo porque estamos Aprendiendo a hacer esto primero porque vamos a hacer una regresión, vamos a construir una red neuronal que haga Exactamente lo mismo que estamos haciendo con cactus y con auto emer, simplemente por las risas, o sea, sabemos que con cactus Puede que sea suficiente De hecho, no para esta semana con Carlos Puede que sea suficiente, pero para aprender cómo funciona una red neuronal. Lo vamos a hacer aquí con una red neuronal también vamos a pegarle aquí otro que se llama red normal netbook, pero al final la idea es construir.',
#  'Como les comentaba algo llamado auch, que ahora ya creo que con el con el con el preámbulo que ya tenemos de de que es una red neuronal, vamos a poder entender un poco mejor Cómo funciona el autor entonces Y como otra arquitectura puede ser funcional en redes normales Por lo general, la red neuronal es de regresión, van a ver que tienen siempre las mismas el mismo número de neuronas en todas las capas es decir, la la información Se transporta, sí, O a lo mucho Hay algún embudo, pero es porque quiero sintetizar algunos datos, . Pero esa es la forma en la que usualmente tienen, . Las redes neuronales de regresión suelen ser densamente conectadas y con el mismo número de neuronas en cada capa sencillo, . Pero nosotros queremos construir algo llamado.',
#  'Al digamos al a la forma original es una visión de Espejo se entiendes, o sea, la mitad derecha izquierda, suele ser igual acá de hecho. Creo que se ve mejor Entonces por qué Nosotros queremos hacer eso y está este ejemplo de La Mona Lisa nos va a ayudar a entender, . Nosotros queremos hacer esto aquí se ve mejor sí, porque lo que tú puedes lograr con autoencoder y el dengue el cobre y de cobre del autor y es lo que va a hacer es a la salida, me debería reconstruir los mismos datos, es decir toda la información que yo le tiré el precio la información que le tiré de',
#  'Quien lo creó todos esos datos debería construirme los muy parecido siempre se pierde información, pero es muy parecido Por qué se hace esto porque el autor a mí me permite que en la mitad se filtren los patrones más relevantes es decir, él va a quitar todo el ruido que hay alrededor aquí con la imagen número dos también se entiende Esta es la la imagen dos original la paso por el autor la reconstruye, pero ahora esta parte que se llama espacio embebido en Being space que es la parte de la mitad esa parte va a contener la información más relevante que contiene el número dos ya no me interesa saber, por ejemplo, No lo sé si si tiene algunos píxeles desviados o si llega a tener muchos negros alrededor y demás no me interesa. Yo soy capaz de Identificar y reconstruir el número dos eso porque es útil al momento de hacer.',
#  'Lo que vamos a hacer de identificar los layers es útil Porque si alguna de esas reconstrucciones se sale del margen, lo podemos detectar porque esto lo que hace como siempre es generalizar yo entreno esta red normal con muchos datos muchos muchas imágenes de número dos muchas imágenes de La Mona Lisa o cualquier otra cosa mucha información de carros. Yo la meto como mucha información ella lo que hace es aprender esos patrones aprende los patrones relevantes que me dice Ah esto es un Chevrolet el Chevrolet tiene tantas configuraciones y demás de nuevo Yo estoy asumiendo esto, pero cómo funciona por dentro ni idea, pero lo aprendió él encuentra sus patrones base los vuelve a reconstruir, pero en la reconstrucción si alguno de sus datos llega a fallar, es decir, hay un error muy grande en la reconstrucción en alguno de esos datos se puede considerar como una anomalía y Adivinen cuál anomalía queremos encontrar si la reconstrucción del precio es muy grande eso.',
#  'Queremos encontrar y de ahí viene la idea de la orden de construir y de hecho con esto ya para complementar y ya no los quiero, .,Pues tomar más tiempo de ustedes con esto también se hacen Eh modelos generativos Esta es la base de modelos generativos. Si están interesados en modelos generativos, el libro que Les recomiendo es este del pajarito. Quién era de Deep learning este Man habla de hecho justamente yo estaba leyendo de este capítulo porque creo que me va a tocar hacer datos sintéticos también te sirve para hacer datos sintéticos acá Cómo es la imagen pueden ver por ejemplo, . Eh, el autor se entrenó para que fuera reconstruir ropa y yo puedo ahora reko.',
#  ...]

# %%
# %%time

# Embed all texts in batches
text_chunk_embeddings = embedding_model.encode(text_chunks,
                                               batch_size=32,
                                               # you can use different batch sizes here for speed/performance, I found 32 works well for this use case
                                               convert_to_tensor=True)  # optional to return embeddings as tensor instead of array

text_chunk_embeddings
# Out:
# CPU times: total: 53min 19s
# Wall time: 4min 47s
# tensor([[-0.0152,  0.0161, -0.0492,  ...,  0.0106, -0.0394, -0.0349],
#         [-0.0342,  0.0889, -0.0104,  ...,  0.0263,  0.0218, -0.0037],
#         [-0.0203,  0.0660, -0.0530,  ...,  0.0323, -0.0198, -0.0195],
#         ...,
#         [-0.0270, -0.0313, -0.0291,  ..., -0.0573, -0.0180, -0.0306],
#         [-0.0161, -0.0514, -0.0222,  ..., -0.0194, -0.0295, -0.0322],
#         [-0.0049, -0.0089, -0.0266,  ..., -0.0140, -0.0268,  0.0056]])

# %% [markdown]
# That's what I'm talking about!
#
# A ~4x improvement (on my GPU) in speed thanks to batched operations.
#
# So the tip here is to use a GPU when you can and use batched operations if you can too.
#
# Now let's save our chunks and their embeddings so we could import them later if we wanted.

# %% [markdown]
# ### Save embeddings to file
#
# Since creating embeddings can be a timely process (not so much for our case but it can be for more larger datasets), let's turn our `pages_and_chunks_over_min_token_len` list of dictionaries into a DataFrame and save it.

# %%
# Save embeddings to file
text_chunks_and_embeddings_df = pd.DataFrame(pages_and_chunks_over_min_token_len)
embeddings_df_save_path = "text_chunks_and_embeddings_df.csv"
text_chunks_and_embeddings_df.to_csv(embeddings_df_save_path, index=False)

# %% [markdown]
# And we can make sure it imports nicely by loading it.

# %%
# Import saved file and view
text_chunks_and_embedding_df_load = pd.read_csv(embeddings_df_save_path)
text_chunks_and_embedding_df_load.head()
# Out:
#    Start time  End time                                             Source  \
# 0        21.8      36.7  MML-SG Training meeting (2024-02-21 19_06 GMT-...
# 1        42.8      75.5  MML-SG Training meeting (2024-02-21 19_06 GMT-...
# 2        86.7     147.2  MML-SG Training meeting (2024-02-21 19_06 GMT-...
# 3       147.0     179.0  MML-SG Training meeting (2024-02-21 19_06 GMT-...
# 4       181.1     236.9  MML-SG Training meeting (2024-02-21 19_06 GMT-...
#
#                                       sentence_chunk  chunk_char_count  \
# 0  Sí sí, se puede ver listo amplia, grande. Eso ...               136
# 1  Que pues surgió de de uno que existía en Berlí...               423
# 2  Y finalmente una una demo o un un primer plano...               748
# 3  Momentos de incluso oportunidades laborales in...               396
# 4  Y .,para aclarar, . El grupo es más cercano a ...               742
#
#    chunk_word_count  chunk_token_count  \
# 0                22              34.00
# 1                83             105.75
# 2               130             187.00
# 3                61              99.00
# 4               135             185.50
#
#                                            embedding
# 0  [-1.52003458e-02  1.60651207e-02 -4.91986498e-...
# 1  [-3.42119262e-02  8.89105499e-02 -1.03912214e-...
# 2  [-2.02538352e-02  6.59917817e-02 -5.29866256e-...
# 3  [-4.50983942e-02  1.09780550e-01 -2.96392590e-...
# 4  [-1.06098512e-02  2.30875835e-02 -2.39032283e-...

# %% [markdown]
# ### Chunking and embedding questions
#
# > **Which embedding model should I use?**
#
# This depends on many factors. My best advice is to experiment, experiment, experiment!
#
# If you want the model to run locally, you'll have to make sure it's feasible to run on your own hardware.
#
# A good place to see how different models perform on a wide range of embedding tasks is the [Hugging Face Massive Text Embedding Benchmark (MTEB) Leaderboard](https://huggingface.co/spaces/mteb/leaderboard).
#
# > **What other forms of text chunking/splitting are there?**
#
# There are a fair few options here too. We've kept it simple with groups of sentences.
#
# For more, [Pinecone has a great guide on different kinds of chunking](https://www.pinecone.io/learn/chunking-strategies/) including for different kinds of data such as markdown and LaTeX.
#
# Libraries such as [LangChain also have a good amount of in-built text splitting options](https://python.langchain.com/docs/modules/data_connection/document_transformers/).
#
# > **What should I think about when creating my embeddings?**
#
# Our model turns text inputs up to 384 tokens long in embedding vectors of size 768.
#
# Generally, the larger the vector size, the more information that gets encoded into the embedding (however, this is not always the case, as smaller, better models can outperform larger ones).
#
# Though with larger vector sizes comes larger storage and compute requirements.
#
# Our model is also relatively small (420MB) in size compared to larger models that are available.
#
# Larger models may result in better performance but will also require more compute.
#
# So some things to think about:
# * Size of input - If you need to embed longer sequences, choose a model with a larger input capacity.
# * Size of embedding vector - Larger is generally a better representation but requires more compute/storage.
# * Size of model - Larger models generally result in better embeddings but require more compute power/time to run.
# * Open or closed - Open models allow you to run them on your own hardware whereas closed models can be easier to setup but require an API call to get embeddings.
#
# > **Where should I store my embeddings?**
#
# If you've got a relatively small dataset, for example, under 100,000 examples (this number is rough and only based on first hand experience), `np.array` or `torch.tensor` can work just fine as your dataset.
#
# But if you've got a production system and want to work with 100,000+ embeddings, you may want to look into a [vector database]( https://en.wikipedia.org/wiki/Vector_database) (these have become very popular lately and there are many offerings).
#
# ### Document Ingestion and Embedding Creation Extensions
#
# One major extension to the workflow above would to functionize it.
#
# Or turn it into a script.
#
# As in, take all the functionality we've created and package it into a single process (e.g. go from document -> embeddings file).
#
# So you could input a document on one end and have embeddings come out the other end. The hardest part of this is knowing what kind of preprocessing your text may need before it's turned into embeddings. Cleaner text generally means better results.

# %% [markdown]
# ## 2. RAG - Search and Answer
#
# We discussed RAG briefly in the beginning but let's quickly recap.
#
# RAG stands for Retrieval Augmented Generation.
#
# Which is another way of saying "given a query, search for relevant resources and answer based on those resources".
#
# Let's breakdown each step:
# * **Retrieval** - Get relevant resources given a query. For example, if the query is "what are the macronutrients?" the ideal results will contain information about protein, carbohydrates and fats (and possibly alcohol) rather than information about which tractors are the best for farming (though that is also cool information).
# * **Augmentation** - LLMs are capable of generating text given a prompt. However, this generated text is designed to *look* right. And it often has some correct information, however, they are prone to hallucination (generating a result that *looks* like legit text but is factually wrong). In augmentation, we pass relevant information into the prompt and get an LLM to use that relevant information as the basis of its generation.
# * **Generation** - This is where the LLM will generate a response that has been flavoured/augmented with the retrieved resources. In turn, this not only gives us a potentially more correct answer, it also gives us resources to investigate more (since we know which resources went into the prompt).
#
# The whole idea of RAG is to get an LLM to be more factually correct based on your own input as well as have a reference to where the generated output may have come from.
#
# This is an incredibly helpful tool.
#
# Let's say you had 1000s of customer support documents.
#
# You could use RAG to generate direct answers to questions with links to relevant documentation.
#
# Or you were an insurance company with large chains of claims emails.
#
# You could use RAG to answer questions about the emails with sources.
#
# One helpful analogy is to think of LLMs as calculators for words.
#
# With good inputs, the LLM can sort them into helpful outputs.
#
# How?
#
# It starts with better search.

# %% [markdown]
# ### Similarity search
#
# Similarity search or semantic search or vector search is the idea of searching on *vibe*.
#
# If this sounds like woo, woo. It's not.
#
# Perhaps searching via *meaning* is a better analogy.
#
# With keyword search, you are trying to match the string "apple" with the string "apple".
#
# Whereas with similarity/semantic search, you may want to search "macronutrients functions".
#
# And get back results that don't necessarily contain the words "macronutrients functions" but get back pieces of text that match that meaning.
#
# > **Example:** Using similarity search on our textbook data with the query "macronutrients function" returns a paragraph that starts with:
# >
# >*There are three classes of macronutrients: carbohydrates, lipids, and proteins. These can be metabolically processed into cellular energy. The energy from macronutrients comes from their chemical bonds. This chemical energy is converted into cellular energy that is then utilized to perform work, allowing our bodies to conduct their basic functions.*
# >
# > as the first result. How cool!
#
# If you've ever used Google, you know this kind of workflow.
#
# But now we'd like to perform that across our own data.
#
# Let's import our embeddings we created earlier (tk -link to embedding file) and prepare them for use by turning them into a tensor.

# %%
import random

import torch
import numpy as np
import pandas as pd

device = "cuda" if torch.cuda.is_available() else "cpu"

# Import texts and embedding df
text_chunks_and_embedding_df = pd.read_csv("text_chunks_and_embeddings_df.csv")

# Convert embedding column back to np.array (it got converted to string when it got saved to CSV)
text_chunks_and_embedding_df["embedding"] = text_chunks_and_embedding_df["embedding"].apply(
    lambda x: np.fromstring(x.strip("[]"), sep=" "))

# Convert texts and embedding df to list of dicts
recording_transcription_and_chunks = text_chunks_and_embedding_df.to_dict(orient="records")

# Convert embeddings to torch tensor and send to device (note: NumPy arrays are float64, torch tensors are float32 by default)
embeddings = torch.tensor(np.array(text_chunks_and_embedding_df["embedding"].tolist()), dtype=torch.float32).to(device)
embeddings.shape
# Out:
# torch.Size([1118, 768])

# %%
text_chunks_and_embedding_df.head()
# Out:
#    Start time  End time                                             Source  \
# 0        21.8      36.7  MML-SG Training meeting (2024-02-21 19_06 GMT-...
# 1        42.8      75.5  MML-SG Training meeting (2024-02-21 19_06 GMT-...
# 2        86.7     147.2  MML-SG Training meeting (2024-02-21 19_06 GMT-...
# 3       147.0     179.0  MML-SG Training meeting (2024-02-21 19_06 GMT-...
# 4       181.1     236.9  MML-SG Training meeting (2024-02-21 19_06 GMT-...
#
#                                       sentence_chunk  chunk_char_count  \
# 0  Sí sí, se puede ver listo amplia, grande. Eso ...               136
# 1  Que pues surgió de de uno que existía en Berlí...               423
# 2  Y finalmente una una demo o un un primer plano...               748
# 3  Momentos de incluso oportunidades laborales in...               396
# 4  Y .,para aclarar, . El grupo es más cercano a ...               742


# %% [markdown]
# Woah!! Now that was fast!
#
# ~0.00008 seconds to perform a dot product comparison across 1680 embeddings on my machine (NVIDIA RTX 4090 GPU).
#
# GPUs are optimized for these kinds of operations.
#
# So even if you we're to increase our embeddings by 100x (1680 -> 168,000), an exhaustive dot product operation would happen in ~0.008 seconds (assuming linear scaling).
#
# Heck, let's try it.

# %%
larger_embeddings = torch.randn(100 * embeddings.shape[0], 768).to(device)
print(f"Embeddings shape: {larger_embeddings.shape}")

# Perform dot product across 168,000 embeddings
start_time = timer()
dot_scores = util.dot_score(a=query_embedding, b=larger_embeddings)[0]
end_time = timer()

print(f"Time take to get scores on {len(larger_embeddings)} embeddings: {end_time - start_time:.5f} seconds.")
# Out:
# Embeddings shape: torch.Size([111800, 768])
# Time take to get scores on 111800 embeddings: 0.02064 seconds.

# %% [markdown]
# Wow. That's quick!
#
# That means we can get pretty far by just storing our embeddings in `torch.tensor` for now.
#
# However, for *much* larger datasets, we'd likely look at a dedicated vector database/indexing libraries such as [Faiss](https://github.com/facebookresearch/faiss).
#
# Let's check the results of our original similarity search.
#
# [`torch.topk`](https://pytorch.org/docs/stable/generated/torch.topk.html) returns a tuple of values (scores) and indicies for those scores.
#
# The indicies relate to which indicies in the `embeddings` tensor have what scores in relation to the query embedding (higher is better).
#
# We can use those indicies to map back to our text chunks.
#
# First, we'll define a small helper function to print out wrapped text (so it doesn't print a whole text chunk as a single line).

# %%
# Define helper function to print wrapped text 
import textwrap


def print_wrapped(text, wrap_length=80):
    wrapped_text = textwrap.fill(text, wrap_length)
    print(wrapped_text)

# %% [markdown]
# Now we can loop through the `top_results_dot_product` tuple and match up the scores and indicies and then use those indicies to index on our `pages_and_chunks` variable to get the relevant text chunk.
#
# Sounds like a lot but we can do it!

# %%
print(f"Query: '{query}'\n")
print("Results:")
# Loop through zipped together scores and indicies from torch.topk
for score, idx in zip(top_results_dot_product[0], top_results_dot_product[1]):
    print(f"Score: {score:.4f}")
    # Print relevant sentence chunk (since the scores are in descending order, the most relevant chunk will be first)
    print("Text:")
    print_wrapped(recording_transcription_and_chunks[idx]["sentence_chunk"])
    # Print the page number too so we can reference the textbook further (and check the results)
    print(f"Start time : {recording_transcription_and_chunks[idx]['Start time']}")
    print(f"End time : {recording_transcription_and_chunks[idx]['End time']}")
    print(f"Source : {recording_transcription_and_chunks[idx]['Source']}")
    print("\n")
# Out:
# Query: 'que es Medellin Machine Learning?'
#
# Results:
# Score: 0.7920
# Text:
# Sí sí, se puede ver listo amplia, grande. Eso es, . Nada muchachos, Bienvenidos
# a Machine learning Medellín Machine learning Story Group
# Start time : 21.8
# End time : 36.7
# Source : MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv
#
#
# Score: 0.7463
# Text:
# Alguna inquietud o todavía no hay si el silencio siempre lo tomó como estoy todo
# bien procesando, yo creo. Okay, Okay yo creo que lo que les digo haciendo un
# ejercicio es de cero, nos va a ayudar mucho a entender cómo funciona de acuerdo
# de acuerdo, Déjenme Les comparto también otra parte esta es la otra cara de de
# The Machine learning. Es por lo general. Se trabaja el Machine learning. Ya
# tienes datos, .,Ya tienes de dónde agarrar de dónde tirar para para poder tener
# información y procesar estos datos correctamente y de hecho lo que les quiero
# mostrar a ustedes es el Script que se usa para extraer esta información.
# Start time : 1857.9
# End time : 1917.0
# Source : MML-SG Training meeting (2024-04-10 19_11 GMT-5).csv
#
#
# Score: 0.7279
# Text:
# Correcto Entonces si quieres, .,HM lo que quiero mostrarles hoy es la primera
# etapa que vendría A la meditación proyecto de Machine learning, es recolectar
# los datos, . Los datos Por lo general. El mundo real no vienen tan limpios como
# le gustaría pero es parte del trabajo, aunque este tipo de tareas ya lo haría
# otro rol que se llamaríamos como de ir a ingeniero cosas, así que se que son las
# personas encargadas de recolectar los datos y prepararlos pero en este caso pues
# para que lo conozcan cómo funciona de cero, . La idea es mostrarles cómo
# funciona este tipo de extracciones que se hacen entonces con ese objetivo
# Déjenme les muestro Cuál es nuestro nuestra página objetivo en la página que se
# llama Cars
# Start time : 118.9
# End time : 176.5
# Source : MML-SG Training meeting (2024-04-17 19_09 GMT-5).csv
#
#
# Score: 0.7129
# Text:
# e lo que ven en pantalla es una de las cosas que más rompió mi cabeza cuando lo
# vi es él está hablando del presente el pasado del presente al futuro de la
# Inteligencia artificial de Machine learning, Obviamente que ya sabemos que va en
# el corazón, . Una de las cosas que me asombró es, .
# Start time : 3002.4
# End time : 3022.9
# Source : MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv
#
#
# Score: 0.7098
# Text:
# Eh, esta pregunta es tan e es tan fácil como difícil de responder, . Machine
# learning. Es el corazón a uno de los corazones que tiene a y creo que todos
# ahorita vemos el impacto que tiene la tecnología llegó a un nivel de madurez en
# el que podemos sacar provecho a estos algoritmos que se han estado desarrollando
# desde hace mucho tiempo, pero por capacidad de Hardware principalmente no se ha
# podido, . Concretar Eh hay hay mucho por hacer y es difícil incluso.
# Start time : 462.1
# End time : 496.9
# Source : MML-SG Training meeting (2024-02-21 19_06 GMT-5).csv

# %% [markdown]
# The first result looks to have nailed it!
#
# We get a very relevant answer to our query `"macronutrients functions"` even though its quite vague.
#
# That's the power of semantic search!
#
# And even better, if we wanted to inspect the result further, we get the page number where the text appears.
#
# How about we check the page to verify?
#
# We can do so by loading the page number containing the highest result (page 5 but really page 5 + 41 since our PDF page numbers start on page 41).

# %%
"""import fitz

# Open PDF and load target page
pdf_path = "human-nutrition-text.pdf"  # requires PDF to be downloaded
doc = fitz.open(pdf_path)
page = doc.load_page(5 + 41)  # number of page (our doc starts page numbers on page 41)

# Get the image of the page
img = page.get_pixmap(dpi=300)

# Optional: save the image
#img.save("output_filename.png")
doc.close()

# Convert the Pixmap to a numpy array
img_array = np.frombuffer(img.samples_mv,
                          dtype=np.uint8).reshape((img.h, img.w, img.n))

# Display the image using Matplotlib
import matplotlib.pyplot as plt

plt.figure(figsize=(13, 10))
plt.imshow(img_array)
plt.title(f"Query: '{query}' | Most relevant page:")
plt.axis('off')  # Turn off axis
plt.show()"""
# Out:
# 'import fitz\n\n# Open PDF and load target page\npdf_path = "human-nutrition-text.pdf"  # requires PDF to be downloaded\ndoc = fitz.open(pdf_path)\npage = doc.load_page(5 + 41)  # number of page (our doc starts page numbers on page 41)\n\n# Get the image of the page\nimg = page.get_pixmap(dpi=300)\n\n# Optional: save the image\n#img.save("output_filename.png")\ndoc.close()\n\n# Convert the Pixmap to a numpy array\nimg_array = np.frombuffer(img.samples_mv,\n                          dtype=np.uint8).reshape((img.h, img.w, img.n))\n\n# Display the image using Matplotlib\nimport matplotlib.pyplot as plt\n\nplt.figure(figsize=(13, 10))\nplt.imshow(img_array)\nplt.title(f"Query: \'{query}\' | Most relevant page:")\nplt.axis(\'off\')  # Turn off axis\nplt.show()'

# %% [markdown]
# Nice!
#
# Now we can do extra research if we'd like.
#
# We could repeat this workflow for any kind of query we'd like on our textbook.
#
# And it would also work for other datatypes too.
#
# We could use semantic search on customer support documents.
#
# Or email threads.
#
# Or company plans.
#
# Or our old journal entries.
#
# Almost anything!
#
# The workflow is the same:
#
# `ingest documents -> split into chunks -> embed chunks -> make a query -> embed the query -> compare query embedding to chunk embeddings`
#
# And we get relevant resources *along with* the source they came from!
#
# That's the **retrieval** part of Retrieval Augmented Generation (RAG).
#
# Before we get to the next two steps, let's take a small aside and discuss similarity measures.

# %% [markdown]
# ### Similarity measures: dot product and cosine similarity
#
# Let's talk similarity measures between vectors.
#
# Specifically, embedding vectors which are representations of data with magnitude and direction in high dimensional space (our embedding vectors have 768 dimensions).
#
# Two of the most common you'll across are the dot product and cosine similarity.
#
# They are quite similar.
#
# The main difference is that cosine similarity has a normalization step.
#
# | Similarity measure | Description | Code |
# | ----- | ----- | ----- |
# | [Dot Product](https://en.wikipedia.org/wiki/Dot_product) | - Measure of magnitude and direction between two vectors<br>- Vectors that are aligned in direction and magnitude have a higher positive value<br>- Vectors that are opposite in direction and magnitude have a higher negative value | [`torch.dot`](https://pytorch.org/docs/stable/generated/torch.dot.html), [`np.dot`](https://numpy.org/doc/stable/reference/generated/numpy.dot.html), [`sentence_transformers.util.dot_score`](https://www.sbert.net/docs/package_reference/util.html#sentence_transformers.util.dot_score) |
# | [Cosine Similarity](https://en.wikipedia.org/wiki/Cosine_similarity) | - Vectors get normalized by magnitude/[Euclidean norm](https://en.wikipedia.org/wiki/Norm_(mathematics))/L2 norm so they have unit length and are compared more so on direction<br>- Vectors that are aligned in direction have a value close to 1<br>- Vectors that are opposite in direction have a value close to -1 | [`torch.nn.functional.cosine_similarity`](https://pytorch.org/docs/stable/generated/torch.nn.functional.cosine_similarity.html), [`1 - scipy.spatial.distance.cosine`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.spatial.distance.cosine.html) (subtract the distance from 1 for similarity measure), [`sentence_transformers.util.cos_sim`](https://www.sbert.net/docs/package_reference/util.html#sentence_transformers.util.cos_sim) |
#
# For text similarity, you generally want to use cosine similarity as you are after the semantic measurements (direction) rather than magnitude.
#
# In our case, our embedding model `all-mpnet-base-v2` outputs normalized outputs (see the [Hugging Face model card](https://huggingface.co/sentence-transformers/all-mpnet-base-v2#usage-huggingface-transformers) for more on this) so dot product and cosine similarity return the same results. However, dot product is faster due to not need to perform a normalize step.
#
# To make things bit more concrete, let's make simple dot product and cosine similarity functions and view their results on different vectors.
#
# > **Note:** Similarity measures between vectors and embeddings can be used on any kind of embeddings, not just text embeddings. For example, you could measure image embedding similarity or audio embedding similarity. Or with text and image models like [CLIP](https://github.com/mlfoundations/open_clip), you can measure the similarity between text and image embeddings.

# %%
import torch


def dot_product(vector1, vector2):
    return torch.dot(vector1, vector2)


def cosine_similarity(vector1, vector2):
    dot_product = torch.dot(vector1, vector2)

    # Get Euclidean/L2 norm of each vector (removes the magnitude, keeps direction)
    norm_vector1 = torch.sqrt(torch.sum(vector1 ** 2))
    norm_vector2 = torch.sqrt(torch.sum(vector2 ** 2))

    return dot_product / (norm_vector1 * norm_vector2)


# Example tensors
vector1 = torch.tensor([1, 2, 3], dtype=torch.float32)
vector2 = torch.tensor([1, 2, 3], dtype=torch.float32)
vector3 = torch.tensor([4, 5, 6], dtype=torch.float32)
vector4 = torch.tensor([-1, -2, -3], dtype=torch.float32)

# Calculate dot product
print("Dot product between vector1 and vector2:", dot_product(vector1, vector2))
print("Dot product between vector1 and vector3:", dot_product(vector1, vector3))
print("Dot product between vector1 and vector4:", dot_product(vector1, vector4))

# Calculate cosine similarity
print("Cosine similarity between vector1 and vector2:", cosine_similarity(vector1, vector2))
print("Cosine similarity between vector1 and vector3:", cosine_similarity(vector1, vector3))
print("Cosine similarity between vector1 and vector4:", cosine_similarity(vector1, vector4))
# Out:
# Dot product between vector1 and vector2: tensor(14.)
# Dot product between vector1 and vector3: tensor(32.)
# Dot product between vector1 and vector4: tensor(-14.)
# Cosine similarity between vector1 and vector2: tensor(1.0000)
# Cosine similarity between vector1 and vector3: tensor(0.9746)
# Cosine similarity between vector1 and vector4: tensor(-1.0000)

# %% [markdown]
# Notice for both dot product and cosine similarity the comparisons of `vector1` and `vector2` are the opposite of `vector1` and `vector4`.
#
# Comparing `vector1` and `vector2` both equations return positive values (14 for dot product and 1.0 for cosine similarity).
#
# But comparing `vector1` and `vector4` the result is in the negative direction.
#
# This makes sense because `vector4` is the negative version of `vector1`.
#
# Whereas comparing `vector1` and `vector3` shows a different outcome.
#
# For the dot product, the value is positive and larger then the comparison of two exactly the same vectors (32 vs 14).
#
# However, for the cosine similarity, thanks to the normalization step, comparing `vector1` and `vector3` results in a postive value close to 1 but not exactly 1.
#
# It is because of this that when comparing text embeddings, cosine similarity is generally favoured as it measures the difference in direction of a pair of vectors rather than difference in magnitude.
#
# And it is this difference in direction that is more generally considered to capture the semantic meaning/vibe of the text.
#
# The good news is that as mentioned before, the outputs of our embedding model `all-mpnet-base-v2` are already normalized.
#
# So we can continue using the dot product (cosine similarity is dot product + normalization).
#
# With similarity measures explained, let's functionize our semantic search steps from above so we can repeat them.

# %% [markdown]
# ### Functionizing our semantic search pipeline
#
# Let's put all of the steps from above for semantic search into a function or two so we can repeat the workflow.

# %%
def retrieve_relevant_resources(query: str,
                                embeddings: torch.tensor,
                                model: SentenceTransformer = embedding_model,
                                n_resources_to_return: int = 5,
                                print_time: bool = True):
    """
    Embeds a query with model and returns top k scores and indices from embeddings.
    """

    # Embed the query
    query_embedding = model.encode(query,
                                   convert_to_tensor=True)

    # Get dot product scores on embeddings
    start_time = timer()
    dot_scores = util.dot_score(query_embedding, embeddings)[0]
    end_time = timer()

    if print_time:
        print(f"[INFO] Time taken to get scores on {len(embeddings)} embeddings: {end_time - start_time:.5f} seconds.")

    scores, indices = torch.topk(input=dot_scores,
                                 k=n_resources_to_return)

    return scores, indices


def print_top_results_and_scores(query: str,
                                 embeddings: torch.tensor,
                                 pages_and_chunks: list[dict] = recording_transcription_and_chunks,
                                 n_resources_to_return: int = 5):
    """
    Takes a query, retrieves most relevant resources and prints them out in descending order.

    Note: Requires pages_and_chunks to be formatted in a specific way (see above for reference).
    """

    scores, indices = retrieve_relevant_resources(query=query,
                                                  embeddings=embeddings,
                                                  n_resources_to_return=n_resources_to_return)

    print(f"Query: {query}\n")
    print("Results:")
    # Loop through zipped together scores and indicies
    for score, index in zip(scores, indices):
        print(f"Score: {score:.4f}")
        # Print relevant sentence chunk (since the scores are in descending order, the most relevant chunk will be first)
        print_wrapped(pages_and_chunks[index]["sentence_chunk"])
        # Print the page number too so we can reference the textbook further and check the results
        print(f"Start time : {pages_and_chunks[index]['Start time']}")
        print(f"End time : {pages_and_chunks[index]['End time']}")
        print(f"Source : {pages_and_chunks[index]['Source']}")
        print("\n")

# %% [markdown]
# Excellent! Now let's test our functions out.

# %%
query = "primer proyecto"

# Get just the scores and indices of top related results
scores, indices = retrieve_relevant_resources(query=query,
                                              embeddings=embeddings)
scores, indices
# Out:
# [INFO] Time taken to get scores on 1118 embeddings: 0.00038 seconds.
# (tensor([0.4322, 0.4117, 0.4107, 0.4099, 0.4019]),
#  tensor([249, 416, 424, 283, 742]))

# %%
# Print out the texts of the top scores
print_top_results_and_scores(query=query,
                             embeddings=embeddings)
# Out:
# [INFO] Time taken to get scores on 1118 embeddings: 0.00030 seconds.
# Query: primer proyecto
#
# Results:
# Score: 0.4322
# Eso ante la sesión pasada fue que ya con tanto Death Bake y por ejemplo con
# noción de voz clonación de rostros en videos y demás con un modelo supervisado
# es posible entrenarlo para que identifique Cuáles son falsos y cuáles no, eso es
# un digamos un tipo de clasificación que se podría estar ahí y eso lo hacen con
# modelos de este tipo que son supervisados que pueden, . Que ya conocen la
# respuesta al problema, vale, .,de nuevo para entrar en materia de cuáles son los
# algoritmos o los más populares El lineal polinómico, . Logístico superberry,
# digamos que quieres predecir el precio de una prenda, . Podría ser como en base
# a la marca Cómo es el color la textura, qué material se usa etcétera etcétera?
# Start time : 299.0
# End time : 358.2
# Source : MML-SG Training meeting (2024-03-13 19_07 GMT-5).csv
#
#
# Score: 0.4117
# Dale chicos, Entonces si quieren trabajemos con este en el en el tiempo medio
# voy a trabajar a sacar la información de de los carros, igual lo tenemos como en
# remojo en serio Les recomiendo mucho la librería porque ustedes pueden hacer
# esto en código pero de nuevo, si se dan cuenta esto te lo está haciendo en que
# nos demoramos 5 minutos y pues no te no te tienes que matar como haciendo esta
# observación inicial, entonces la recomiendo mucho y Y prefiero que de pronto
# bajo estas estos datos, si está primer análisis de pronto, busquen como tiene
# alta relación, Qué significa eso, qué pasa si tienes qt?Qué era lo que vimos
# ahorita, Qué pasa si tiene esta cola largota que o qué pasa si está
# desbalanceado, Qué significa estar desbalanceado un documento que Les
# recomiendo.
# Start time : 4232.0
# End time : 4291.8
# Source : MML-SG Training meeting (2024-04-10 19_11 GMT-5).csv
#
#
# Score: 0.4107
# Como ya casi como primerísimo bien, sí que iban a hacer como este proyecto y me
# interesó como para meterme al lado bienvenido bienvenido. Sí, genial, La idea,
# es hacer este proyecto para es Cómo empezar de cero con todo lo que ya hemos
# aprendido en las sesiones anteriores, que he hecho me di cuenta, no les compartí
# el video de la sesión anterior, Se los voy a compartir y ya estoy grabando el de
# este les comparto el de ambos, el objetivo es, . Con lo que hemos aprendido
# aplicarlo con un problema real, no, no queríamos Pues a pesar de que los
# ejercicios de libros están muy bien, son ejercicios de libro, seguramente van a
# funcionar, pero con un problema real, pues aprendes aprendes Cómo es desde cero,
# sí señor.
# Start time : 0.0
# End time : 58.9
# Source : MML-SG Training meeting (2024-04-17 19_09 GMT-5).csv
#
#
# Score: 0.4099
# Para resolver nuestro problema de predicción de precio se utiliza también para
# regresión y para .. Para clasificación, básicamente trabaja con condicionales
# que es lo que hemos visto en sesiones anteriores Ya lo hemos, . Trabajado, pero
# para los chicos nuevos le doy un contexto que digamos en la imagen que está a
# mano derecha, tienes un condicional que te dice el diámetro, qué tan gordito es
# las pepitas, qué tan Gorditas son sí Entonces si se dan cuenta las que están en
# este color, . Como fucsia, son ligeramente más pequeñas por lo que se van a la
# izquierda las más gorditas se van a la derecha, pero luego a la derecha tengo
# otro condicional, que me dice Cuál es tu color en este caso podemos decir si
# estás más tirando hacia el hacia el verde o tirando hacia el azul y haces otra
# división Y de esa manera, puedes aplicar una clasificación usando deshizo la
# regresión funciona.
# Start time : 2337.0
# End time : 2396.8
# Source : MML-SG Training meeting (2024-03-13 19_07 GMT-5).csv
#
#
# Score: 0.4019
# Make al piso que se llama señor una una duda ahí con ahorita que estaba
# nombrando es como que no alcancé pues como a preguntarte, pero es que he leído
# acerca de eso y en varias partes como que castigan un poquito como esas
# librerías de métodos que que generan datos sintéticos porque precisamente pues
# como que me están digamos que con datos ficticios gente del modelo, puede
# aprender de ellos, . A veces puede quedar incluso para que haya over peeling por
# ejemplo y y nombraste el otro de las redes, si si uno no utiliza una red
# neuronal, si no, otro algoritmo uno también podría decirle al al algoritmo al
# modelo tenga cuidado con que cuando se vaya a equivocar prediciendo, por
# ejemplo, la clase más desbalanceada, pues como póngale más atención a esas
# depende del algoritmo.
# Start time : 779.0
# End time : 838.7
# Source : MML-SG Training meeting (2024-05-15 19_11 GMT-5).csv

# %% [markdown]
# ### Semantic search/vector search extensions
#
# We've covered an exmaple of using embedding vector search to find relevant results based on a query.
#
# However, you could also add to this pipeline with traditional keyword search.
#
# Many modern search systems use keyword and vector search in tandem.
#
# Our dataset is small and allows for an exhaustive search (comparing the query to *every* possible result) but if you start to work with large scale datasets with hundred of thousands, millions or even billions of vectors, you'll want to implement an index.
#
# You can think of an index as sorting your embeddings before you search through them.
#
# So it narrows down the search space.
#
# For example, it would be inefficient to search every word in the dictionary to find the word "duck", instead you'd go straight to the letter D, perhaps even straight to the back half of the letter D, find words close to "duck" before finding it.
#
# That's how an index can help search through many examples without comprimising too much on speed or quality (for more on this, check out [nearest neighbour search](https://en.wikipedia.org/wiki/Nearest_neighbor_search)).
#
# One of the most popular indexing libraries is [Faiss](https://github.com/facebookresearch/faiss).
#
# Faiss is open-source and was originally created by Facebook to deal with internet-scale vectors and implements many algorithms such as [HNSW](https://arxiv.org/abs/1603.09320) (Hierarchical Naviganle Small Worlds).

# %% [markdown]
# ### Getting an LLM for local generation
#
# We're got our retrieval pipeline ready, let's now get the generation side of things happening.
#
# To perform generation, we're going to use a Large Language Model (LLM).
#
# LLMs are designed to generate an output given an input.
#
# In our case, we want our LLM to generate and output of text given a input of text.
#
# And more specifically, we want the output of text to be generated based on the context of relevant information to the query.
#
# The input to an LLM is often referred to as a prompt.
#
# We'll augment our prompt with a query as well as context from our textbook related to that query.
#
# > **Which LLM should I use?**
#
# There are many LLMs available.
#
# Two of the main questions to ask from this is:
# 1. Do I want it to run locally?
# 2. If yes, how much compute power can I dedicate?
#
# If you're after the absolute best performance, you'll likely want to use an API (not running locally) such as GPT-4 or Claude 3. However, this comes with the tradeoff of sending your data away and then awaiting a response.
#
# For our case, since we want to set up a local pipeline and run it on our own GPU, we'd answer "yes" to the first question and then the second question will depend on what hardware we have available.
#
# To find open-source LLMs, one great resource is the [Hugging Face open LLM leaderboard](https://huggingface.co/spaces/HuggingFaceH4/open_llm_leaderboard).
#
# The leaderboard compares many of the latest and greatest LLMs on various benchmarks.
#
# Another great resource is [TheBloke on Hugging Face](https://huggingface.co/TheBloke), an account which provides an extensive range of quantized (models that have been made smaller) LLMs.
#
# A rule of thumb for LLMs (and deep learning models in general) is that the higher the number of parameters, the better the model performs.
#
# It may be tempting to go for the largest size model (e.g. a 70B parameter model rather than a 7B parameter model) but a larger size model may not be able to run on your available hardware.
#
# The following table gives an insight into how much GPU memory you'll need to load an LLM with different sizes and different levels of [numerical precision](https://en.wikipedia.org/wiki/Precision_(computer_science)).
#
# They are based on the fact that 1 float32 value (e.g. `0.69420`) requires 4 bytes of memory and 1GB is approximately 1,000,000,000 (one billion) bytes.
#
# | Model Size (Billion Parameters) | Float32 VRAM (GB) | Float16 VRAM (GB) | 8-bit VRAM (GB) | 4-bit VRAM (GB) |
# |-----|-----|-----|-----|-----|
# | 1B                              | ~4                | ~2                | ~1              | ~0.5            |
# | 7B (e.g., [Llama 2 7B](https://huggingface.co/meta-llama/Llama-2-7b), [Gemma 7B](https://huggingface.co/google/gemma-7b-it), [Mistral 7B](https://huggingface.co/mistralai/Mistral-7B-v0.1))             | ~28               | ~14               | ~7              | ~3.5            |
# | 10B                             | ~40               | ~20               | ~10             | ~5              |
# | 70B (e.g, Llama 2 70B)          | ~280              | ~140              | ~70             | ~35             |
# | 100B                            | ~400              | ~200              | ~100            | ~50             |
# | 175B                            | ~700              | ~350              | ~175            | ~87.5           |
#
# <br>
#
# > **Note:** Loading a model in a lower precision (e.g. 8-bit instead of float16) generally lowers performance. Lower precision can help to reduce computing requirements, however sometimes the performance degradation in terms of model output can be substantial. Finding the right speed/performance tradeoff will often require many experiments.

# %% [markdown]
# ### Checking local GPU memory availability
#
# Let's find out what hardware we've got available and see what kind of model(s) we'll be able to load.
#
# > **Note:** You can also check this with the `!nvidia-smi` command.

# %%
# Get GPU available memory
import torch

gpu_memory_bytes = torch..get_device_properties(0).total_memory
gpu_memory_gb = round(gpu_memory_bytes / (2 ** 30))
print(f"Available GPU memory: {gpu_memory_gb} GB")
# Out:
#   Cell In[42], line 4
#     gpu_memory_bytes = torch..get_device_properties(0).total_memory
#                              ^
# SyntaxError: invalid syntax

# %% [markdown]
# Ok wonderful!
#
# I'm running this notebook with a NVIDIA RTX 4090, so I've got 24GB of VRAM available.
#
# However, this may be different on your end.
#
# Looking at the table above, it seems we can run a ~7-10B parameter model in float16 precision pretty comfortably.
#
# But we could also run a smaller one if we'd like.
#
# Let's try out the recently released (at the time of writing, March 2024) LLM from Google, [Gemma](https://huggingface.co/blog/gemma).
#
# Specifically, we'll use the `gemma-7b-it` version which stands for Gemma 7B Instruction-Tuned.
#
# Instruction tuning is the process of tuning a raw language model to follow instructions.
#
# These are the kind of models you'll find in most chat-based assistants such as ChatGPT, Gemini or Claude.
#
# The following table shows different amounts of GPU memory requirements for different verions of the Gemma LLMs with varying levels of precision.
#
# | Model             | Precision | Min-Memory (Bytes) | Min-Memory (MB) | Min-Memory (GB) | Recommended Memory (GB) | Hugging Face ID |
# |-------------------|-----------|----------------|-------------|-------------| ----- | ----- |
# | [Gemma 2B](https://huggingface.co/google/gemma-2b-it)          | 4-bit     | 2,106,749,952  | 2009.15     | 1.96        | ~5.0 | [`gemma-2b`](https://huggingface.co/google/gemma-2b) or [`gemma-2b-it`](https://huggingface.co/google/gemma-2b-it) for instruction tuned version |
# | Gemma 2B          | Float16   | 5,079,453,696  | 4844.14     | 4.73        | ~8.0 | Same as above |
# | [Gemma 7B](https://huggingface.co/google/gemma-7b-it)          | 4-bit     | 5,515,859,968  | 5260.33     | 5.14        | ~8.0 | [`gemma-7b`](https://huggingface.co/google/gemma-7b) or [`gemma-7b-it`](https://huggingface.co/google/gemma-7b-it) for instruction tuned version |
# | Gemma 7B          | Float16   | 17,142,470,656 | 16348.33    | 15.97       | ~19 | Same as above |
#
# > **Note:** `gemma-7b-it` means "instruction tuned", as in, a base LLM (`gemma-7b`) has been fine-tuned to follow instructions, similar to [`Mistral-7B-v0.1`](https://huggingface.co/mistralai/Mistral-7B-v0.1) and [`Mistral-7B-Instruct-v0.1`](https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.1).
# >
# > There are also further quantized and smaller variants of Gemma (and other LLMs) available in various formats such as GGUF. You can see many of these on [TheBloke account on Hugging Face](https://huggingface.co/TheBloke).
# >
# > The version of LLM you choose to use will be largely based on project requirements and experimentation.
#
# Based on the table above, let's write a simple if/else statement which recommends which Gemma variant we should look into using.

# %%
# Note: the following is Gemma focused, however, there are more and more LLMs of the 2B and 7B size appearing for local use.
if gpu_memory_gb < 5.1:
    print(
        f"Your available GPU memory is {gpu_memory_gb}GB, you may not have enough memory to run a Gemma LLM locally without quantization.")
elif gpu_memory_gb < 8.1:
    print(f"GPU memory: {gpu_memory_gb} | Recommended model: Gemma 2B in 4-bit precision.")
    use_quantization_config = True
    model_id = "google/gemma-2b-it"
elif gpu_memory_gb < 19.0:
    print(f"GPU memory: {gpu_memory_gb} | Recommended model: Gemma 2B in float16 or Gemma 7B in 4-bit precision.")
    use_quantization_config = False
    model_id = "google/gemma-2b-it"
elif gpu_memory_gb > 19.0:
    print(f"GPU memory: {gpu_memory_gb} | Recommend model: Gemma 7B in 4-bit or float16 precision.")
    use_quantization_config = False
    model_id = "google/gemma-7b-it"

print(f"use_quantization_config set to: {use_quantization_config}")
print(f"model_id set to: {model_id}")

# %% [markdown]
# ### Loading an LLM locally
#
# Alright! Looks like `gemma-7b-it` it is (for my local machine with an RTX 4090, change the `model_id` and `use_quantization_config` values to suit your needs)!
#
# There are plenty of examples of how to load the model on the `gemma-7b-it` [Hugging Face model card](https://huggingface.co/google/gemma-7b-it).
#
# Good news is, the Hugging Face [`transformers`](https://huggingface.co/docs/transformers/) library has all the tools we need.
#
# To load our LLM, we're going to need a few things:
# 1. A quantization config (optional) - This will determine whether or not we load the model in 4bit precision for lower memory usage. The we can create this with the [`transformers.BitsAndBytesConfig`](https://huggingface.co/docs/transformers/v4.38.2/en/main_classes/quantization#transformers.BitsAndBytesConfig) class (requires installing the [`bitsandbytes` library](https://github.com/TimDettmers/bitsandbytes)).
# 2. A model ID - This is the reference Hugging Face model ID which will determine which tokenizer and model gets used. For example `gemma-7b-it`.
# 3. A tokenzier - This is what will turn our raw text into tokens ready for the model. We can create it using the [`transformers.AutoTokenzier.from_pretrained`](https://huggingface.co/docs/transformers/v4.38.2/en/model_doc/auto#transformers.AutoTokenizer) method and passing it our model ID.
# 4. An LLM model - Again, using our model ID we can load a specific LLM model. To do so we can use the [`transformers.AutoModelForCausalLM.from_pretrained`](https://huggingface.co/docs/transformers/model_doc/auto#transformers.AutoModelForCausalLM.from_pretrained) method and passing it our model ID as well as other various parameters.
#
# As a bonus, we'll check if [Flash Attention 2](https://huggingface.co/docs/transformers/perf_infer_gpu_one#flashattention-2) is available using `transformers.utils.is_flash_attn_2_available()`. Flash Attention 2 speeds up the attention mechanism in Transformer architecture models (which is what many modern LLMs are based on, including Gemma). So if it's available and the model is supported (not all models support Flash Attention 2), we'll use it. If it's not available, you can install it by following the instructions on the [GitHub repo](https://github.com/Dao-AILab/flash-attention).
#
# > **Note:** Flash Attention 2 currently works on NVIDIA GPUs with a compute capability score of 8.0+ (Ampere, Ada Lovelace, Hopper architectures). We can check our GPU compute capability score with [`torch.cuda.get_device_capability(0)`](https://pytorch.org/docs/stable/generated/torch.cuda.get_device_capability.html).
#
# > **Note:** To get access to the Gemma models, you will have to [agree to the terms & conditions](https://huggingface.co/google/gemma-7b-it) on the Gemma model page on Hugging Face. You will then have to authorize your local machine via the [Hugging Face CLI/Hugging Face Hub `login()` function](https://huggingface.co/docs/huggingface_hub/en/quick-start#authentication). Once you've done this, you'll be able to download the models. If you're using Google Colab, you can add a [Hugging Face token](https://huggingface.co/docs/hub/en/security-tokens) to the "Secrets" tab.
# >
# > Downloading an LLM locally can take a fair bit of time depending on your internet connection. Gemma 7B is about a 16GB download and Gemma 2B is about a 6GB download.
#
# Let's do it!

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
from transformers.utils import is_flash_attn_2_available

# 1. Create quantization config for smaller model loading (optional)
# Requires !pip install bitsandbytes accelerate, see: https://github.com/TimDettmers/bitsandbytes, https://huggingface.co/docs/accelerate/
# For models that require 4-bit quantization (use this if you have low GPU memory available)
from transformers import BitsAndBytesConfig

quantization_config = BitsAndBytesConfig(load_in_4bit=True,
                                         bnb_4bit_compute_dtype=torch.float16)

# Bonus: Setup Flash Attention 2 for faster inference, default to "sdpa" or "scaled dot product attention" if it's not available
# Flash Attention 2 requires NVIDIA GPU compute capability of 8.0 or above, see: https://developer.nvidia.com/cuda-gpus
# Requires !pip install flash-attn, see: https://github.com/Dao-AILab/flash-attention 
if (is_flash_attn_2_available()) and (torch.cuda.get_device_capability(0)[0] >= 8):
    attn_implementation = "flash_attention_2"
else:
    attn_implementation = "sdpa"
print(f"[INFO] Using attention implementation: {attn_implementation}")

# 2. Pick a model we'd like to use (this will depend on how much GPU memory you have available)
#model_id = "google/gemma-7b-it"
model_id = model_id  # (we already set this above)
print(f"[INFO] Using model_id: {model_id}")

# 3. Instantiate tokenizer (tokenizer turns text into numbers ready for the model) 
tokenizer = AutoTokenizer.from_pretrained(pretrained_model_name_or_path=model_id)

# 4. Instantiate the model
llm_model = AutoModelForCausalLM.from_pretrained(pretrained_model_name_or_path=model_id,
                                                 torch_dtype=torch.float16,  # datatype to use, we want float16
                                                 quantization_config=quantization_config if use_quantization_config else None,
                                                 low_cpu_mem_usage=False,  # use full memory 
                                                 attn_implementation=attn_implementation)  # which attention version to use

if not use_quantization_config:  # quantization takes care of device setting automatically, so if it's not used, send model to GPU 
    llm_model.to("cuda")

# %% [markdown]
# We've got an LLM!
#
# Let's check it out.

# %%
llm_model

# %% [markdown]
# Ok, ok a bunch of layers ranging from embedding layers to attention layers (see the `GemmaFlashAttention2` layers!) to MLP and normalization layers.
#
# The good news is that we don't have to know too much about these to use the model.
#
# How about we get the number of parameters in our model?

# %%
def get_model_num_params(model: torch.nn.Module):
    return sum([param.numel() for param in model.parameters()])


get_model_num_params(llm_model)

# %% [markdown]
# Hmm, turns out that Gemma 7B is really Gemma 8.5B.
#
# It pays to do your own investigations!
#
# How about we get the models memory requirements?

# %%
def get_model_mem_size(model: torch.nn.Module):
    """
    Get how much memory a PyTorch model takes up.

    See: https://discuss.pytorch.org/t/gpu-memory-that-model-uses/56822
    """
    # Get model parameters and buffer sizes
    mem_params = sum([param.nelement() * param.element_size() for param in model.parameters()])
    mem_buffers = sum([buf.nelement() * buf.element_size() for buf in model.buffers()])

    # Calculate various model sizes
    model_mem_bytes = mem_params + mem_buffers  # in bytes
    model_mem_mb = model_mem_bytes / (1024 ** 2)  # in megabytes
    model_mem_gb = model_mem_bytes / (1024 ** 3)  # in gigabytes

    return {"model_mem_bytes": model_mem_bytes,
            "model_mem_mb": round(model_mem_mb, 2),
            "model_mem_gb": round(model_mem_gb, 2)}


get_model_mem_size(llm_model)

# %% [markdown]
# Nice, looks like this model takes up 15.97GB of space on the GPU.
#
# Plus a little more for the forward pass (due to all the calculations happening between the layers).
#
# Hence why I rounded it up to be ~19GB in the table above.
#
# Now let's get to the fun part, generating some text!

# %% [markdown]
# ### Generating text with our LLM
#
# We can generate text with our LLM `model` instance by calling the [`generate()` method](https://huggingface.co/docs/transformers/v4.38.2/en/main_classes/text_generation#transformers.GenerationConfig) (this method has plenty of options to pass into it alongside the text) on it and passing it a tokenized input.
#
# The tokenized input comes from passing a string of text to our `tokenizer`.
#
# It's important to note that you should use a tokenizer that has been paired with a model.
#
# Otherwise if you try to use a different tokenizer and then pass those inputs to a model, you will likely get errors/strange results.
#
# For some LLMs, there's a specific template you should pass to them for ideal outputs.
#
# For example, the `gemma-7b-it` model has been trained in a dialogue fashion (instruction tuning).
#
# In this case, our `tokenizer` has a [`apply_chat_template()` method](https://huggingface.co/docs/transformers/main/en/internal/tokenization_utils#transformers.PreTrainedTokenizerBase.apply_chat_template) which can prepare our input text in the right format for the model.
#
# Let's try it out.
#
# > **Note:** The following demo has been modified from the Hugging Face model card for [Gemma 7B](https://huggingface.co/google/gemma-7b-it). Many similar demos of usage are available on the model cards of similar models.

# %%
input_text = "What are the macronutrients, and what roles do they play in the human body?"
print(f"Input text:\n{input_text}")

# Create prompt template for instruction-tuned model
dialogue_template = [
    {"role": "user",
     "content": input_text}
]

# Apply the chat template
prompt = tokenizer.apply_chat_template(conversation=dialogue_template,
                                       tokenize=False,  # keep as raw text (not tokenized)
                                       add_generation_prompt=True)
print(f"\nPrompt (formatted):\n{prompt}")

# %% [markdown]
# Notice the scaffolding around our input text, this is the kind of turn-by-turn instruction tuning our model has gone through.
#
# Our next step is to tokenize this formatted text and pass it to our model's `generate()` method.
#
# We'll make sure our tokenized text is on the same device as our model (GPU) using `to("cuda")`.
#
# Let's generate some text!
#
# We'll time it for fun with the `%%time` magic.

# %%
# %%time

# Tokenize the input text (turn it into numbers) and send it to GPU
input_ids = tokenizer(prompt, return_tensors="pt").to("cuda")
print(f"Model input (tokenized):\n{input_ids}\n")

# Generate outputs passed on the tokenized input
# See generate docs: https://huggingface.co/docs/transformers/v4.38.2/en/main_classes/text_generation#transformers.GenerationConfig 
outputs = llm_model.generate(**input_ids,
                             max_new_tokens=256)  # define the maximum number of new tokens to create
print(f"Model output (tokens):\n{outputs[0]}\n")

# %% [markdown]
# Woohoo! We just generated some text on our local GPU!
#
# Well not just yet...
#
# Our LLM accepts tokens in and sends tokens back out.
#
# We can conver the output tokens to text using [`tokenizer.decode()`](https://huggingface.co/docs/transformers/main_classes/tokenizer#transformers.PreTrainedTokenizer.decode).

# %%
# Decode the output tokens to text
outputs_decoded = tokenizer.decode(outputs[0])
print(f"Model output (decoded):\n{outputs_decoded}\n")

# %% [markdown]
# Woah! That looks like a pretty good answer.
#
# But notice how the output contains the prompt text as well?
#
# How about we do a little formatting to replace the prompt in the output text?
#
# > **Note:** `"<bos>"` and `"<eos>"` are special tokens to denote "beginning of sentence" and "end of sentence" respectively.

# %%
print(f"Input text: {input_text}\n")
print(f"Output text:\n{outputs_decoded.replace(prompt, '').replace('<bos>', '').replace('<eos>', '')}")

# %% [markdown]
# How cool is that!
#
# We just officially generated text from an LLM running locally.
#
# So we've covered the R (retrieval) and G (generation) of RAG.
#
# How about we check out the last step?
#
# Augmentation.
#
# First, let's put together a list of queries we can try out with our pipeline.

# %%
# Nutrition-style questions generated with GPT4
gpt4_questions = [
    "What are the macronutrients, and what roles do they play in the human body?",
    "How do vitamins and minerals differ in their roles and importance for health?",
    "Describe the process of digestion and absorption of nutrients in the human body.",
    "What role does fibre play in digestion? Name five fibre containing foods.",
    "Explain the concept of energy balance and its importance in weight management."
]

# Manually created question list
manual_questions = [
    "How often should infants be breastfed?",
    "What are symptoms of pellagra?",
    "How does saliva help with digestion?",
    "What is the RDI for protein per day?",
    "water soluble vitamins"
]

query_list = gpt4_questions + manual_questions

# %% [markdown]
# And now let's check if our `retrieve_relevant_resources()` function works with our list of queries.

# %%
import random

query = random.choice(query_list)

print(f"Query: {query}")

# Get just the scores and indices of top related results
scores, indices = retrieve_relevant_resources(query=query,
                                              embeddings=embeddings)
scores, indices

# %% [markdown]
# Beautiful!
#
# Let's augment!

# %% [markdown]
# ### Augmenting our prompt with context items
#
# What we'd like to do with augmentation is take the results from our search for relevant resources and put them into the prompt that we pass to our LLM.
#
# In essence, we start with a base prompt and update it with context text.
#
# Let's write a function called `prompt_formatter` that takes in a query and our list of context items (in our case it'll be select indices from our list of dictionaries inside `pages_and_chunks`) and then formats the query with text from the context items.
#
# We'll apply the dialogue and chat template to our prompt before returning it as well.
#
# > **Note:** The process of augmenting or changing a prompt to an LLM is known as prompt engineering. And the best way to do it is an active area of research. For a comprehensive guide on different prompt engineering techniques, I'd recommend the Prompt Engineering Guide ([promptingguide.ai](https://www.promptingguide.ai/)), [Brex's Prompt Engineering Guide](https://github.com/brexhq/prompt-engineering) and the paper [Prompt Design and Engineering: Introduction and Advanced Models](https://arxiv.org/abs/2401.14423).

# %%
def prompt_formatter(query: str,
                     context_items: list[dict]) -> str:
    """
    Augments query with text-based context from context_items.
    Augments query with text-based context from context_items.
    """
    # Join context items into one dotted paragraph
    context = "- " + "\n- ".join([item["sentence_chunk"] for item in context_items])

    # Create a base prompt with examples to help the model
    # Note: this is very customizable, I've chosen to use 3 examples of the answer style we'd like.
    # We could also write this in a txt file and import it in if we wanted.
    base_prompt = """Based on the following context items, please answer the query.
Give yourself room to think by extracting relevant passages from the context before answering the query.
Don't return the thinking, only return the answer.
Make sure your answers are as explanatory as possible.
Use the following examples as reference for the ideal answer style.
\nExample 1:
Query: What are the fat-soluble vitamins?
Answer: The fat-soluble vitamins include Vitamin A, Vitamin D, Vitamin E, and Vitamin K. These vitamins are absorbed along with fats in the diet and can be stored in the body's fatty tissue and liver for later use. Vitamin A is important for vision, immune function, and skin health. Vitamin D plays a critical role in calcium absorption and bone health. Vitamin E acts as an antioxidant, protecting cells from damage. Vitamin K is essential for blood clotting and bone metabolism.
\nExample 2:
Query: What are the causes of type 2 diabetes?
Answer: Type 2 diabetes is often associated with overnutrition, particularly the overconsumption of calories leading to obesity. Factors include a diet high in refined sugars and saturated fats, which can lead to insulin resistance, a condition where the body's cells do not respond effectively to insulin. Over time, the pancreas cannot produce enough insulin to manage blood sugar levels, resulting in type 2 diabetes. Additionally, excessive caloric intake without sufficient physical activity exacerbates the risk by promoting weight gain and fat accumulation, particularly around the abdomen, further contributing to insulin resistance.
\nExample 3:
Query: What is the importance of hydration for physical performance?
Answer: Hydration is crucial for physical performance because water plays key roles in maintaining blood volume, regulating body temperature, and ensuring the transport of nutrients and oxygen to cells. Adequate hydration is essential for optimal muscle function, endurance, and recovery. Dehydration can lead to decreased performance, fatigue, and increased risk of heat-related illnesses, such as heat stroke. Drinking sufficient water before, during, and after exercise helps ensure peak physical performance and recovery.
\nNow use the following context items to answer the user query:
{context}
\nRelevant passages: <extract relevant passages from the context here>
User query: {query}
Answer:"""

    # Update base prompt with context items and query   
    base_prompt = base_prompt.format(context=context, query=query)

    # Create prompt template for instruction-tuned model
    dialogue_template = [
        {"role": "user",
         "content": base_prompt}
    ]

    # Apply the chat template
    prompt = tokenizer.apply_chat_template(conversation=dialogue_template,
                                           tokenize=False,
                                           add_generation_prompt=True)
    return prompt

# %% [markdown]
# Looking good! Let's try our function out.

# %%
query = random.choice(query_list)
print(f"Query: {query}")

# Get relevant resources
scores, indices = retrieve_relevant_resources(query=query,
                                              embeddings=embeddings)

# Create a list of context items
context_items = [recording_transcription_and_chunks[i] for i in indices]

# Format prompt with context items
prompt = prompt_formatter(query=query,
                          context_items=context_items)
print(prompt)

# %% [markdown]
# What a good looking prompt!
#
# We can tokenize this and pass it straight to our LLM.

# %%
# %%time

input_ids = tokenizer(prompt, return_tensors="pt").to("cuda")

# Generate an output of tokens
outputs = llm_model.generate(**input_ids,
                             temperature=0.7,
                             # lower temperature = more deterministic outputs, higher temperature = more creative outputs
                             do_sample=True,
                             # whether or not to use sampling, see https://huyenchip.com/2024/01/16/sampling.html for more
                             max_new_tokens=256)  # how many new tokens to generate from prompt 

# Turn the output tokens into text
output_text = tokenizer.decode(outputs[0])

print(f"Query: {query}")
print(f"RAG answer:\n{output_text.replace(prompt, '')}")

# %% [markdown]
# Yesssssss!!!
#
# Our RAG pipeline is complete!
#
# We just Retrieved, Augmented and Generated!
#
# And all on our own local GPU!
#
# How about we functionize the generation step to make it easier to use?
#
# We can put a little formatting on the text being returned to make it look nice too.
#
# And we'll make an option to return the context items if needed as well.

# %%
def ask(query,
        temperature=0.7,
        max_new_tokens=512,
        format_answer_text=True,
        return_answer_only=True):
    """
    Takes a query, finds relevant resources/context and generates an answer to the query based on the relevant resources.
    """

    # Get just the scores and indices of top related results
    scores, indices = retrieve_relevant_resources(query=query,
                                                  embeddings=embeddings)

    # Create a list of context items
    context_items = [recording_transcription_and_chunks[i] for i in indices]

    # Add score to context item
    for i, item in enumerate(context_items):
        item["score"] = scores[i].cpu()  # return score back to CPU 

    # Format the prompt with context items
    prompt = prompt_formatter(query=query,
                              context_items=context_items)

    # Tokenize the prompt
    input_ids = tokenizer(prompt, return_tensors="pt").to("cuda")

    # Generate an output of tokens
    outputs = llm_model.generate(**input_ids,
                                 temperature=temperature,
                                 do_sample=True,
                                 max_new_tokens=max_new_tokens)

    # Turn the output tokens into text
    output_text = tokenizer.decode(outputs[0])

    if format_answer_text:
        # Replace special tokens and unnecessary help message
        output_text = output_text.replace(prompt, "").replace("<bos>", "").replace("<eos>", "").replace(
            "Sure, here is the answer to the user query:\n\n", "")

    # Only return the answer without the context items
    if return_answer_only:
        return output_text

    return output_text, context_items

# %% [markdown]
# What a good looking function!
#
# The workflow could probably be a little refined but this should work!
#
# Let's try it out.

# %%
query = random.choice(query_list)
print(f"Query: {query}")

# Answer query with context and return context 
answer, context_items = ask(query=query,
                            temperature=0.7,
                            max_new_tokens=512,
                            return_answer_only=False)

print(f"Answer:\n")
print_wrapped(answer)
print(f"Context items:")
context_items

# %% [markdown]
# Local RAG workflow complete!
#
# We've now officially got a way to Retrieve, Augment and Generate answers based on a source.
#
# For now we can verify our answers manually by reading them and reading through the textbook.
#
# But if you want to put this into a production system, it'd be a good idea to have some kind of evaluation on how well our pipeline works.
#
# For example, you could use another LLM to rate the answers returned by our LLM and then use those ratings as a proxy evaluation.
#
# However, I'll leave this and a few more interesting ideas as extensions.

# %% [markdown]
# ## Extensions
#
# * May want to improve text extraction with something like Marker - https://github.com/VikParuchuri/marker
# * Guide to more advanced PDF extraction - https://towardsdatascience.com/extracting-text-from-pdf-files-with-python-a-comprehensive-guide-9fc4003d517
# * See the following prompt engineering resources for more prompting techniques - promptinguide.ai, Brex's Prompt Engineering Guide
# * What happens when a query comes through that there isn't any context in the textbook on?
# * Try another embedding model (e.g. Mixed Bread AI large, `mixedbread-ai/mxbai-embed-large-v1`, see: https://huggingface.co/mixedbread-ai/mxbai-embed-large-v1)
# * Try another LLM... (e.g. Mistral-Instruct)
# * Try different prompts (e.g. see prompting techniques online)
# * Our example only focuses on text from a PDF, however, we could extend it to include figures and images
# * Evaluate the answers -> could use another LLM to rate our answers (e.g. use GPT-4 to make)
# * Vector database/index for larger setup (e.g. 100,000+ chunks)
# * Libraries/frameworks such as LangChain / LlamaIndex can help do many of the steps for you - so it's worth looking into those next, wanted to recreate a workflow with lower-level tools to show the principles
# * Optimizations for speed
#     * See Hugging Face docs for recommended speed ups on GPU - https://huggingface.co/docs/transformers/perf_infer_gpu_one
#     * Optimum NVIDIA - https://huggingface.co/blog/optimum-nvidia, GitHub: https://github.com/huggingface/optimum-nvidia
#     * See NVIDIA TensorRT-LLM - https://github.com/NVIDIA/TensorRT-LLM
#     * See GPT-Fast for PyTorch-based optimizations - https://github.com/pytorch-labs/gpt-fast
#     * Flash attention 2 (requires Ampere GPUs or newer) - https://github.com/Dao-AILab/flash-attention
# * Stream text output so it looks prettier (e.g. each token appears as it gets output from the model)
# * Turn the workflow into an app, see Gradio type chatbots for this - https://www.gradio.app/guides/creating-a-chatbot-fast, see local example: https://www.gradio.app/guides/creating-a-chatbot-fast#example-using-a-local-open-source-llm-with-hugging-face
